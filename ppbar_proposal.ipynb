# %% [markdown]
# # Exercise with $p\bar{p}$-reacion
#
# Angular coverige
# ![calorimeter](ppbar/calorimeter.png)
# WASA-at-COSY calorimeter
# ![Angular](ppbar/angular_covarage.png)
# Other characteristics
# ![characteristics](ppbar/characteristics.png)

# %% [markdown]
# ## Phase space simulations for the reaction  $p\bar{p}\to Z_c^+[\to J/\psi\pi^0\pi^0]\, \pi^-$
#  * For simplicity, I consider $Z_c$ very narrow.
#  * Flat Dalitz plot for $J/\psi\pi^0\pi^0$

# %%
function boost!(v,γ)
    β=sqrt(1-1/γ^2)
    v[1],v[4] = v[1]*γ+v[4]*β*γ, v[1]*β*γ+v[4]*γ
end

function rotateY!(v,cosθ)
    sinθ = sqrt(1-cosθ*cosθ)
    v[2],v[4] = v[2]*cosθ+v[4]*sinθ, -v[2]*sinθ+v[4]*cosθ
end

function rotateZ!(v,ϕ)
    v[2],v[3] = v[2]*cos(ϕ)-v[3]*sin(ϕ), v[3]*cos(ϕ)+v[2]*sin(ϕ)
end

λ(x,y,z) = x^2+y^2+z^2-2*x*y-2*y*z-2*z*x

function decay2two(v0,m1sq,m2sq)
    cosθ = 2*rand()-1;
    decay2two(v0,m1sq,m2sq,cosθ)
end

function decay2two(v0,m1sq,m2sq,cosθ)
    p0sq = v0[2]*v0[2]+v0[3]*v0[3]+v0[4]*v0[4];
    msq = v0[1]*v0[1]-p0sq
    (sqrt(msq) < sqrt(m1sq)+sqrt(m2sq)) && begin
        print("Error<decay2two>: decay products are too heavy (dM=",
            sqrt(msq) - (sqrt(m1sq)+sqrt(m2sq)),")!\n")
        return [0,0,0,0], [0,0,0,0]
    end
    p = sqrt(λ(msq,m1sq,m2sq)/(4*msq));
    ϕ = (2*rand()-1)*π;
    sinθ = sqrt(1-cosθ*cosθ);
    v1 = [(msq+m1sq-m2sq)/(2*sqrt(msq)),p*sinθ*sin(ϕ),p*sinθ*cos(ϕ),p*cosθ];
    v2 = [(msq-m1sq+m2sq)/(2*sqrt(msq)),-p*sinθ*sin(ϕ),-p*sinθ*cos(ϕ),-p*cosθ];
    # boost and rotate to the Lab frame
    γ0 = v0[1]/sqrt(msq)
    boost!(v1,γ0); boost!(v2,γ0); 
    # rotate appropriately
    if (p0sq > 0) 
        cosθ0 = v0[4]/sqrt(p0sq)
        rotateY!(v1,cosθ0); rotateY!(v2,cosθ0); 
    end
    ϕ0 = atan2(v0[3],v0[2])
    rotateZ!(v1,ϕ0); rotateZ!(v2,ϕ0);
    return v1,v2
end

masssq(v) = v[1]^2-v[2]^2-v[3]^2-v[4]^2;

# %%
# set constants
const mπ = 0.139; const mπ2 = mπ^2;
const mZc = 4.430; const mJpsi = 3.096;
const mp = 0.938; const mp2 = mp^2;
const mμ = 0.105; const mμ2 = mμ^2;
# energy
const e0 = 12 # (GeV)
const s0 = 2*mp2+2*mp*e0  # (GeV^2)

# functions to generate random variables
fρ(s,m1sq,m2sq,m3sq,m0sq)=(sqrt(s)>sqrt(m1sq)+sqrt(m2sq)) ? sqrt(λ(s,m1sq,m2sq)*λ(m0sq,s,m3sq))/s : 0;

const dX = collect(linspace(4mπ2,(mZc-mJpsi)^2,100))
fX = [fρ(s,mπ2,mπ2,mJpsi^2,mZc^2) for s in 0.5*(dX[1:end-1]+dX[2:end])]; fX /= sum(fX)
[fX[i] = fX[i-1]+fX[i] for i in 2:length(fX)];
const cX = fX;

# %%
# X disctribution
function randX()
    bi = searchsortedlast(cX,rand())+1
    return dX[bi] + rand()*(dX[bi+1]-dX[bi])
end
# Out:
# randX (generic function with 1 method)

# %%
using Plots

# %%
histogram([randX() for i=1:100000],bins=100)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip1400)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip1400)" points="
# 42.1066,375.813 580.315,375.813 580.315,11.811 42.1066,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="42" y="11" width="539" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip1402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   113.427,375.813 113.427,11.811
#   "/>
# <polyline clip-path="url(#clip1402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   187.227,375.813 187.227,11.811
#   "/>
# <polyline clip-path="url(#clip1402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   261.027,375.813 261.027,11.811
#   "/>
# <polyline clip-path="url(#clip1402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   334.827,375.813 334.827,11.811
#   "/>
# <polyline clip-path="url(#clip1402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   408.627,375.813 408.627,11.811
#   "/>
# <polyline clip-path="url(#clip1402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   482.427,375.813 482.427,11.811
#   "/>
# <polyline clip-path="url(#clip1402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   556.227,375.813 556.227,11.811
#   "/>
# <polyline clip-path="url(#clip1402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   42.1066,375.813 580.315,375.813
#   "/>
# <polyline clip-path="url(#clip1402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   42.1066,263.675 580.315,263.675
#   "/>
# <polyline clip-path="url(#clip1402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   42.1066,151.536 580.315,151.536
#   "/>
# <polyline clip-path="url(#clip1402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   42.1066,39.3972 580.315,39.3972
#   "/>
# <polyline clip-path="url(#clip1400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.1066,375.813 580.315,375.813
#   "/>
# <polyline clip-path="url(#clip1400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.1066,375.813 42.1066,11.811
#   "/>
# <polyline clip-path="url(#clip1400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   113.427,375.813 113.427,370.353
#   "/>
# <polyline clip-path="url(#clip1400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   187.227,375.813 187.227,370.353
#   "/>
# <polyline clip-path="url(#clip1400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   261.027,375.813 261.027,370.353
#   "/>
# <polyline clip-path="url(#clip1400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   334.827,375.813 334.827,370.353
#   "/>
# <polyline clip-path="url(#clip1400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   408.627,375.813 408.627,370.353
#   "/>
# <polyline clip-path="url(#clip1400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   482.427,375.813 482.427,370.353
#   "/>
# <polyline clip-path="url(#clip1400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   556.227,375.813 556.227,370.353
#   "/>
# <polyline clip-path="url(#clip1400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.1066,375.813 50.1797,375.813
#   "/>
# <polyline clip-path="url(#clip1400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.1066,263.675 50.1797,263.675
#   "/>
# <polyline clip-path="url(#clip1400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.1066,151.536 50.1797,151.536
#   "/>
# <polyline clip-path="url(#clip1400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.1066,39.3972 50.1797,39.3972
#   "/>
# <g clip-path="url(#clip1400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 113.427, 389.613)" x="113.427" y="389.613">0.25</text>
# </g>
# <g clip-path="url(#clip1400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 187.227, 389.613)" x="187.227" y="389.613">0.50</text>
# </g>
# <g clip-path="url(#clip1400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 261.027, 389.613)" x="261.027" y="389.613">0.75</text>
# </g>
# <g clip-path="url(#clip1400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 334.827, 389.613)" x="334.827" y="389.613">1.00</text>
# </g>
# <g clip-path="url(#clip1400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 408.627, 389.613)" x="408.627" y="389.613">1.25</text>
# </g>
# <g clip-path="url(#clip1400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 482.427, 389.613)" x="482.427" y="389.613">1.50</text>
# </g>
# <g clip-path="url(#clip1400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 556.227, 389.613)" x="556.227" y="389.613">1.75</text>
# </g>
# <g clip-path="url(#clip1400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 36.1066, 380.313)" x="36.1066" y="380.313">0</text>
# </g>
# <g clip-path="url(#clip1400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 36.1066, 268.175)" x="36.1066" y="268.175">500</text>
# </g>
# <g clip-path="url(#clip1400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 36.1066, 156.036)" x="36.1066" y="156.036">1000</text>
# </g>
# <g clip-path="url(#clip1400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 36.1066, 43.8972)" x="36.1066" y="43.8972">1500</text>
# </g>
# <polygon clip-path="url(#clip1402)" points="
# 57.3389,355.853 57.3389,375.813 63.2429,375.813 63.2429,355.853 57.3389,355.853 57.3389,355.853
#   " fill="#009af9" fill-opacity="1"/>
# <polyline clip-path="url(#clip1402)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   57.3389,355.853 57.3389,375.813 63.2429,375.813 63.2429,355.853 57.3389,355.853
#   "/>
# <polygon clip-path="url(#clip1402)" points="
# 63.2429,222.408 63.2429,375.813 69.1469,375.813 69.1469,222.408 63.2429,222.408 63.2429,222.408
#   " fill="#009af9" fill-opacity="1"/>
# <polyline clip-path="url(#clip1402)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   63.2429,222.408 63.2429,375.813 69.1469,375.813 69.1469,222.408 63.2429,222.408
#   "/>
# <polygon clip-path="url(#clip1402)" points="
# 69.1469,145.705 6

# %%
function generate()
    p0 = [e0,0,0,sqrt(e0^2-mp2)] + [mp,0,0,0];
    # generate variables
    pZc,pπm = decay2two(p0,mZc^2,mπ2)
    # Z to Jpsi pi pi
    sPiPi = randX();
    # Z to Jpsi pi pi
    pPiPi,pJpsi = decay2two(pZc,sPiPi,mJpsi^2)
    pπ01,pπ02 = decay2two(pPiPi,mπ2,mπ2)
    pγ1,pγ2 = decay2two(pπ01,0,0)
    pγ3,pγ4 = decay2two(pπ02,0,0)
    pμ1,pμ2 = decay2two(pJpsi,mμ2,mμ2)
    pμ1,pμ2,pπm,pγ1,pγ2,pγ3,pγ4
end
# Out:
# generate (generic function with 1 method)

# %%
using DataFrames

# %%
pμ1,pμ2,pπm,pγ1,pγ2,pγ3,pγ4 = generate()
# Out:
# ([1.34028, 0.890638, -0.664269, 0.742178], [7.21886, 0.0689513, 0.74648, 7.17906], [1.36673, -0.251583, 0.372927, 1.28306], [0.310356, -0.193168, -0.105205, 0.218949], [1.01855, -0.430248, -0.322917, 0.864899], [1.4222, -0.10601, -0.0593778, 1.417], [0.261027, 0.0214202, 0.0323616, 0.258126])

# %%
Nev = 10000
# data storage
tree = DataFrame(
    [Array{Float64,1} for i in 1:7],
    [:M1, :M2, :C1, :G1, :G2, :G3, :G4],
    Nev);
# fill with events
for i in 1:Nev
    tree[i,:M1],tree[i,:M2],tree[i,:C1],
        tree[i,:G1],tree[i,:G2],tree[i,:G3],tree[i,:G4] = generate();
end

# %%
histogram(vcat(
    [tree[i,:G1][1] for i=1:821],
    [tree[i,:G2][1] for i=1:821],
    [tree[i,:G3][1] for i=1:821],
    [tree[i,:G4][1] for i=1:821]), bins=100,
    lab = "", title = "Energy spectrum of photons", xlab = "Eg, (GeV)")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip2200)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip2200)" points="
# 35.5169,360.065 580.315,360.065 580.315,31.4961 35.5169,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="35" y="31" width="546" height="330"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip2202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   50.9357,360.065 50.9357,31.4961
#   "/>
# <polyline clip-path="url(#clip2202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   151.712,360.065 151.712,31.4961
#   "/>
# <polyline clip-path="url(#clip2202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   252.489,360.065 252.489,31.4961
#   "/>
# <polyline clip-path="url(#clip2202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   353.265,360.065 353.265,31.4961
#   "/>
# <polyline clip-path="url(#clip2202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   454.042,360.065 454.042,31.4961
#   "/>
# <polyline clip-path="url(#clip2202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   554.818,360.065 554.818,31.4961
#   "/>
# <polyline clip-path="url(#clip2202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   35.5169,360.065 580.315,360.065
#   "/>
# <polyline clip-path="url(#clip2202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   35.5169,284.008 580.315,284.008
#   "/>
# <polyline clip-path="url(#clip2202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   35.5169,207.95 580.315,207.95
#   "/>
# <polyline clip-path="url(#clip2202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   35.5169,131.892 580.315,131.892
#   "/>
# <polyline clip-path="url(#clip2202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   35.5169,55.8345 580.315,55.8345
#   "/>
# <polyline clip-path="url(#clip2200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.5169,360.065 580.315,360.065
#   "/>
# <polyline clip-path="url(#clip2200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.5169,360.065 35.5169,31.4961
#   "/>
# <polyline clip-path="url(#clip2200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   50.9357,360.065 50.9357,355.137
#   "/>
# <polyline clip-path="url(#clip2200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   151.712,360.065 151.712,355.137
#   "/>
# <polyline clip-path="url(#clip2200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   252.489,360.065 252.489,355.137
#   "/>
# <polyline clip-path="url(#clip2200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   353.265,360.065 353.265,355.137
#   "/>
# <polyline clip-path="url(#clip2200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   454.042,360.065 454.042,355.137
#   "/>
# <polyline clip-path="url(#clip2200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   554.818,360.065 554.818,355.137
#   "/>
# <polyline clip-path="url(#clip2200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.5169,360.065 43.6889,360.065
#   "/>
# <polyline clip-path="url(#clip2200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.5169,284.008 43.6889,284.008
#   "/>
# <polyline clip-path="url(#clip2200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.5169,207.95 43.6889,207.95
#   "/>
# <polyline clip-path="url(#clip2200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.5169,131.892 43.6889,131.892
#   "/>
# <polyline clip-path="url(#clip2200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.5169,55.8345 43.6889,55.8345
#   "/>
# <g clip-path="url(#clip2200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 50.9357, 373.865)" x="50.9357" y="373.865">0</text>
# </g>
# <g clip-path="url(#clip2200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 151.712, 373.865)" x="151.712" y="373.865">1</text>
# </g>
# <g clip-path="url(#clip2200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 252.489, 373.865)" x="252.489" y="373.865">2</text>
# </g>
# <g clip-path="url(#clip2200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 353.265, 373.865)" x="353.265" y="373.865">3</text>
# </g>
# <g clip-path="url(#clip2200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 454.042, 373.865)" x="454.042" y="373.865">4</text>
# </g>
# <g clip-path="url(#clip2200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 554.818, 373.865)" x="554.818" y="373.865">5</text>
# </g>
# <g clip-path="url(#clip2200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.5169, 364.565)" x="29.5169" y="364.565">0</text>
# </g>
# <g clip-path="url(#clip2200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.5169, 288.508)" x="29.5169" y="288.508">50</text>
# </g>
# <g clip-path="url(#clip2200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.5169, 212.45)" x="29.5169" y="212.45">100</text>
# </g>
# <g clip-path="url(#clip2200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.5169, 136.392)" x="29.5169" y="136.392">150</text>
# </g>
# <g clip-path="url(#clip2200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.5169, 60.3345)" x="29.5169" y="60.3345">200</text>
# </g>
# <g clip-path="url(#clip2200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(0, 307.916, 18)" x="307.916" y="18">Energy spectrum of photons</text>
# </g>
# <g clip-path="url(#clip2200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(0, 307.916, 397.6)" x="307.916" y="397.6">Eg, (GeV)</text>
# </g>
# <polygon clip-path="url(#clip2202)" points="
# 50.9357,141.019 50.9357,360.065 55.9746,360.065 55.9746,141.019 50.9357,141.019 50.9357,141.019
#   " fill="#009af9" fill-opacity="1"/>
# <polyline clip-path="url(#clip2202)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   50.9357,141.019 50.9357,360.065 55.9746,360.065 55

# %%
polAngle(v) = 180/π*acos(v[4]/v[1])
histogram(vcat(
    [polAngle(tree[i,:G1]) for i=1:size(tree,1)],
    [polAngle(tree[i,:G2]) for i=1:size(tree,1)],
    [polAngle(tree[i,:G3]) for i=1:size(tree,1)],
    [polAngle(tree[i,:G4]) for i=1:size(tree,1)]), bins=100,
    xlim = (0,180),
    lab = "", title = "Polar angles of photons", xlab = "theta, (deg.)")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip9600)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip9600)" points="
# 42.1066,360.065 580.315,360.065 580.315,31.4961 42.1066,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="42" y="31" width="539" height="330"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip9602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   42.1066,360.065 42.1066,31.4961
#   "/>
# <polyline clip-path="url(#clip9602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   131.808,360.065 131.808,31.4961
#   "/>
# <polyline clip-path="url(#clip9602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   221.509,360.065 221.509,31.4961
#   "/>
# <polyline clip-path="url(#clip9602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   311.211,360.065 311.211,31.4961
#   "/>
# <polyline clip-path="url(#clip9602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   400.912,360.065 400.912,31.4961
#   "/>
# <polyline clip-path="url(#clip9602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   490.614,360.065 490.614,31.4961
#   "/>
# <polyline clip-path="url(#clip9602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   580.315,360.065 580.315,31.4961
#   "/>
# <polyline clip-path="url(#clip9602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   42.1066,360.065 580.315,360.065
#   "/>
# <polyline clip-path="url(#clip9602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   42.1066,291.613 580.315,291.613
#   "/>
# <polyline clip-path="url(#clip9602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   42.1066,223.162 580.315,223.162
#   "/>
# <polyline clip-path="url(#clip9602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   42.1066,154.71 580.315,154.71
#   "/>
# <polyline clip-path="url(#clip9602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   42.1066,86.2576 580.315,86.2576
#   "/>
# <polyline clip-path="url(#clip9600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.1066,360.065 580.315,360.065
#   "/>
# <polyline clip-path="url(#clip9600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.1066,360.065 42.1066,31.4961
#   "/>
# <polyline clip-path="url(#clip9600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.1066,360.065 42.1066,355.137
#   "/>
# <polyline clip-path="url(#clip9600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   131.808,360.065 131.808,355.137
#   "/>
# <polyline clip-path="url(#clip9600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   221.509,360.065 221.509,355.137
#   "/>
# <polyline clip-path="url(#clip9600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   311.211,360.065 311.211,355.137
#   "/>
# <polyline clip-path="url(#clip9600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   400.912,360.065 400.912,355.137
#   "/>
# <polyline clip-path="url(#clip9600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   490.614,360.065 490.614,355.137
#   "/>
# <polyline clip-path="url(#clip9600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   580.315,360.065 580.315,355.137
#   "/>
# <polyline clip-path="url(#clip9600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.1066,360.065 50.1797,360.065
#   "/>
# <polyline clip-path="url(#clip9600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.1066,291.613 50.1797,291.613
#   "/>
# <polyline clip-path="url(#clip9600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.1066,223.162 50.1797,223.162
#   "/>
# <polyline clip-path="url(#clip9600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.1066,154.71 50.1797,154.71
#   "/>
# <polyline clip-path="url(#clip9600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.1066,86.2576 50.1797,86.2576
#   "/>
# <g clip-path="url(#clip9600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 42.1066, 373.865)" x="42.1066" y="373.865">0</text>
# </g>
# <g clip-path="url(#clip9600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 131.808, 373.865)" x="131.808" y="373.865">30</text>
# </g>
# <g clip-path="url(#clip9600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 221.509, 373.865)" x="221.509" y="373.865">60</text>
# </g>
# <g clip-path="url(#clip9600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 311.211, 373.865)" x="311.211" y="373.865">90</text>
# </g>
# <g clip-path="url(#clip9600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 400.912, 373.865)" x="400.912" y="373.865">120</text>
# </g>
# <g clip-path="url(#clip9600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 490.614, 373.865)" x="490.614" y="373.865">150</text>
# </g>
# <g clip-path="url(#clip9600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 580.315, 373.865)" x="580.315" y="373.865">180</text>
# </g>
# <g clip-path="url(#clip9600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 36.1066, 364.565)" x="36.1066" y="364.565">0</text>
# </g>
# <g clip-path="url(#clip9600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 36.1066, 296.113)" x="36.1066" y="296.113">500</text>
# </g>
# <g clip-path="url(#clip9600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 36.1066, 227.662)" x="36.1066" y="227.662">1000</text>
# </g>
# <g clip-path="url(#clip9600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 36.1066, 159.21)" x="36.1066" y="159.21">1500</text>
# </g>
# <g clip-path="url(#clip9600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 36.1066, 90.7576)" x="36.1066" y="90.7576">2000</text>
# </g>
# <g clip-path="url(#clip9600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(0, 311.211, 18)" x="311.211" y="18">Polar angles of photons</text>
# </g>
# <g clip-path="url(#clip960

# %% [markdown]
# ### Charge particles spectrum
# Muon invariant masses, dalitz plot

# %%
function invariants(v1,v2,v3)
    masssq(v1+v2), masssq(v2+v3)
end
s1s2set = [invariants(
        tree[i,:G1]+tree[i,:G2],
        tree[i,:M1]+tree[i,:M2],
        tree[i,:G3]+tree[i,:G4]) for i=1:size(tree,1)]
histogram2d(
    [s1s2set[i][1] for i=1:length(s1s2set)],
    [s1s2set[i][2] for i=1:length(s1s2set)], bins=40,
    xlab="mJpsiPi", ylab="mJpsiPi", title="JpsiPiPi Dalitz plot")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip3200)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip3200)" points="
# 44.6753,360.065 520.315,360.065 520.315,31.4961 44.6753,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="44" y="31" width="477" height="330"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip3202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   139.803,360.065 139.803,31.4961
#   "/>
# <polyline clip-path="url(#clip3202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   258.713,360.065 258.713,31.4961
#   "/>
# <polyline clip-path="url(#clip3202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   377.623,360.065 377.623,31.4961
#   "/>
# <polyline clip-path="url(#clip3202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   496.533,360.065 496.533,31.4961
#   "/>
# <polyline clip-path="url(#clip3202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   44.6753,295.954 520.315,295.954
#   "/>
# <polyline clip-path="url(#clip3202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   44.6753,215.815 520.315,215.815
#   "/>
# <polyline clip-path="url(#clip3202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   44.6753,135.677 520.315,135.677
#   "/>
# <polyline clip-path="url(#clip3202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   44.6753,55.5377 520.315,55.5377
#   "/>
# <polyline clip-path="url(#clip3200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   44.6753,360.065 520.315,360.065
#   "/>
# <polyline clip-path="url(#clip3200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   44.6753,360.065 44.6753,31.4961
#   "/>
# <polyline clip-path="url(#clip3200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   139.803,360.065 139.803,355.137
#   "/>
# <polyline clip-path="url(#clip3200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   258.713,360.065 258.713,355.137
#   "/>
# <polyline clip-path="url(#clip3200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   377.623,360.065 377.623,355.137
#   "/>
# <polyline clip-path="url(#clip3200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   496.533,360.065 496.533,355.137
#   "/>
# <polyline clip-path="url(#clip3200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   44.6753,295.954 51.8099,295.954
#   "/>
# <polyline clip-path="url(#clip3200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   44.6753,215.815 51.8099,215.815
#   "/>
# <polyline clip-path="url(#clip3200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   44.6753,135.677 51.8099,135.677
#   "/>
# <polyline clip-path="url(#clip3200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   44.6753,55.5377 51.8099,55.5377
#   "/>
# <g clip-path="url(#clip3200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 139.803, 373.865)" x="139.803" y="373.865">12</text>
# </g>
# <g clip-path="url(#clip3200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 258.713, 373.865)" x="258.713" y="373.865">14</text>
# </g>
# <g clip-path="url(#clip3200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 377.623, 373.865)" x="377.623" y="373.865">16</text>
# </g>
# <g clip-path="url(#clip3200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 496.533, 373.865)" x="496.533" y="373.865">18</text>
# </g>
# <g clip-path="url(#clip3200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 38.6753, 300.454)" x="38.6753" y="300.454">12</text>
# </g>
# <g clip-path="url(#clip3200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 38.6753, 220.315)" x="38.6753" y="220.315">14</text>
# </g>
# <g clip-path="url(#clip3200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 38.6753, 140.177)" x="38.6753" y="140.177">16</text>
# </g>
# <g clip-path="url(#clip3200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 38.6753, 60.0377)" x="38.6753" y="60.0377">18</text>
# </g>
# <g clip-path="url(#clip3200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(0, 282.495, 18)" x="282.495" y="18">JpsiPiPi Dalitz plot</text>
# </g>
# <g clip-path="url(#clip3200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(0, 282.495, 397.6)" x="282.495" y="397.6">mJpsiPi</text>
# </g>
# <g clip-path="url(#clip3200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(-90, 14.4, 195.781)" x="14.4" y="195.781">mJpsiPi</text>
# </g>
# <g clip-path="url(#clip3202)">
# <image width="476" height="329" xlink:href="data:;base64,
# iVBORw0KGgoAAAANSUhEUgAAAdwAAAFJCAYAAAAxCJwFAAANnklEQVR4nO3dW5DWhX3G8VdYYWF3
# ccWVjVBxwyAURVEkiqYlikZj4imxYplU20ltMpMWJrVpp6dpOvaqnSQdD8nUKO0ImSSaaNOMjVUR
# JQ4aJ4p1wKIoRkEjrLIcdlkOEdObNr3odHx/Fh4W9vO5fvy7g+v7nf/Fj/eolpFdv2gUvLP/7aMq
# ewCg0RhxqH8AABgOBBcAAgQXAAIEFwACBBcAAgQXAAIEFwACBBcAAlqeOn9O6R9Y39td+osyPv38
# vaXnv/vugL9YA4AjjjdcAAgQXAAIEFwACBBcAAgQXAAIEFwACBBcAAg46rrxi0t3tXfe/1jpX7D0
# M+eU9je++qPSvn/Pi+52ARjyvOECQIDgAkCA4AJAgOACQIDgAkCA4AJAgOACQMBRI0a0l+5wf/ob
# M0r/gmMm9pb2P3ny7NL+8mefKu337NvobheAOG+4ABAguAAQILgAECC4ABAguAAQILgAECC4ABBQ
# vkm9tnNR6W73m1++o/T8n29qL+1X3P/R0n7h86tLe9+3C8CB4A0XAAIEFwACBBcAAgQXAAIEFwAC
# BBcAAgQXAALKN6YH+/tzW9t3lfarVs8u7WdM2lTaX77ymNL+5YEfuNsF4H/xhgsAAYILAAGCCwAB
# ggsAAYILAAGCCwABggsAAQf9ZnRq+xWlu91VC14uPX/0uNrd7v69o0r7qnOW1e6O3e0CDA/ecAEg
# QHABIEBwASBAcAEgQHABIEBwASBAcAEgYMjdgN427XOlu915H6zd7Y4ds7u077nuhdL+JzefV9r/
# 3jNjS/u1u+4Zcv/NAHhv3nABIEBwASBAcAEgQHABIEBwASBAcAEgQHABIGDI3XTObFtQusP9+5ml
# eWPaSa+W9ms2TC3tL7lpZWn/2h09pf1nHzqt6e2KwduH3H9fgOHKGy4ABAguAAQILgAECC4ABAgu
# AAQILgAECC4ABBz2d5rXdi4qHeIuWf1G6fmbb9xc2neM317aV/X3dTa9/e2HZpSevWpwyWH/+wAw
# VHnDBYAAwQWAAMEFgADBBYAAwQWAAMEFgADBBYCAYXd3+eS8y0p3u2d+7PHS89evnFPaT/vI0wft
# +d2T3iw9e/F9F5b2d2+/ddj9/gC8X95wASBAcAEgQHABIEBwASBAcAEgQHABIEBwASBg2N1Rto6a
# XLrD7fuzwdLzn3t0bmn/5s7mv9+20Wg0Tu95pelt9/RXS8/+8WMfLu3/cG3t12ftrnuG3e8bwH/z
# hgsAAYILAAGCCwABggsAAYILAAGCCwABggsAAe4i38Ol7Z8v3e3eedUTpee/s+/o0v7trcc1vT19
# 4WOlZ+95aXxpv+XFntJ+0fIzSvsHBr7u9xM4YnjDBYAAwQWAAMEFgADBBYAAwQWAAMEFgADBBYAA
# d44H2I0TF5fudv9o/o9Kz2/r2tb0tnXC9tKzWya/U9rf/NfXl/ZzJmwu7W/8947S/pnBpX6fgSHL
# Gy4ABAguAAQILgAECC4ABAguAAQILgAECC4ABLhbPMBGjGgv3eE+Ovejpefv29/S9PaUk18qPfs/
# Xjq5tN/7TvM/S6PRaJzQ2fwNcaPRaMz8eO1G+ca/u6G0/9qWW/z+AzHecAEgQH

# %%
histogram([
    vcat([tree[i,:G1][1]+tree[i,:G2][1] for i=1:size(tree,1)],
             [tree[i,:G3][1]+tree[i,:G4][1] for i=1:size(tree,1)]),
    [tree[i,:C1][1] for i=1:size(tree,1)]
          ],
    lab = ["Decay Pions energy", "Recoil Pions energy"],
    title = "Energy spectrum",
    xlab = "E, (GeV)", ylab = "Entries"
        )
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip4200)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip4200)" points="
# 57.8546,360.065 580.315,360.065 580.315,31.4961 57.8546,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="57" y="31" width="523" height="330"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip4202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   72.6412,360.065 72.6412,31.4961
#   "/>
# <polyline clip-path="url(#clip4202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   160.657,360.065 160.657,31.4961
#   "/>
# <polyline clip-path="url(#clip4202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   248.672,360.065 248.672,31.4961
#   "/>
# <polyline clip-path="url(#clip4202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   336.688,360.065 336.688,31.4961
#   "/>
# <polyline clip-path="url(#clip4202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   424.703,360.065 424.703,31.4961
#   "/>
# <polyline clip-path="url(#clip4202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   512.719,360.065 512.719,31.4961
#   "/>
# <polyline clip-path="url(#clip4202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   57.8546,360.065 580.315,360.065
#   "/>
# <polyline clip-path="url(#clip4202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   57.8546,266.775 580.315,266.775
#   "/>
# <polyline clip-path="url(#clip4202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   57.8546,173.484 580.315,173.484
#   "/>
# <polyline clip-path="url(#clip4202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   57.8546,80.1937 580.315,80.1937
#   "/>
# <polyline clip-path="url(#clip4200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   57.8546,360.065 580.315,360.065
#   "/>
# <polyline clip-path="url(#clip4200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   57.8546,360.065 57.8546,31.4961
#   "/>
# <polyline clip-path="url(#clip4200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   72.6412,360.065 72.6412,355.137
#   "/>
# <polyline clip-path="url(#clip4200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   160.657,360.065 160.657,355.137
#   "/>
# <polyline clip-path="url(#clip4200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   248.672,360.065 248.672,355.137
#   "/>
# <polyline clip-path="url(#clip4200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   336.688,360.065 336.688,355.137
#   "/>
# <polyline clip-path="url(#clip4200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   424.703,360.065 424.703,355.137
#   "/>
# <polyline clip-path="url(#clip4200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   512.719,360.065 512.719,355.137
#   "/>
# <polyline clip-path="url(#clip4200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   57.8546,360.065 65.6915,360.065
#   "/>
# <polyline clip-path="url(#clip4200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   57.8546,266.775 65.6915,266.775
#   "/>
# <polyline clip-path="url(#clip4200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   57.8546,173.484 65.6915,173.484
#   "/>
# <polyline clip-path="url(#clip4200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   57.8546,80.1937 65.6915,80.1937
#   "/>
# <g clip-path="url(#clip4200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 72.6412, 373.865)" x="72.6412" y="373.865">0</text>
# </g>
# <g clip-path="url(#clip4200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 160.657, 373.865)" x="160.657" y="373.865">1</text>
# </g>
# <g clip-path="url(#clip4200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 248.672, 373.865)" x="248.672" y="373.865">2</text>
# </g>
# <g clip-path="url(#clip4200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 336.688, 373.865)" x="336.688" y="373.865">3</text>
# </g>
# <g clip-path="url(#clip4200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 424.703, 373.865)" x="424.703" y="373.865">4</text>
# </g>
# <g clip-path="url(#clip4200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 512.719, 373.865)" x="512.719" y="373.865">5</text>
# </g>
# <g clip-path="url(#clip4200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 51.8546, 364.565)" x="51.8546" y="364.565">0</text>
# </g>
# <g clip-path="url(#clip4200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 51.8546, 271.275)" x="51.8546" y="271.275">500</text>
# </g>
# <g clip-path="url(#clip4200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 51.8546, 177.984)" x="51.8546" y="177.984">1000</text>
# </g>
# <g clip-path="url(#clip4200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 51.8546, 84.6937)" x="51.8546" y="84.6937">1500</text>
# </g>
# <g clip-path="url(#clip4200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(0, 319.085, 18)" x="319.085" y="18">Energy spectrum</text>
# </g>
# <g clip-path="url(#clip4200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(0, 319.085, 397.6)" x="319.085" y="397.6">E, (GeV)</text>
# </g>
# <g clip-path="url(#clip4200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(-90, 14.4, 195.781)" x="14.4" y="195.781">Entries</text>
# </g>
# <polygon clip-path="url(#clip4202)" points="
# 72.6412,295.508 72.6412,360.065 90.2443,360.065 90.2443,295.508 72.6412,295.508 72.6412,295.508
#   " fill="#009af9" fill-opacity="1"/>
# <polyline clip-path="url(#clip4202)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   72.6412,295.508 72.6412,360.065 90.2443,360.065 90.2443,295.508 72.6412,295.508
#   "/>
# <polygon clip-path="url(#clip4202)" points="
# 90.2443,41.3849 90.2443,360.065 107.847,360.065 107.847,41.3849 90.2443,41.3849 90.2443,41.3849
#   " fill="#009af9" fill-opacity="1"/>
# <polyline clip-path="url(#clip4202)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fil

# %% [markdown]
# # Second reaction $p\bar{p}\to\pi^0\pi^0 Z_c[\to J/\psi\pi^+\pi^-]$
#  * For simplicity, I consider $Z_c$ very narrow.
#  * Flat Dalitz plot for $Z_c\pi^0\pi^0$
#  * Flat Dalitz plot for $J/\psi\pi^-\pi^+$

# %%
const dPi0Pi0 = collect(linspace(4mπ2,(sqrt(s0)-mZc)^2,100))
fPi0Pi0 = [fρ(s,mπ2,mπ2,mZc^2,s0) for s in 0.5*(dPi0Pi0[1:end-1]+dPi0Pi0[2:end])]; fPi0Pi0 /= sum(fPi0Pi0)
[fPi0Pi0[i] = fPi0Pi0[i-1]+fPi0Pi0[i] for i in 2:length(fPi0Pi0)];
const cPi0Pi0 = fPi0Pi0;

# %%
# X disctribution
function randPi0Pi0()
    bi = searchsortedlast(cPi0Pi0, rand())+1
    return dPi0Pi0[bi] + rand()*(dPi0Pi0[bi+1]-dPi0Pi0[bi])
end
# Out:
# randPi0Pi0 (generic function with 1 method)

# %%
function generateR2()
    p0 = [e0,0,0,sqrt(e0^2-mp2)] + [mp,0,0,0];
    # generate variables
    sPi0Pi0 = randPi0Pi0();
    pZc,pπ0π0 = decay2two(p0,mZc^2,sPi0Pi0)
    pπ01,pπ02 = decay2two(pπ0π0,mπ2,mπ2)
    # pi0 decays
    pγ1,pγ2 = decay2two(pπ01,0,0)
    pγ3,pγ4 = decay2two(pπ02,0,0)
    # Z to Jpsi pi pi
    sPiPi = randX();
    pPiPi,pJpsi = decay2two(pZc,sPiPi,mJpsi^2)
    pπ1,pπ2 = decay2two(pPiPi,mπ2,mπ2)
    # Jpsi decay
    pμ1,pμ2 = decay2two(pJpsi,mμ2,mμ2)
    pμ1,pμ2,pπ1,pπ2,pγ1,pγ2,pγ3,pγ4
end
# Out:
# generateR2 (generic function with 1 method)

# %%
generateR2()
# Out:
# ([7.5821, 1.06226, -0.513987, 7.48897], [1.92668, -1.07014, 0.548682, 1.50161], [0.915623, -0.169529, -0.558858, 0.691362], [1.39427, 0.254679, 0.484626, 1.27473], [0.47455, -0.0582772, 0.0480578, 0.468499], [0.350073, -0.152338, -0.00156798, 0.315185], [0.0275085, -0.00377319, -0.0266783, -0.00554519], [0.267189, 0.137125, 0.0197255, 0.228468])

# %%
Nev = 10000
# data storage
treeR2 = DataFrame(
    [Array{Float64,1} for i in 1:8],
    [:M1, :M2, :C1, :C2, :G1, :G2, :G3, :G4],
    Nev);
# fill with events
for i in 1:Nev
    treeR2[i,:M1],treeR2[i,:M2],treeR2[i,:C1],treeR2[i,:C2],
        treeR2[i,:G1],treeR2[i,:G2],treeR2[i,:G3],treeR2[i,:G4] = generateR2();
end

# %%
histogram(vcat(
    [treeR2[i,:G1][1] for i=1:size(treeR2,1)],
    [treeR2[i,:G2][1] for i=1:size(treeR2,1)],
    [treeR2[i,:G3][1] for i=1:size(treeR2,1)],
    [treeR2[i,:G4][1] for i=1:size(treeR2,1)]), bins=100,
    lab = "", title = "Energy spectrum of photons", xlab = "Eg (GeV)")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip6600)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip6600)" points="
# 42.1066,360.065 580.315,360.065 580.315,31.4961 42.1066,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="42" y="31" width="539" height="330"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip6602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   57.3389,360.065 57.3389,31.4961
#   "/>
# <polyline clip-path="url(#clip6602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   212.139,360.065 212.139,31.4961
#   "/>
# <polyline clip-path="url(#clip6602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   366.939,360.065 366.939,31.4961
#   "/>
# <polyline clip-path="url(#clip6602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   521.739,360.065 521.739,31.4961
#   "/>
# <polyline clip-path="url(#clip6602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   42.1066,360.065 580.315,360.065
#   "/>
# <polyline clip-path="url(#clip6602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   42.1066,275.339 580.315,275.339
#   "/>
# <polyline clip-path="url(#clip6602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   42.1066,190.612 580.315,190.612
#   "/>
# <polyline clip-path="url(#clip6602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   42.1066,105.886 580.315,105.886
#   "/>
# <polyline clip-path="url(#clip6600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.1066,360.065 580.315,360.065
#   "/>
# <polyline clip-path="url(#clip6600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.1066,360.065 42.1066,31.4961
#   "/>
# <polyline clip-path="url(#clip6600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   57.3389,360.065 57.3389,355.137
#   "/>
# <polyline clip-path="url(#clip6600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   212.139,360.065 212.139,355.137
#   "/>
# <polyline clip-path="url(#clip6600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   366.939,360.065 366.939,355.137
#   "/>
# <polyline clip-path="url(#clip6600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   521.739,360.065 521.739,355.137
#   "/>
# <polyline clip-path="url(#clip6600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.1066,360.065 50.1797,360.065
#   "/>
# <polyline clip-path="url(#clip6600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.1066,275.339 50.1797,275.339
#   "/>
# <polyline clip-path="url(#clip6600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.1066,190.612 50.1797,190.612
#   "/>
# <polyline clip-path="url(#clip6600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.1066,105.886 50.1797,105.886
#   "/>
# <g clip-path="url(#clip6600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 57.3389, 373.865)" x="57.3389" y="373.865">0.0</text>
# </g>
# <g clip-path="url(#clip6600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 212.139, 373.865)" x="212.139" y="373.865">0.5</text>
# </g>
# <g clip-path="url(#clip6600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 366.939, 373.865)" x="366.939" y="373.865">1.0</text>
# </g>
# <g clip-path="url(#clip6600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 521.739, 373.865)" x="521.739" y="373.865">1.5</text>
# </g>
# <g clip-path="url(#clip6600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 36.1066, 364.565)" x="36.1066" y="364.565">0</text>
# </g>
# <g clip-path="url(#clip6600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 36.1066, 279.839)" x="36.1066" y="279.839">500</text>
# </g>
# <g clip-path="url(#clip6600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 36.1066, 195.112)" x="36.1066" y="195.112">1000</text>
# </g>
# <g clip-path="url(#clip6600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 36.1066, 110.386)" x="36.1066" y="110.386">1500</text>
# </g>
# <g clip-path="url(#clip6600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(0, 311.211, 18)" x="311.211" y="18">Energy spectrum of photons</text>
# </g>
# <g clip-path="url(#clip6600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(0, 311.211, 397.6)" x="311.211" y="397.6">Eg (GeV)</text>
# </g>
# <polygon clip-path="url(#clip6602)" points="
# 57.3389,257.716 57.3389,360.065 63.5309,360.065 63.5309,257.716 57.3389,257.716 57.3389,257.716
#   " fill="#009af9" fill-opacity="1"/>
# <polyline clip-path="url(#clip6602)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   57.3389,257.716 57.3389,360.065 63.5309,360.065 63.5309,257.716 57.3389,257.716
#   "/>
# <polygon clip-path="url(#clip6602)" points="
# 63.5309,83.3487 63.5309,360.065 69.7229,360.065 69.7229,83.3487 63.5309,83.3487 63.5309,83.3487
#   " fill="#009af9" fill-opacity="1"/>
# <polyline clip-path="url(#clip6602)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   63.5309,83.3487 63.5309,360.065 69.7229,360.065 69.7229,83.3487 63.5309,83.3487
#   "/>
# <polygon clip-path="url(#clip6602)" points="
# 69.7229,50.8137 69.7229,360.065 75.9149,360.065 75.9149,50.8137 69.7229,50.8137 69.7229,50.8137
#   " fill="#009af9" fill-opacity="1"/>
# <polyline clip-path="url(#clip6602)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   69.7229,50.8137 69.7229,360.065 75.9149,360.065 75.9149,50.8137 69.7229,50.8137
#   "/>
# <polygon clip-path="url(#clip6602)" points="
# 75.9149,39.2909 75.9149,360.065 82.1069,360.065 82.1069,39.2909 75.9149,39.2909 75.9149,39.2909
#   " fill="#009af9" fill-opacity="1"/>
# <polyline clip-path="url(#clip6602)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   75.9149,39.2909 75.9149,360.065 82.1069,360.065 82.1069,39.2909 75.9149,39.2909
#   "/>
# <polygon clip-path="url(#clip6602)" points="
# 82.1069,31.4961 82.1069,360.065 88.2989,360.065 88.2989,31.4961 82.1069,31.4961 82.1069,31.4961
#   " fill="#009af9" fill-opacity="1"/>
# <polyline clip-path="url(#clip6602)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   82.1069,31.4961 82.1069,360.065 88.2989,360.065 88.2989,31.4961 82.1069,31.4961
#   "/>
# <polygon clip-path="url(#clip6602)" points="
# 88.2989,43.1883 88.2989,360.065 94.49

# %%
polAngle(v) = 180/π*acos(v[4]/v[1])
histogram(vcat(
    [polAngle(treeR2[i,:G1]) for i=1:size(treeR2,1)],
    [polAngle(treeR2[i,:G2]) for i=1:size(treeR2,1)],
    [polAngle(treeR2[i,:G3]) for i=1:size(treeR2,1)],
    [polAngle(treeR2[i,:G4]) for i=1:size(treeR2,1)]), bins=100,
    xlim = (0,180),
    lab = "", title = "Polar angles of photons", xlab = "theta (deg.)")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip9200)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip9200)" points="
# 42.1066,360.065 580.315,360.065 580.315,31.4961 42.1066,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="42" y="31" width="539" height="330"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip9202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   42.1066,360.065 42.1066,31.4961
#   "/>
# <polyline clip-path="url(#clip9202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   131.808,360.065 131.808,31.4961
#   "/>
# <polyline clip-path="url(#clip9202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   221.509,360.065 221.509,31.4961
#   "/>
# <polyline clip-path="url(#clip9202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   311.211,360.065 311.211,31.4961
#   "/>
# <polyline clip-path="url(#clip9202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   400.912,360.065 400.912,31.4961
#   "/>
# <polyline clip-path="url(#clip9202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   490.614,360.065 490.614,31.4961
#   "/>
# <polyline clip-path="url(#clip9202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   580.315,360.065 580.315,31.4961
#   "/>
# <polyline clip-path="url(#clip9202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   42.1066,360.065 580.315,360.065
#   "/>
# <polyline clip-path="url(#clip9202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   42.1066,290.951 580.315,290.951
#   "/>
# <polyline clip-path="url(#clip9202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   42.1066,221.837 580.315,221.837
#   "/>
# <polyline clip-path="url(#clip9202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   42.1066,152.723 580.315,152.723
#   "/>
# <polyline clip-path="url(#clip9202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   42.1066,83.6082 580.315,83.6082
#   "/>
# <polyline clip-path="url(#clip9200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.1066,360.065 580.315,360.065
#   "/>
# <polyline clip-path="url(#clip9200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.1066,360.065 42.1066,31.4961
#   "/>
# <polyline clip-path="url(#clip9200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.1066,360.065 42.1066,355.137
#   "/>
# <polyline clip-path="url(#clip9200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   131.808,360.065 131.808,355.137
#   "/>
# <polyline clip-path="url(#clip9200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   221.509,360.065 221.509,355.137
#   "/>
# <polyline clip-path="url(#clip9200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   311.211,360.065 311.211,355.137
#   "/>
# <polyline clip-path="url(#clip9200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   400.912,360.065 400.912,355.137
#   "/>
# <polyline clip-path="url(#clip9200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   490.614,360.065 490.614,355.137
#   "/>
# <polyline clip-path="url(#clip9200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   580.315,360.065 580.315,355.137
#   "/>
# <polyline clip-path="url(#clip9200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.1066,360.065 50.1797,360.065
#   "/>
# <polyline clip-path="url(#clip9200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.1066,290.951 50.1797,290.951
#   "/>
# <polyline clip-path="url(#clip9200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.1066,221.837 50.1797,221.837
#   "/>
# <polyline clip-path="url(#clip9200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.1066,152.723 50.1797,152.723
#   "/>
# <polyline clip-path="url(#clip9200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.1066,83.6082 50.1797,83.6082
#   "/>
# <g clip-path="url(#clip9200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 42.1066, 373.865)" x="42.1066" y="373.865">0</text>
# </g>
# <g clip-path="url(#clip9200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 131.808, 373.865)" x="131.808" y="373.865">30</text>
# </g>
# <g clip-path="url(#clip9200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 221.509, 373.865)" x="221.509" y="373.865">60</text>
# </g>
# <g clip-path="url(#clip9200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 311.211, 373.865)" x="311.211" y="373.865">90</text>
# </g>
# <g clip-path="url(#clip9200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 400.912, 373.865)" x="400.912" y="373.865">120</text>
# </g>
# <g clip-path="url(#clip9200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 490.614, 373.865)" x="490.614" y="373.865">150</text>
# </g>
# <g clip-path="url(#clip9200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 580.315, 373.865)" x="580.315" y="373.865">180</text>
# </g>
# <g clip-path="url(#clip9200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 36.1066, 364.565)" x="36.1066" y="364.565">0</text>
# </g>
# <g clip-path="url(#clip9200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 36.1066, 295.451)" x="36.1066" y="295.451">500</text>
# </g>
# <g clip-path="url(#clip9200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 36.1066, 226.337)" x="36.1066" y="226.337">1000</text>
# </g>
# <g clip-path="url(#clip9200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 36.1066, 157.223)" x="36.1066" y="157.223">1500</text>
# </g>
# <g clip-path="url(#clip9200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 36.1066, 88.1082)" x="36.1066" y="88.1082">2000</text>
# </g>
# <g clip-path="url(#clip9200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(0, 311.211, 18)" x="311.211" y="18">Polar angles of photons</text>
# </g>
# <g clip-path="url(#c

# %%
s1s2set = [invariants(
        treeR2[i,:C1],
        treeR2[i,:M1]+treeR2[i,:M2],
        treeR2[i,:C2]) for i=1:size(treeR2,1)]
histogram2d(
    [s1s2set[i][1] for i=1:length(s1s2set)],
    [s1s2set[i][2] for i=1:length(s1s2set)], bins=40,
    xlab="mJpsiPi", ylab="mJpsiPi", title="JpsiPiPi Dalitz plot")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip7200)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip7200)" points="
# 44.6753,360.065 520.315,360.065 520.315,31.4961 44.6753,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="44" y="31" width="477" height="330"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip7202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   137.483,360.065 137.483,31.4961
#   "/>
# <polyline clip-path="url(#clip7202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   253.493,360.065 253.493,31.4961
#   "/>
# <polyline clip-path="url(#clip7202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   369.502,360.065 369.502,31.4961
#   "/>
# <polyline clip-path="url(#clip7202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   485.512,360.065 485.512,31.4961
#   "/>
# <polyline clip-path="url(#clip7202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   44.6753,294.352 520.315,294.352
#   "/>
# <polyline clip-path="url(#clip7202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   44.6753,212.209 520.315,212.209
#   "/>
# <polyline clip-path="url(#clip7202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   44.6753,130.067 520.315,130.067
#   "/>
# <polyline clip-path="url(#clip7202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   44.6753,47.9245 520.315,47.9245
#   "/>
# <polyline clip-path="url(#clip7200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   44.6753,360.065 520.315,360.065
#   "/>
# <polyline clip-path="url(#clip7200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   44.6753,360.065 44.6753,31.4961
#   "/>
# <polyline clip-path="url(#clip7200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   137.483,360.065 137.483,355.137
#   "/>
# <polyline clip-path="url(#clip7200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   253.493,360.065 253.493,355.137
#   "/>
# <polyline clip-path="url(#clip7200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   369.502,360.065 369.502,355.137
#   "/>
# <polyline clip-path="url(#clip7200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   485.512,360.065 485.512,355.137
#   "/>
# <polyline clip-path="url(#clip7200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   44.6753,294.352 51.8099,294.352
#   "/>
# <polyline clip-path="url(#clip7200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   44.6753,212.209 51.8099,212.209
#   "/>
# <polyline clip-path="url(#clip7200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   44.6753,130.067 51.8099,130.067
#   "/>
# <polyline clip-path="url(#clip7200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   44.6753,47.9245 51.8099,47.9245
#   "/>
# <g clip-path="url(#clip7200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 137.483, 373.865)" x="137.483" y="373.865">12</text>
# </g>
# <g clip-path="url(#clip7200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 253.493, 373.865)" x="253.493" y="373.865">14</text>
# </g>
# <g clip-path="url(#clip7200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 369.502, 373.865)" x="369.502" y="373.865">16</text>
# </g>
# <g clip-path="url(#clip7200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 485.512, 373.865)" x="485.512" y="373.865">18</text>
# </g>
# <g clip-path="url(#clip7200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 38.6753, 298.852)" x="38.6753" y="298.852">12</text>
# </g>
# <g clip-path="url(#clip7200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 38.6753, 216.709)" x="38.6753" y="216.709">14</text>
# </g>
# <g clip-path="url(#clip7200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 38.6753, 134.567)" x="38.6753" y="134.567">16</text>
# </g>
# <g clip-path="url(#clip7200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 38.6753, 52.4245)" x="38.6753" y="52.4245">18</text>
# </g>
# <g clip-path="url(#clip7200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(0, 282.495, 18)" x="282.495" y="18">JpsiPiPi Dalitz plot</text>
# </g>
# <g clip-path="url(#clip7200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(0, 282.495, 397.6)" x="282.495" y="397.6">mJpsiPi</text>
# </g>
# <g clip-path="url(#clip7200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(-90, 14.4, 195.781)" x="14.4" y="195.781">mJpsiPi</text>
# </g>
# <g clip-path="url(#clip7202)">
# <image width="476" height="329" xlink:href="data:;base64,
# iVBORw0KGgoAAAANSUhEUgAAAdwAAAFJCAYAAAAxCJwFAAANy0lEQVR4nO3da5DQdbnA8T/L7rK7
# LlcJ1luAGixuYEJ4ycIJi05qeUFFp1aZKSUd8nSm2znjmzqeZk7nHEdFjuWhOkeZUrDMmqKxsnTo
# IhWYMgYoF0VEwAsX94Isl942TZ1+T8LDLvv5vH58/A8u+/X34vf/D/jRtNkHq4DdbwyKjFezn7p3
# QOgfAICjUM2RfgAA6A8EFwASCC4AJBBcAEgguACQQHABIIHgAkACwQWABANmNM0NvfjiR1/8Zuhf
# MPC48vX118TekXHgQIeXagDQJzjhAkACwQWABIILAAkEFwASCC4AJBBcAEgguACQIHyP9Xfv/WDo
# 3m7bHV3Fs898pi70LO9Z9lJofnf30+7tAnBEOOECQALBBYAEggsACQQXABIILgAkEFwASCC4AJAg
# fC/1siHzQvdwb/vg8uLZl7ePDD1L24zHQ/MjbhlaPNu99zl3dgE4ZJxwASCB4AJAAsEFgASCCwAJ
# BBcAEgguACQQXABI8HfcNa0N3cN9fvYZxbMt71wdepINj04NzXd2NRXP/sPyV0K7X+n6rXu7APxV
# TrgAkEBwASCB4AJAAsEFgASCCwAJBBcAEgguACQQXABIcNhf1jClqb34RRn/dXpnaHfrqetD88M/
# O6x4tubhFaHdE784vXh2Q8dSL8kA6GeccAEggeACQALBBYAEggsACQQXABIILgAkEFwASFB7uP8F
# K7sWFd85fWPf7NDH7Ud9YF3oWbqHX1w8O2jaS6HdS6aVP/r1y8vvJldV7M8QgN7JCRcAEgguACQQ
# XABIILgAkEBwASCB4AJAAsEFgAS96n5nXe2o0P3UHZ+PPX7dsPLv7e5ae1Jod8PQjuLZHZtbQrvP
# +WFTaH5Lx2O96r8rAE64AJBCcAEggeACQALBBYAEggsACQQXABIILgAk6NP3NS9ovjF0b/drl/6y
# eHb4+E2hZ6lp6CmeXbX0PaHd75i3PDT/4WuvKp5d2nFXn/4ZAOgrnHABIIHgAkACwQWABIILAAkE
# FwASCC4AJBBcAEgguACQoF+99GD1hecVvyjjqRfGhHa/f3r5SzWGnL01tLtqHBQaf25Ra/Hsh35y
# fGj36s5v96ufGYBDxQkXABIILgAkEFwASCC4AJBAcAEggeACQALBBYAE/epOZU1Nc/E93FduHB3a
# vW3jicWze3vqQrvr68o/bl9VVTX27KeKZ59ZNjW0++urTiuenf/S/H718wXw/3HCBYAEggsACQQX
# ABIILgAkEFwASCC4AJBAcAEggXuSf8UFzTcW39mtqqr63m3fKJ49+La3hp5lwLObQvP7tjYWz77+
# fEtod9Po14pnr7nzitDuB3cv8PMIHLWccAEggeACQALBBYAEggsACQQXABIILgAkEFwASODe4yGy
# ePI1xfd2Z33uO6Hd2x8+NTTf9foxxbMnLL4qtLvuB18ont2zMvbd3+m3zQzNr+xa5OcX6DOccAEg
# geACQALBBYAEggsACQQXABIILgAkEFwASOAe4xGw7pJ3hb61O+qUF0L7N66aUDzbekv5922rqqo2
# /Ovg4tkTv3pCaPfB25eF5j/5f5cWz97z6nw/68AR5YQLAAkEFwASCC4AJBBcAE

# %%
s1s2set = [invariants(
        treeR2[i,:M1]+treeR2[i,:M2]+treeR2[i,:C1]+treeR2[i,:C2],
        treeR2[i,:G1]+treeR2[i,:G2],
        treeR2[i,:G3]+treeR2[i,:G4],) for i=1:size(treeR2,1)]
histogram2d(
    [s1s2set[i][1] for i=1:length(s1s2set)],
    [s1s2set[i][2] for i=1:length(s1s2set)], bins=40,
    xlab="ZcPi (GeV)", ylab="PiPi (GeV)", title="ZcPiPi Dalitz plot")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip8000)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip8000)" points="
# 54.5598,360.065 520.315,360.065 520.315,31.4961 54.5598,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="54" y="31" width="467" height="330"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip8002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   87.828,360.065 87.828,31.4961
#   "/>
# <polyline clip-path="url(#clip8002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   198.722,360.065 198.722,31.4961
#   "/>
# <polyline clip-path="url(#clip8002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   309.616,360.065 309.616,31.4961
#   "/>
# <polyline clip-path="url(#clip8002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   420.51,360.065 420.51,31.4961
#   "/>
# <polyline clip-path="url(#clip8002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   54.5598,313.127 520.315,313.127
#   "/>
# <polyline clip-path="url(#clip8002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   54.5598,219.25 520.315,219.25
#   "/>
# <polyline clip-path="url(#clip8002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   54.5598,125.373 520.315,125.373
#   "/>
# <polyline clip-path="url(#clip8002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   54.5598,31.4961 520.315,31.4961
#   "/>
# <polyline clip-path="url(#clip8000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   54.5598,360.065 520.315,360.065
#   "/>
# <polyline clip-path="url(#clip8000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   54.5598,360.065 54.5598,31.4961
#   "/>
# <polyline clip-path="url(#clip8000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   87.828,360.065 87.828,355.137
#   "/>
# <polyline clip-path="url(#clip8000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   198.722,360.065 198.722,355.137
#   "/>
# <polyline clip-path="url(#clip8000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   309.616,360.065 309.616,355.137
#   "/>
# <polyline clip-path="url(#clip8000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   420.51,360.065 420.51,355.137
#   "/>
# <polyline clip-path="url(#clip8000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   54.5598,313.127 61.5461,313.127
#   "/>
# <polyline clip-path="url(#clip8000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   54.5598,219.25 61.5461,219.25
#   "/>
# <polyline clip-path="url(#clip8000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   54.5598,125.373 61.5461,125.373
#   "/>
# <polyline clip-path="url(#clip8000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   54.5598,31.4961 61.5461,31.4961
#   "/>
# <g clip-path="url(#clip8000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 87.828, 373.865)" x="87.828" y="373.865">21.0</text>
# </g>
# <g clip-path="url(#clip8000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 198.722, 373.865)" x="198.722" y="373.865">21.5</text>
# </g>
# <g clip-path="url(#clip8000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 309.616, 373.865)" x="309.616" y="373.865">22.0</text>
# </g>
# <g clip-path="url(#clip8000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 420.51, 373.865)" x="420.51" y="373.865">22.5</text>
# </g>
# <g clip-path="url(#clip8000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 48.5598, 317.627)" x="48.5598" y="317.627">0.10</text>
# </g>
# <g clip-path="url(#clip8000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 48.5598, 223.75)" x="48.5598" y="223.75">0.15</text>
# </g>
# <g clip-path="url(#clip8000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 48.5598, 129.873)" x="48.5598" y="129.873">0.20</text>
# </g>
# <g clip-path="url(#clip8000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 48.5598, 35.9961)" x="48.5598" y="35.9961">0.25</text>
# </g>
# <g clip-path="url(#clip8000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(0, 287.437, 18)" x="287.437" y="18">ZcPiPi Dalitz plot</text>
# </g>
# <g clip-path="url(#clip8000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(0, 287.437, 397.6)" x="287.437" y="397.6">ZcPi (GeV)</text>
# </g>
# <g clip-path="url(#clip8000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(-90, 14.4, 195.781)" x="14.4" y="195.781">PiPi (GeV)</text>
# </g>
# <g clip-path="url(#clip8002)">
# <image width="466" height="329" xlink:href="data:;base64,
# iVBORw0KGgoAAAANSUhEUgAAAdIAAAFJCAYAAAAvway2AAAZJklEQVR4nO3db2yV93nG8ZuGPzYG
# Dg4+tgUuNUmA2idA6qCW0sR4KCmCtLK6QUuyiJIpRLVVlqC1jRoxqqRdUNdMLH+E2xB1DJEsjYk2
# KwsINUqMSWlagRNCjx0gBOMaZHxMjDHGxiFjL9oX+yOt151bTwrd9/P64tHjc55zLp0Xv4tRBuD/
# MPqymrz72nr5qtvf3yxnSyd8Xs6amfWPdMrZoZETo1wXB/C/fOKPfQMAAFzNKFIAAAIoUgAAAihS
# AAACKFIAAAIoUgAAAihSAAACKFIAAAIoUgAAAlg1wccqf+yn5KWg6jHL5OtuWtQuZ5vaK+Vstn+0
# nE3nyVFr6/9Azq6YrmfNzCqKeuRs7+BEObvhHfmtsyOXfiFnWVfC1Y5fpAAABFCkAAAEUKQAAARQ
# pAAABFCkAAAEUKQAAARQpAAABFCkAAAE6KfN8f/MaPn0/bqp9YncQU3pGTl7Z/NUObv55i45W1mo
# DxYUFQzIWc8QwqLq1+WsmVn2wDw529aXkrNz8vSvi51LC+VsR+c8+Vm77VcH5esy9ICPC79IAQAI
# oEgBAAigSAEACKBIAQAIoEgBAAigSAEACKBIAQAIoEgBAAigSAEACGDZ6CpWOuFWeRHGzOy2sZ+R
# s5nUJTlbWagvEDV2TJGzuaF8OTsnb7ycbemaLGfTeSNydmbpSTnr8bUty1z5pvXPytnCvVVytnlP
# hZwtSPfJ2Ywj+41jtXI2N2zy5+OVkTfl63af38tiEv4bfpECABBAkQIAEECRAgAQQJECABBAkQIA
# EECRAgAQQJECABBAkQIAEMDB4ivOaPkQeduyW1xXPto9Tc629aXk7Lr7tsvZAztr5GxDtlzOetRl
# OuRsS1eZnH3+9Fk5+8in9Y9eUcGAnDUza+8tlrMVRT1ydsexcjmbG5aj9uL5Jjm7Ydodcra6rEvO
# et7nx3OH5Gz3+V/K2d+5xHfyVYhfpAAABFCkAAAEUKQAAARQpAAABFCkAAAEUKQAAARQpAAABFCk
# AAAEcPj3Y7CkoE4eWfBIjxvjyq8oPyNnc0P5cjbbP951H6pM6kIi9+C5bjp/SM5uPjxJzm6oOiln
# vR5p1Yc3Vkz/QM42durPm+fvK5/eKWcfe61azialplT/HHmeCTOz3YNbHGnGG64U/CIFACCAIgUA
# IIAiBQAggCIFACCAIgUAIIAiBQAggCIFACCAIgUAIIAiBQAggGWMjyh/7KfktaLnb7xFvm5z9xQ5
# u3HtVjlrZnZgZ42cbe8tdl1blRseK2ez/aMTuYd0np7NDSdz3eJxlxzXHdEvbGbLl/xczg7mCl3X
# Vu1qnS9nPc+E57XwLDHVFOtfhbUVbXK2qb1Sznp99/hmvr+vEPwiBQAggCIFACCAIgUAIIAiBQAg
# gCIFACCAIgUAIIAiBQAggCIFACCAA73/RVIjC219KTnb3CPfglWm9APnXpnUBTm7tGq/nE3qoH5S
# h+R7LuqjEMuv75CzLV1lctY7TPHDpS1y9sFd1XL2qVVNcvbUkRly9mj3NDnr0dihj5vUlOjPe/Pp
# 8XI2k9KHN8x8gxPZfv0+Np3a7LiLS/SCE79IAQAIoEgBAAigSAEACKBIAQAI

# %%
histogram((
    [treeR2[i,:C1][1] for i=1:size(treeR2,1)],
    [treeR2[i,:C2][1] for i=1:size(treeR2,1)]), bins=100,
    lab = "", title = "Energy spectrum of change pions", xlab = "E (GeV)")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip0000)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip0000)" points="
# 35.5169,360.065 580.315,360.065 580.315,31.4961 35.5169,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="35" y="31" width="546" height="330"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip0002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   40.9559,360.065 40.9559,31.4961
#   "/>
# <polyline clip-path="url(#clip0002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   140.754,360.065 140.754,31.4961
#   "/>
# <polyline clip-path="url(#clip0002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   240.552,360.065 240.552,31.4961
#   "/>
# <polyline clip-path="url(#clip0002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   340.35,360.065 340.35,31.4961
#   "/>
# <polyline clip-path="url(#clip0002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   440.148,360.065 440.148,31.4961
#   "/>
# <polyline clip-path="url(#clip0002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   539.947,360.065 539.947,31.4961
#   "/>
# <polyline clip-path="url(#clip0002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   35.5169,360.065 580.315,360.065
#   "/>
# <polyline clip-path="url(#clip0002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   35.5169,293.01 580.315,293.01
#   "/>
# <polyline clip-path="url(#clip0002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   35.5169,225.955 580.315,225.955
#   "/>
# <polyline clip-path="url(#clip0002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   35.5169,158.901 580.315,158.901
#   "/>
# <polyline clip-path="url(#clip0002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   35.5169,91.8455 580.315,91.8455
#   "/>
# <polyline clip-path="url(#clip0000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.5169,360.065 580.315,360.065
#   "/>
# <polyline clip-path="url(#clip0000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.5169,360.065 35.5169,31.4961
#   "/>
# <polyline clip-path="url(#clip0000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   40.9559,360.065 40.9559,355.137
#   "/>
# <polyline clip-path="url(#clip0000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   140.754,360.065 140.754,355.137
#   "/>
# <polyline clip-path="url(#clip0000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   240.552,360.065 240.552,355.137
#   "/>
# <polyline clip-path="url(#clip0000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   340.35,360.065 340.35,355.137
#   "/>
# <polyline clip-path="url(#clip0000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   440.148,360.065 440.148,355.137
#   "/>
# <polyline clip-path="url(#clip0000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   539.947,360.065 539.947,355.137
#   "/>
# <polyline clip-path="url(#clip0000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.5169,360.065 43.6889,360.065
#   "/>
# <polyline clip-path="url(#clip0000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.5169,293.01 43.6889,293.01
#   "/>
# <polyline clip-path="url(#clip0000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.5169,225.955 43.6889,225.955
#   "/>
# <polyline clip-path="url(#clip0000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.5169,158.901 43.6889,158.901
#   "/>
# <polyline clip-path="url(#clip0000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.5169,91.8455 43.6889,91.8455
#   "/>
# <g clip-path="url(#clip0000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 40.9559, 373.865)" x="40.9559" y="373.865">0</text>
# </g>
# <g clip-path="url(#clip0000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 140.754, 373.865)" x="140.754" y="373.865">1</text>
# </g>
# <g clip-path="url(#clip0000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 240.552, 373.865)" x="240.552" y="373.865">2</text>
# </g>
# <g clip-path="url(#clip0000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 340.35, 373.865)" x="340.35" y="373.865">3</text>
# </g>
# <g clip-path="url(#clip0000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 440.148, 373.865)" x="440.148" y="373.865">4</text>
# </g>
# <g clip-path="url(#clip0000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 539.947, 373.865)" x="539.947" y="373.865">5</text>
# </g>
# <g clip-path="url(#clip0000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.5169, 364.565)" x="29.5169" y="364.565">0</text>
# </g>
# <g clip-path="url(#clip0000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.5169, 297.51)" x="29.5169" y="297.51">50</text>
# </g>
# <g clip-path="url(#clip0000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.5169, 230.455)" x="29.5169" y="230.455">100</text>
# </g>
# <g clip-path="url(#clip0000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.5169, 163.401)" x="29.5169" y="163.401">150</text>
# </g>
# <g clip-path="url(#clip0000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.5169, 96.3455)" x="29.5169" y="96.3455">200</text>
# </g>
# <g clip-path="url(#clip0000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(0, 307.916, 18)" x="307.916" y="18">Energy spectrum of change pions</text>
# </g>
# <g clip-path="url(#clip0000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(0, 307.916, 397.6)" x="307.916" y="397.6">E (GeV)</text>
# </g>
# <polygon clip-path="url(#clip0002)" points="
# 50.9357,331.902 50.9357,360.065 55.9256,360.065 55.9256,331.902 50.9357,331.902 50.9357,331.902
#   " fill="#009af9" fill-opacity="1"/>
# <polyline clip-path="url(#clip0002)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   50.9357,331.902 50.9357,360.065 55.9256,360.065 55.92
