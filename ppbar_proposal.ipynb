# %% [markdown]
# # Exercise with $p\bar{p}$-reacion
#
# WASA-at-COSY calorimeter
# ![calorimeter](ppbar/calorimeter.png)
# WASA-at-COSY calorimeter
# ![Angular](ppbar/angular_covarage.png)
# Other characteristics
# ![characteristics](ppbar/characteristics.png)

# %% [markdown]
# ## Phase space simulations for the reaction  $p\bar{p}\to Z_c^+[\to J/\psi\pi^+\pi^0]\, \pi^-$
#  * For simplicity, I consider $Z_c$ very narrow.
#  * Flat Dalitz plot for $J/\psi\pi^0\pi^0$

# %%
function boost!(v,γ)
    β=sqrt(1-1/γ^2)
    v[1],v[4] = v[1]*γ+v[4]*β*γ, v[1]*β*γ+v[4]*γ
end

function rotateY!(v,cosθ)
    sinθ = sqrt(1-cosθ*cosθ)
    v[2],v[4] = v[2]*cosθ+v[4]*sinθ, -v[2]*sinθ+v[4]*cosθ
end

function rotateZ!(v,ϕ)
    v[2],v[3] = v[2]*cos(ϕ)-v[3]*sin(ϕ), v[3]*cos(ϕ)+v[2]*sin(ϕ)
end

λ(x,y,z) = x^2+y^2+z^2-2*x*y-2*y*z-2*z*x

function decay2two(v0,m1sq,m2sq)
    cosθ = 2*rand()-1;
    decay2two(v0,m1sq,m2sq,cosθ)
end

function decay2two(v0,m1sq,m2sq,cosθ)
    p0sq = v0[2]*v0[2]+v0[3]*v0[3]+v0[4]*v0[4];
    msq = v0[1]*v0[1]-p0sq
    (sqrt(msq) < sqrt(m1sq)+sqrt(m2sq)) && begin
        print("Error<decay2two>: decay products are too heavy (dM=",
            sqrt(msq) - (sqrt(m1sq)+sqrt(m2sq)),")!\n")
        return [0,0,0,0], [0,0,0,0]
    end
    p = sqrt(λ(msq,m1sq,m2sq)/(4*msq));
    ϕ = (2*rand()-1)*π;
    sinθ = sqrt(1-cosθ*cosθ);
    v1 = [(msq+m1sq-m2sq)/(2*sqrt(msq)),p*sinθ*sin(ϕ),p*sinθ*cos(ϕ),p*cosθ];
    v2 = [(msq-m1sq+m2sq)/(2*sqrt(msq)),-p*sinθ*sin(ϕ),-p*sinθ*cos(ϕ),-p*cosθ];
    # boost and rotate to the Lab frame
    γ0 = v0[1]/sqrt(msq)
    boost!(v1,γ0); boost!(v2,γ0); 
    # rotate appropriately
    if (p0sq > 0) 
        cosθ0 = v0[4]/sqrt(p0sq)
        rotateY!(v1,cosθ0); rotateY!(v2,cosθ0); 
    end
    ϕ0 = atan2(v0[3],v0[2])
    rotateZ!(v1,ϕ0); rotateZ!(v2,ϕ0);
    return v1,v2
end

masssq(v) = v[1]^2-v[2]^2-v[3]^2-v[4]^2;

# %%
# set constants
const mπ = 0.139; const mπ2 = mπ^2;
const mZc = 4.430; const mJpsi = 3.096;
const mp = 0.938; const mp2 = mp^2;
const mμ = 0.105; const mμ2 = mμ^2;
# energy
const e0 = 12 # (GeV)
const s0 = 2*mp2+2*mp*e0  # (GeV^2)

# functions to generate random variables
fρ(s,m1sq,m2sq,m3sq,m0sq)=(sqrt(s)>sqrt(m1sq)+sqrt(m2sq)) ? sqrt(λ(s,m1sq,m2sq)*λ(m0sq,s,m3sq))/s : 0;

const dX = collect(linspace(4mπ2,(mZc-mJpsi)^2,100))
fX = [fρ(s,mπ2,mπ2,mJpsi^2,mZc^2) for s in 0.5*(dX[1:end-1]+dX[2:end])]; fX /= sum(fX)
[fX[i] = fX[i-1]+fX[i] for i in 2:length(fX)];
const cX = fX;

# %%
# X disctribution
function randX()
    bi = searchsortedlast(cX,rand())+1
    return dX[bi] + rand()*(dX[bi+1]-dX[bi])
end
# Out:
# randX (generic function with 1 method)

# %%
using Plots

# %%
histogram([randX() for i=1:100000],bins=100)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip0000)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip0000)" points="
# 42.1066,375.813 580.315,375.813 580.315,11.811 42.1066,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="42" y="11" width="539" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip0002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   113.427,370.353 113.427,17.2711
#   "/>
# <polyline clip-path="url(#clip0002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   187.227,370.353 187.227,17.2711
#   "/>
# <polyline clip-path="url(#clip0002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   261.027,370.353 261.027,17.2711
#   "/>
# <polyline clip-path="url(#clip0002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   334.827,370.353 334.827,17.2711
#   "/>
# <polyline clip-path="url(#clip0002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   408.627,370.353 408.627,17.2711
#   "/>
# <polyline clip-path="url(#clip0002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   482.427,370.353 482.427,17.2711
#   "/>
# <polyline clip-path="url(#clip0002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   556.227,370.353 556.227,17.2711
#   "/>
# <polyline clip-path="url(#clip0002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   50.1797,375.813 572.242,375.813
#   "/>
# <polyline clip-path="url(#clip0002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   50.1797,266.569 572.242,266.569
#   "/>
# <polyline clip-path="url(#clip0002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   50.1797,157.325 572.242,157.325
#   "/>
# <polyline clip-path="url(#clip0002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   50.1797,48.0802 572.242,48.0802
#   "/>
# <polyline clip-path="url(#clip0000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.1066,375.813 580.315,375.813
#   "/>
# <polyline clip-path="url(#clip0000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.1066,375.813 42.1066,11.811
#   "/>
# <polyline clip-path="url(#clip0000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   113.427,375.813 113.427,370.353
#   "/>
# <polyline clip-path="url(#clip0000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   187.227,375.813 187.227,370.353
#   "/>
# <polyline clip-path="url(#clip0000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   261.027,375.813 261.027,370.353
#   "/>
# <polyline clip-path="url(#clip0000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   334.827,375.813 334.827,370.353
#   "/>
# <polyline clip-path="url(#clip0000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   408.627,375.813 408.627,370.353
#   "/>
# <polyline clip-path="url(#clip0000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   482.427,375.813 482.427,370.353
#   "/>
# <polyline clip-path="url(#clip0000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   556.227,375.813 556.227,370.353
#   "/>
# <polyline clip-path="url(#clip0000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.1066,375.813 50.1797,375.813
#   "/>
# <polyline clip-path="url(#clip0000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.1066,266.569 50.1797,266.569
#   "/>
# <polyline clip-path="url(#clip0000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.1066,157.325 50.1797,157.325
#   "/>
# <polyline clip-path="url(#clip0000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.1066,48.0802 50.1797,48.0802
#   "/>
# <g clip-path="url(#clip0000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 113.427, 389.613)" x="113.427" y="389.613">0.25</text>
# </g>
# <g clip-path="url(#clip0000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 187.227, 389.613)" x="187.227" y="389.613">0.50</text>
# </g>
# <g clip-path="url(#clip0000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 261.027, 389.613)" x="261.027" y="389.613">0.75</text>
# </g>
# <g clip-path="url(#clip0000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 334.827, 389.613)" x="334.827" y="389.613">1.00</text>
# </g>
# <g clip-path="url(#clip0000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 408.627, 389.613)" x="408.627" y="389.613">1.25</text>
# </g>
# <g clip-path="url(#clip0000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 482.427, 389.613)" x="482.427" y="389.613">1.50</text>
# </g>
# <g clip-path="url(#clip0000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 556.227, 389.613)" x="556.227" y="389.613">1.75</text>
# </g>
# <g clip-path="url(#clip0000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 36.1066, 380.313)" x="36.1066" y="380.313">0</text>
# </g>
# <g clip-path="url(#clip0000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 36.1066, 271.069)" x="36.1066" y="271.069">500</text>
# </g>
# <g clip-path="url(#clip0000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 36.1066, 161.825)" x="36.1066" y="161.825">1000</text>
# </g>
# <g clip-path="url(#clip0000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 36.1066, 52.5802)" x="36.1066" y="52.5802">1500</text>
# </g>
# <polygon clip-path="url(#clip0002)" points="
# 57.3389,356.805 57.3389,375.813 63.2429,375.813 63.2429,356.805 57.3389,356.805 57.3389,356.805
#   " fill="#009af9" fill-opacity="1"/>
# <polyline clip-path="url(#clip0002)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   57.3389,356.805 57.3389,375.813 63.2429,375.813 63.2429,356.805 57.3389,356.805
#   "/>
# <polygon clip-path="url(#clip0002)" points="
# 63.2429,214.132 63.2429,375.813 69.1469,375.813 69.1469,214.132 63.2429,214.132 63.2429,214.132
#   " fill="#009af9" fill-opacity="1"/>
# <polyline clip-path="url(#clip0002)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   63.2429,214.132 63.2429,375.813 69.1469,375.813 69.1469,214.132 63.2429,214.132
#   "/>
# <polygon clip-path="url(#clip0002)" points="
# 69.1469,15

# %%
function generate()
    p0 = [e0,0,0,sqrt(e0^2-mp2)] + [mp,0,0,0];
    # generate variables
    pZc,pπm = decay2two(p0,mZc^2,mπ2)
    # Z to Jpsi pi pi
    sPiPi = randX();
    # Z to Jpsi pi pi
    pPiPi,pJpsi = decay2two(pZc,sPiPi,mJpsi^2)
    pπp,pπ0 = decay2two(pPiPi,mπ2,mπ2)
    pγ1,pγ2 = decay2two(pπ0,0,0)
    pμ1,pμ2 = decay2two(pJpsi,mμ2,mμ2)
    pμ1,pμ2,pπm,pπp,pγ1,pγ2
end
# Out:
# generate (generic function with 1 method)

# %%
using DataFrames

# %%
pμ1,pμ2,pπm,pγ1,pγ2 = generate()
# Out:
# ([3.64431, -1.5215, 0.697405, 3.23552], [4.69691, 1.41201, -0.00890786, 4.4784], [0.890435, -0.424104, -0.0625894, 0.767966], [0.747666, -0.123338, -0.39114, 0.609493], [0.0288078, 0.0123769, 0.00940847, 0.0242524], [2.92987, 0.644555, -0.244177, 2.84764])

# %%
Nev = 10000
# data storage
tree = DataFrame(
    [Array{Float64,1} for i in 1:6],
    [:M1, :M2, :C1, :C2, :G1, :G2],
    Nev);
# fill with events
for i in 1:Nev
    tree[i,:M1],tree[i,:M2],tree[i,:C1],tree[i,:C2],
        tree[i,:G1],tree[i,:G2] = generate();
end

# %%
histogram(vcat(
[tree[i,:G1][1] for i=1:size(tree,1)],
[tree[i,:G2][1] for i=1:size(tree,1)]), bins=100,
    lab = "", title = "Energy spectrum of photons", xlab = "Eg, (GeV)")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip4600)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip4600)" points="
# 42.1066,360.065 580.315,360.065 580.315,31.4961 42.1066,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="42" y="31" width="539" height="330"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip4602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   57.3389,355.137 57.3389,36.4246
#   "/>
# <polyline clip-path="url(#clip4602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   154.982,355.137 154.982,36.4246
#   "/>
# <polyline clip-path="url(#clip4602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   252.625,355.137 252.625,36.4246
#   "/>
# <polyline clip-path="url(#clip4602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   350.268,355.137 350.268,36.4246
#   "/>
# <polyline clip-path="url(#clip4602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   447.911,355.137 447.911,36.4246
#   "/>
# <polyline clip-path="url(#clip4602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   545.554,355.137 545.554,36.4246
#   "/>
# <polyline clip-path="url(#clip4602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   50.1797,360.065 572.242,360.065
#   "/>
# <polyline clip-path="url(#clip4602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   50.1797,307.62 572.242,307.62
#   "/>
# <polyline clip-path="url(#clip4602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   50.1797,255.175 572.242,255.175
#   "/>
# <polyline clip-path="url(#clip4602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   50.1797,202.73 572.242,202.73
#   "/>
# <polyline clip-path="url(#clip4602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   50.1797,150.285 572.242,150.285
#   "/>
# <polyline clip-path="url(#clip4602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   50.1797,97.8393 572.242,97.8393
#   "/>
# <polyline clip-path="url(#clip4602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   50.1797,45.394 572.242,45.394
#   "/>
# <polyline clip-path="url(#clip4600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.1066,360.065 580.315,360.065
#   "/>
# <polyline clip-path="url(#clip4600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.1066,360.065 42.1066,31.4961
#   "/>
# <polyline clip-path="url(#clip4600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   57.3389,360.065 57.3389,355.137
#   "/>
# <polyline clip-path="url(#clip4600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   154.982,360.065 154.982,355.137
#   "/>
# <polyline clip-path="url(#clip4600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   252.625,360.065 252.625,355.137
#   "/>
# <polyline clip-path="url(#clip4600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   350.268,360.065 350.268,355.137
#   "/>
# <polyline clip-path="url(#clip4600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   447.911,360.065 447.911,355.137
#   "/>
# <polyline clip-path="url(#clip4600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   545.554,360.065 545.554,355.137
#   "/>
# <polyline clip-path="url(#clip4600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.1066,360.065 50.1797,360.065
#   "/>
# <polyline clip-path="url(#clip4600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.1066,307.62 50.1797,307.62
#   "/>
# <polyline clip-path="url(#clip4600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.1066,255.175 50.1797,255.175
#   "/>
# <polyline clip-path="url(#clip4600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.1066,202.73 50.1797,202.73
#   "/>
# <polyline clip-path="url(#clip4600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.1066,150.285 50.1797,150.285
#   "/>
# <polyline clip-path="url(#clip4600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.1066,97.8393 50.1797,97.8393
#   "/>
# <polyline clip-path="url(#clip4600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.1066,45.394 50.1797,45.394
#   "/>
# <g clip-path="url(#clip4600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 57.3389, 373.865)" x="57.3389" y="373.865">0</text>
# </g>
# <g clip-path="url(#clip4600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 154.982, 373.865)" x="154.982" y="373.865">1</text>
# </g>
# <g clip-path="url(#clip4600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 252.625, 373.865)" x="252.625" y="373.865">2</text>
# </g>
# <g clip-path="url(#clip4600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 350.268, 373.865)" x="350.268" y="373.865">3</text>
# </g>
# <g clip-path="url(#clip4600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 447.911, 373.865)" x="447.911" y="373.865">4</text>
# </g>
# <g clip-path="url(#clip4600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 545.554, 373.865)" x="545.554" y="373.865">5</text>
# </g>
# <g clip-path="url(#clip4600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 36.1066, 364.565)" x="36.1066" y="364.565">0</text>
# </g>
# <g clip-path="url(#clip4600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 36.1066, 312.12)" x="36.1066" y="312.12">200</text>
# </g>
# <g clip-path="url(#clip4600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 36.1066, 259.675)" x="36.1066" y="259.675">400</text>
# </g>
# <g clip-path="url(#clip4600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 36.1066, 207.23)" x="36.1066" y="207.23">600</text>
# </g>
# <g clip-path="url(#clip4600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 36.1066, 154.785)" x="36.1066" y="154.785">800</text>
# </g>
# <g clip-path="url(#clip4600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 36.1066, 102.339)" x="36.1066" y="102.339">1000<

# %%
polAngle(v) = 180/π*acos(v[4]/v[1])
histogram(vcat(
    [polAngle(tree[i,:G1]) for i=1:size(tree,1)],
    [polAngle(tree[i,:G2]) for i=1:size(tree,1)]), bins=100,
    xlim = (0,180),
    lab = "", title = "Polar angles of photons", xlab = "theta, (deg.)")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip4800)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip4800)" points="
# 42.1066,360.065 580.315,360.065 580.315,31.4961 42.1066,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="42" y="31" width="539" height="330"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip4802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   42.1066,355.137 42.1066,36.4246
#   "/>
# <polyline clip-path="url(#clip4802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   131.808,355.137 131.808,36.4246
#   "/>
# <polyline clip-path="url(#clip4802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   221.509,355.137 221.509,36.4246
#   "/>
# <polyline clip-path="url(#clip4802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   311.211,355.137 311.211,36.4246
#   "/>
# <polyline clip-path="url(#clip4802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   400.912,355.137 400.912,36.4246
#   "/>
# <polyline clip-path="url(#clip4802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   490.614,355.137 490.614,36.4246
#   "/>
# <polyline clip-path="url(#clip4802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   580.315,355.137 580.315,36.4246
#   "/>
# <polyline clip-path="url(#clip4802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   50.1797,360.065 572.242,360.065
#   "/>
# <polyline clip-path="url(#clip4802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   50.1797,290.157 572.242,290.157
#   "/>
# <polyline clip-path="url(#clip4802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   50.1797,220.249 572.242,220.249
#   "/>
# <polyline clip-path="url(#clip4802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   50.1797,150.34 572.242,150.34
#   "/>
# <polyline clip-path="url(#clip4802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   50.1797,80.4319 572.242,80.4319
#   "/>
# <polyline clip-path="url(#clip4800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.1066,360.065 580.315,360.065
#   "/>
# <polyline clip-path="url(#clip4800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.1066,360.065 42.1066,31.4961
#   "/>
# <polyline clip-path="url(#clip4800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.1066,360.065 42.1066,355.137
#   "/>
# <polyline clip-path="url(#clip4800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   131.808,360.065 131.808,355.137
#   "/>
# <polyline clip-path="url(#clip4800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   221.509,360.065 221.509,355.137
#   "/>
# <polyline clip-path="url(#clip4800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   311.211,360.065 311.211,355.137
#   "/>
# <polyline clip-path="url(#clip4800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   400.912,360.065 400.912,355.137
#   "/>
# <polyline clip-path="url(#clip4800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   490.614,360.065 490.614,355.137
#   "/>
# <polyline clip-path="url(#clip4800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   580.315,360.065 580.315,355.137
#   "/>
# <polyline clip-path="url(#clip4800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.1066,360.065 50.1797,360.065
#   "/>
# <polyline clip-path="url(#clip4800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.1066,290.157 50.1797,290.157
#   "/>
# <polyline clip-path="url(#clip4800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.1066,220.249 50.1797,220.249
#   "/>
# <polyline clip-path="url(#clip4800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.1066,150.34 50.1797,150.34
#   "/>
# <polyline clip-path="url(#clip4800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.1066,80.4319 50.1797,80.4319
#   "/>
# <g clip-path="url(#clip4800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 42.1066, 373.865)" x="42.1066" y="373.865">0</text>
# </g>
# <g clip-path="url(#clip4800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 131.808, 373.865)" x="131.808" y="373.865">30</text>
# </g>
# <g clip-path="url(#clip4800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 221.509, 373.865)" x="221.509" y="373.865">60</text>
# </g>
# <g clip-path="url(#clip4800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 311.211, 373.865)" x="311.211" y="373.865">90</text>
# </g>
# <g clip-path="url(#clip4800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 400.912, 373.865)" x="400.912" y="373.865">120</text>
# </g>
# <g clip-path="url(#clip4800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 490.614, 373.865)" x="490.614" y="373.865">150</text>
# </g>
# <g clip-path="url(#clip4800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 580.315, 373.865)" x="580.315" y="373.865">180</text>
# </g>
# <g clip-path="url(#clip4800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 36.1066, 364.565)" x="36.1066" y="364.565">0</text>
# </g>
# <g clip-path="url(#clip4800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 36.1066, 294.657)" x="36.1066" y="294.657">250</text>
# </g>
# <g clip-path="url(#clip4800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 36.1066, 224.749)" x="36.1066" y="224.749">500</text>
# </g>
# <g clip-path="url(#clip4800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 36.1066, 154.84)" x="36.1066" y="154.84">750</text>
# </g>
# <g clip-path="url(#clip4800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 36.1066, 84.9319)" x="36.1066" y="84.9319">1000</text>
# </g>
# <g clip-path="url(#clip4800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(0, 311.211, 18)" x="311.211" y="18">Polar angles of photons</text>
# </g>
# <g clip-path="url(#clip4800)

# %%
histogram2d(
    vcat([[polAngle(tree[i,g]) for i=1:size(tree,1)] for g in [:G1, :G2]]...),
    vcat([[tree[i,g][1] for i=1:size(tree,1)] for g in [:G1, :G2]]...),
    bins=50,
    lab = "", title = "Angle-Energy correlation for photons",
    xlab = "theta (deg.)", ylab = "E (GeV)")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip5000)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip5000)" points="
# 38.0857,360.065 580.315,360.065 580.315,31.4961 38.0857,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="38" y="31" width="483" height="330"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip5002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   38.0857,355.137 38.0857,36.4246
#   "/>
# <polyline clip-path="url(#clip5002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   118.457,355.137 118.457,36.4246
#   "/>
# <polyline clip-path="url(#clip5002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   198.829,355.137 198.829,36.4246
#   "/>
# <polyline clip-path="url(#clip5002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   279.2,355.137 279.2,36.4246
#   "/>
# <polyline clip-path="url(#clip5002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   359.572,355.137 359.572,36.4246
#   "/>
# <polyline clip-path="url(#clip5002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   439.943,355.137 439.943,36.4246
#   "/>
# <polyline clip-path="url(#clip5002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   520.315,355.137 520.315,36.4246
#   "/>
# <polyline clip-path="url(#clip5002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   45.3191,360.065 513.082,360.065
#   "/>
# <polyline clip-path="url(#clip5002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   45.3191,296.879 513.082,296.879
#   "/>
# <polyline clip-path="url(#clip5002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   45.3191,233.693 513.082,233.693
#   "/>
# <polyline clip-path="url(#clip5002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   45.3191,170.506 513.082,170.506
#   "/>
# <polyline clip-path="url(#clip5002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   45.3191,107.32 513.082,107.32
#   "/>
# <polyline clip-path="url(#clip5002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   45.3191,44.1333 513.082,44.1333
#   "/>
# <polyline clip-path="url(#clip5000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   38.0857,360.065 520.315,360.065
#   "/>
# <polyline clip-path="url(#clip5000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   38.0857,360.065 38.0857,31.4961
#   "/>
# <polyline clip-path="url(#clip5000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   38.0857,360.065 38.0857,355.137
#   "/>
# <polyline clip-path="url(#clip5000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   118.457,360.065 118.457,355.137
#   "/>
# <polyline clip-path="url(#clip5000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   198.829,360.065 198.829,355.137
#   "/>
# <polyline clip-path="url(#clip5000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   279.2,360.065 279.2,355.137
#   "/>
# <polyline clip-path="url(#clip5000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   359.572,360.065 359.572,355.137
#   "/>
# <polyline clip-path="url(#clip5000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   439.943,360.065 439.943,355.137
#   "/>
# <polyline clip-path="url(#clip5000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   520.315,360.065 520.315,355.137
#   "/>
# <polyline clip-path="url(#clip5000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   38.0857,360.065 45.3191,360.065
#   "/>
# <polyline clip-path="url(#clip5000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   38.0857,296.879 45.3191,296.879
#   "/>
# <polyline clip-path="url(#clip5000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   38.0857,233.693 45.3191,233.693
#   "/>
# <polyline clip-path="url(#clip5000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   38.0857,170.506 45.3191,170.506
#   "/>
# <polyline clip-path="url(#clip5000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   38.0857,107.32 45.3191,107.32
#   "/>
# <polyline clip-path="url(#clip5000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   38.0857,44.1333 45.3191,44.1333
#   "/>
# <g clip-path="url(#clip5000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 38.0857, 373.865)" x="38.0857" y="373.865">0</text>
# </g>
# <g clip-path="url(#clip5000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 118.457, 373.865)" x="118.457" y="373.865">30</text>
# </g>
# <g clip-path="url(#clip5000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 198.829, 373.865)" x="198.829" y="373.865">60</text>
# </g>
# <g clip-path="url(#clip5000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 279.2, 373.865)" x="279.2" y="373.865">90</text>
# </g>
# <g clip-path="url(#clip5000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 359.572, 373.865)" x="359.572" y="373.865">120</text>
# </g>
# <g clip-path="url(#clip5000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 439.943, 373.865)" x="439.943" y="373.865">150</text>
# </g>
# <g clip-path="url(#clip5000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 520.315, 373.865)" x="520.315" y="373.865">180</text>
# </g>
# <g clip-path="url(#clip5000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 32.0857, 364.565)" x="32.0857" y="364.565">0</text>
# </g>
# <g clip-path="url(#clip5000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 32.0857, 301.379)" x="32.0857" y="301.379">1</text>
# </g>
# <g clip-path="url(#clip5000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 32.0857, 238.193)" x="32.0857" y="238.193">2</text>
# </g>
# <g clip-path="url(#clip5000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 32.0857, 175.006)" x="32.0857" y="175.006">3</text>
# </g>
# <g clip-path="url(#clip5000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 32.0857, 111.82)" x="32.0857" y="111.82">4</

# %% [markdown]
# ### Charge particles spectrum
# Muon invariant masses, dalitz plot

# %%
function invariants(v1,v2,v3)
    masssq(v1+v2), masssq(v2+v3)
end
s1s2set = [invariants(
        tree[i,:G1]+tree[i,:G2],
        tree[i,:M1]+tree[i,:M2],
        tree[i,:C2]) for i=1:size(tree,1)]
histogram2d(
    [s1s2set[i][1] for i=1:length(s1s2set)],
    [s1s2set[i][2] for i=1:length(s1s2set)], bins=40,
    xlab="mJpsiPi", ylab="mJpsiPi", title="JpsiPiPi Dalitz plot")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip5200)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip5200)" points="
# 44.6753,360.065 580.315,360.065 580.315,31.4961 44.6753,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="44" y="31" width="477" height="330"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip5202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   137.483,355.137 137.483,36.4246
#   "/>
# <polyline clip-path="url(#clip5202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   253.493,355.137 253.493,36.4246
#   "/>
# <polyline clip-path="url(#clip5202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   369.502,355.137 369.502,36.4246
#   "/>
# <polyline clip-path="url(#clip5202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   485.512,355.137 485.512,36.4246
#   "/>
# <polyline clip-path="url(#clip5202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   51.8099,295.954 513.18,295.954
#   "/>
# <polyline clip-path="url(#clip5202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   51.8099,215.815 513.18,215.815
#   "/>
# <polyline clip-path="url(#clip5202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   51.8099,135.677 513.18,135.677
#   "/>
# <polyline clip-path="url(#clip5202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   51.8099,55.5377 513.18,55.5377
#   "/>
# <polyline clip-path="url(#clip5200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   44.6753,360.065 520.315,360.065
#   "/>
# <polyline clip-path="url(#clip5200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   44.6753,360.065 44.6753,31.4961
#   "/>
# <polyline clip-path="url(#clip5200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   137.483,360.065 137.483,355.137
#   "/>
# <polyline clip-path="url(#clip5200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   253.493,360.065 253.493,355.137
#   "/>
# <polyline clip-path="url(#clip5200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   369.502,360.065 369.502,355.137
#   "/>
# <polyline clip-path="url(#clip5200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   485.512,360.065 485.512,355.137
#   "/>
# <polyline clip-path="url(#clip5200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   44.6753,295.954 51.8099,295.954
#   "/>
# <polyline clip-path="url(#clip5200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   44.6753,215.815 51.8099,215.815
#   "/>
# <polyline clip-path="url(#clip5200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   44.6753,135.677 51.8099,135.677
#   "/>
# <polyline clip-path="url(#clip5200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   44.6753,55.5377 51.8099,55.5377
#   "/>
# <g clip-path="url(#clip5200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 137.483, 373.865)" x="137.483" y="373.865">12</text>
# </g>
# <g clip-path="url(#clip5200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 253.493, 373.865)" x="253.493" y="373.865">14</text>
# </g>
# <g clip-path="url(#clip5200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 369.502, 373.865)" x="369.502" y="373.865">16</text>
# </g>
# <g clip-path="url(#clip5200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 485.512, 373.865)" x="485.512" y="373.865">18</text>
# </g>
# <g clip-path="url(#clip5200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 38.6753, 300.454)" x="38.6753" y="300.454">12</text>
# </g>
# <g clip-path="url(#clip5200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 38.6753, 220.315)" x="38.6753" y="220.315">14</text>
# </g>
# <g clip-path="url(#clip5200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 38.6753, 140.177)" x="38.6753" y="140.177">16</text>
# </g>
# <g clip-path="url(#clip5200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 38.6753, 60.0377)" x="38.6753" y="60.0377">18</text>
# </g>
# <g clip-path="url(#clip5200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(0, 282.495, 18)" x="282.495" y="18">JpsiPiPi Dalitz plot</text>
# </g>
# <g clip-path="url(#clip5200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(0, 282.495, 397.6)" x="282.495" y="397.6">mJpsiPi</text>
# </g>
# <g clip-path="url(#clip5200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(-90, 14.4, 195.781)" x="14.4" y="195.781">mJpsiPi</text>
# </g>
# <g clip-path="url(#clip5202)">
# <image width="476" height="329" xlink:href="data:;base64,
# iVBORw0KGgoAAAANSUhEUgAAAdwAAAFJCAYAAAAxCJwFAAANqklEQVR4nO3df4zXdR3A8Y9wd9x9
# +aGCeFcgEIriJEFPxY0YYAbimpWGLsVfOa3wx/o9W7qpTas1a0XkZpatFC3STQqVfmhIVmr4A8XE
# C/MHIJqKwN0Bxw/7tzWt9yvhxR33ePz94rXvxt33yeePF599qqrurSpk+z6xeQCgz57+AADQGwgu
# ACQQXABIILgAkEBwASCB4AJAAsEFgASCCwAJ6m46/LzQH9i4rT70H2V8/u8/DEz7TzUA2Dt5wgWA
# BIILAAkEFwASCC4AJBBcAEgguACQQHABIEHdwtX9Qn/gs+NeDs2vmTiuePaQBetDN76bu15wtwtA
# j+AJFwASCC4AJBBcAEgguACQQHABIIHgAkACwQWABOE71q3fbgrdyvYJjHesbA59lsHfez00v3Nn
# u7tdAPYIT7gAkEBwASCB4AJAAsEFgASCCwAJBBcAEgguACQI36VecMBloTvc6075ffHs9q31oc9y
# QOvK0PyRV84snl3ZcaebXQB2GU+4AJBAcAEggeACQALBBYAEggsACQQXABIILgAk2O23pq9/Zkzx
# 3e6AMatDu3dsrIXm17cdVDzbetfA0O517Uvd7QLwjjzhAkACwQWABIILAAkEFwASCC4AJBBcAEgg
# uACQYLffjk6snV98h7v4ovtCuzv+uX9ofv8xLxXP9um3LbT79OvOLp5duGmem12AXsYTLgAkEFwA
# SCC4AJBAcAEggeACQALBBYAEggsACbrVPehVIy8pvtmtqqr66uU3hfZ3rGwunm1sXh/avSHwrt3p
# t48P7X6ic363+nsCIM4TLgAkEFwASCC4AJBAcAEggeACQALBBYAEggsACbrVfWdTw8jQHe6mX3SG
# 9r++8MDi2f3GPRfa/eZTo4tnh0wvfy9vVVXVpE+eFpp/qPPmbvX3CoAnXABIIbgAkEBwASCB4AJA
# AsEFgASCCwAJBBcAEvToe81Z+14autu9etKTxbP19dtCn2XUScuKZ1/949jQ7v5DY+/mnXDT4cWz
# z7ff26N/BgB6Ck+4AJBAcAEggeACQALBBYAEggsACQQXABIILgAk6FU3mJ1XDQnd7UY0TCj/t8vq
# W98X2r1mXUtofljLuuLZT93dGtq9uOOGXvUzA7CreMIFgASCCwAJBBcAEgguACQQXABIILgAkEBw
# ASBBr7qpbGoYWXyH+/Kc2O4BUzvLh7dsDe3esTb2bt4dG2vFs20PHh3afc6DQ4tnn+ic36t+vgD+
# G0+4AJBAcAEggeACQALBBYAEggsACQQXABIILgAkcCf5Dg7rf2ro3bkrbl1aPNv+h/I72aqqqsaz
# DgzNL/v8e4pn9x+4MbS7Y3NT8ewVD48K7fauXWBv5gkXABIILgAkEFwASCC4AJBAcAEggeACQALB
# BYAE7h53kXuOPaP4bndQ4+bQ7kPGrArNb99aXzy7/NnDQrs/8MEHimf7NnaFdp/7nTND8ws2zPXz
# C/QYnnABIIHgAkACwQWABIILAAkEFwASCC4AJBBcAEjgjnEPaPvIpNC7docd9Uxo/4olx4XmI46Y
# 8nDx7JrHxoZ21zdsC82fu2hC8eySzhv9rAN7lCdcAEgguACQQHABIIHgAkACwQWABI

# %%
histogram([
    [tree[i,:C2][1] for i=1:size(tree,1)],
    [tree[i,:C1][1] for i=1:size(tree,1)]
          ],
    lab = ["Decay Pions energy", "Recoil Pions energy"],
title = "Energy spectrum for charge partiles",
    xlab = "E, (GeV)", ylab = "Entries"
        )
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip5600)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip5600)" points="
# 51.265,360.065 580.315,360.065 580.315,31.4961 51.265,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="51" y="31" width="530" height="330"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip5602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   66.2381,355.137 66.2381,36.4246
#   "/>
# <polyline clip-path="url(#clip5602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   155.364,355.137 155.364,36.4246
#   "/>
# <polyline clip-path="url(#clip5602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   244.489,355.137 244.489,36.4246
#   "/>
# <polyline clip-path="url(#clip5602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   333.615,355.137 333.615,36.4246
#   "/>
# <polyline clip-path="url(#clip5602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   422.741,355.137 422.741,36.4246
#   "/>
# <polyline clip-path="url(#clip5602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   511.866,355.137 511.866,36.4246
#   "/>
# <polyline clip-path="url(#clip5602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   59.2007,360.065 572.379,360.065
#   "/>
# <polyline clip-path="url(#clip5602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   59.2007,289.783 572.379,289.783
#   "/>
# <polyline clip-path="url(#clip5602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   59.2007,219.501 572.379,219.501
#   "/>
# <polyline clip-path="url(#clip5602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   59.2007,149.219 572.379,149.219
#   "/>
# <polyline clip-path="url(#clip5602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   59.2007,78.9366 572.379,78.9366
#   "/>
# <polyline clip-path="url(#clip5600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   51.265,360.065 580.315,360.065
#   "/>
# <polyline clip-path="url(#clip5600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   51.265,360.065 51.265,31.4961
#   "/>
# <polyline clip-path="url(#clip5600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   66.2381,360.065 66.2381,355.137
#   "/>
# <polyline clip-path="url(#clip5600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   155.364,360.065 155.364,355.137
#   "/>
# <polyline clip-path="url(#clip5600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   244.489,360.065 244.489,355.137
#   "/>
# <polyline clip-path="url(#clip5600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   333.615,360.065 333.615,355.137
#   "/>
# <polyline clip-path="url(#clip5600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   422.741,360.065 422.741,355.137
#   "/>
# <polyline clip-path="url(#clip5600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   511.866,360.065 511.866,355.137
#   "/>
# <polyline clip-path="url(#clip5600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   51.265,360.065 59.2007,360.065
#   "/>
# <polyline clip-path="url(#clip5600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   51.265,289.783 59.2007,289.783
#   "/>
# <polyline clip-path="url(#clip5600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   51.265,219.501 59.2007,219.501
#   "/>
# <polyline clip-path="url(#clip5600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   51.265,149.219 59.2007,149.219
#   "/>
# <polyline clip-path="url(#clip5600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   51.265,78.9366 59.2007,78.9366
#   "/>
# <g clip-path="url(#clip5600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 66.2381, 373.865)" x="66.2381" y="373.865">0</text>
# </g>
# <g clip-path="url(#clip5600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 155.364, 373.865)" x="155.364" y="373.865">1</text>
# </g>
# <g clip-path="url(#clip5600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 244.489, 373.865)" x="244.489" y="373.865">2</text>
# </g>
# <g clip-path="url(#clip5600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 333.615, 373.865)" x="333.615" y="373.865">3</text>
# </g>
# <g clip-path="url(#clip5600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 422.741, 373.865)" x="422.741" y="373.865">4</text>
# </g>
# <g clip-path="url(#clip5600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 511.866, 373.865)" x="511.866" y="373.865">5</text>
# </g>
# <g clip-path="url(#clip5600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 45.265, 364.565)" x="45.265" y="364.565">0</text>
# </g>
# <g clip-path="url(#clip5600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 45.265, 294.283)" x="45.265" y="294.283">200</text>
# </g>
# <g clip-path="url(#clip5600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 45.265, 224.001)" x="45.265" y="224.001">400</text>
# </g>
# <g clip-path="url(#clip5600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 45.265, 153.719)" x="45.265" y="153.719">600</text>
# </g>
# <g clip-path="url(#clip5600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 45.265, 83.4366)" x="45.265" y="83.4366">800</text>
# </g>
# <g clip-path="url(#clip5600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(0, 315.79, 18)" x="315.79" y="18">Energy spectrum for charge partiles</text>
# </g>
# <g clip-path="url(#clip5600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(0, 315.79, 397.6)" x="315.79" y="397.6">E, (GeV)</text>
# </g>
# <g clip-path="url(#clip5600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(-90, 14.4, 195.781)" x="14.4" y="195.781">Entries</text>
# </g>
# <polygon clip-path="url(#clip5602)" points="
# 66.2381,304.191 66.2381,360.065 84.0632,360.065 84.0632,304.191 66

# %% [markdown]
# # Second reaction $p\bar{p}\to\pi^0\pi^0 Z_c[\to J/\psi\pi^+\pi^-]$
#  * For simplicity, I consider $Z_c$ very narrow.
#  * Flat Dalitz plot for $Z_c\pi^0\pi^0$
#  * Flat Dalitz plot for $J/\psi\pi^-\pi^+$

# %%
const dPi0Pi0 = collect(linspace(4mπ2,(sqrt(s0)-mZc)^2,100))
fPi0Pi0 = [fρ(s,mπ2,mπ2,mZc^2,s0) for s in 0.5*(dPi0Pi0[1:end-1]+dPi0Pi0[2:end])]; fPi0Pi0 /= sum(fPi0Pi0)
[fPi0Pi0[i] = fPi0Pi0[i-1]+fPi0Pi0[i] for i in 2:length(fPi0Pi0)];
const cPi0Pi0 = fPi0Pi0;

# %%
# X disctribution
function randPi0Pi0()
    bi = searchsortedlast(cPi0Pi0, rand())+1
    return dPi0Pi0[bi] + rand()*(dPi0Pi0[bi+1]-dPi0Pi0[bi])
end
# Out:
# randPi0Pi0 (generic function with 1 method)

# %%
function generateR2()
    p0 = [e0,0,0,sqrt(e0^2-mp2)] + [mp,0,0,0];
    # generate variables
    sPi0Pi0 = randPi0Pi0();
    pZc,pπ0π0 = decay2two(p0,mZc^2,sPi0Pi0)
    pπ01,pπ02 = decay2two(pπ0π0,mπ2,mπ2)
    # pi0 decays
    pγ1,pγ2 = decay2two(pπ01,0,0)
    pγ3,pγ4 = decay2two(pπ02,0,0)
    # Z to Jpsi pi pi
    sPiPi = randX();
    pPiPi,pJpsi = decay2two(pZc,sPiPi,mJpsi^2)
    pπ1,pπ2 = decay2two(pPiPi,mπ2,mπ2)
    # Jpsi decay
    pμ1,pμ2 = decay2two(pJpsi,mμ2,mμ2)
    pμ1,pμ2,pπ1,pπ2,pγ1,pγ2,pγ3,pγ4
end
# Out:
# generateR2 (generic function with 1 method)

# %%
generateR2()
# Out:
# ([6.4131, 0.00439462, 0.0612928, 6.41195], [0.677356, 0.476679, -0.465242, -0.0641314], [2.31723, 0.206124, -0.255811, 2.28961], [2.32497, -0.381041, 0.551487, 2.2219], [0.272324, -0.132571, -0.0792577, 0.224284], [0.265406, -0.0784674, 0.0465155, 0.249238], [0.0346872, 0.0199441, -0.00984094, 0.0266194], [0.632921, -0.115062, 0.150857, 0.603814])

# %%
Nev = 10000
# data storage
treeR2 = DataFrame(
    [Array{Float64,1} for i in 1:8],
    [:M1, :M2, :C1, :C2, :G1, :G2, :G3, :G4],
    Nev);
# fill with events
for i in 1:Nev
    treeR2[i,:M1],treeR2[i,:M2],treeR2[i,:C1],treeR2[i,:C2],
        treeR2[i,:G1],treeR2[i,:G2],treeR2[i,:G3],treeR2[i,:G4] = generateR2();
end

# %%
histogram(vcat(
    [treeR2[i,:G1][1] for i=1:size(treeR2,1)],
    [treeR2[i,:G2][1] for i=1:size(treeR2,1)],
    [treeR2[i,:G3][1] for i=1:size(treeR2,1)],
    [treeR2[i,:G4][1] for i=1:size(treeR2,1)]), bins=100,
    lab = "", title = "Energy spectrum of photons", xlab = "Eg (GeV)")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip1000)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip1000)" points="
# 42.1066,360.065 580.315,360.065 580.315,31.4961 42.1066,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="42" y="31" width="539" height="330"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip1002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   57.3389,355.137 57.3389,36.4246
#   "/>
# <polyline clip-path="url(#clip1002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   218.017,355.137 218.017,36.4246
#   "/>
# <polyline clip-path="url(#clip1002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   378.696,355.137 378.696,36.4246
#   "/>
# <polyline clip-path="url(#clip1002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   539.374,355.137 539.374,36.4246
#   "/>
# <polyline clip-path="url(#clip1002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   50.1797,360.065 572.242,360.065
#   "/>
# <polyline clip-path="url(#clip1002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   50.1797,275.73 572.242,275.73
#   "/>
# <polyline clip-path="url(#clip1002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   50.1797,191.395 572.242,191.395
#   "/>
# <polyline clip-path="url(#clip1002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   50.1797,107.06 572.242,107.06
#   "/>
# <polyline clip-path="url(#clip1000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.1066,360.065 580.315,360.065
#   "/>
# <polyline clip-path="url(#clip1000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.1066,360.065 42.1066,31.4961
#   "/>
# <polyline clip-path="url(#clip1000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   57.3389,360.065 57.3389,355.137
#   "/>
# <polyline clip-path="url(#clip1000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   218.017,360.065 218.017,355.137
#   "/>
# <polyline clip-path="url(#clip1000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   378.696,360.065 378.696,355.137
#   "/>
# <polyline clip-path="url(#clip1000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   539.374,360.065 539.374,355.137
#   "/>
# <polyline clip-path="url(#clip1000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.1066,360.065 50.1797,360.065
#   "/>
# <polyline clip-path="url(#clip1000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.1066,275.73 50.1797,275.73
#   "/>
# <polyline clip-path="url(#clip1000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.1066,191.395 50.1797,191.395
#   "/>
# <polyline clip-path="url(#clip1000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.1066,107.06 50.1797,107.06
#   "/>
# <g clip-path="url(#clip1000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 57.3389, 373.865)" x="57.3389" y="373.865">0.0</text>
# </g>
# <g clip-path="url(#clip1000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 218.017, 373.865)" x="218.017" y="373.865">0.5</text>
# </g>
# <g clip-path="url(#clip1000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 378.696, 373.865)" x="378.696" y="373.865">1.0</text>
# </g>
# <g clip-path="url(#clip1000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 539.374, 373.865)" x="539.374" y="373.865">1.5</text>
# </g>
# <g clip-path="url(#clip1000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 36.1066, 364.565)" x="36.1066" y="364.565">0</text>
# </g>
# <g clip-path="url(#clip1000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 36.1066, 280.23)" x="36.1066" y="280.23">500</text>
# </g>
# <g clip-path="url(#clip1000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 36.1066, 195.895)" x="36.1066" y="195.895">1000</text>
# </g>
# <g clip-path="url(#clip1000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 36.1066, 111.56)" x="36.1066" y="111.56">1500</text>
# </g>
# <g clip-path="url(#clip1000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(0, 311.211, 18)" x="311.211" y="18">Energy spectrum of photons</text>
# </g>
# <g clip-path="url(#clip1000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(0, 311.211, 397.6)" x="311.211" y="397.6">Eg (GeV)</text>
# </g>
# <polygon clip-path="url(#clip1002)" points="
# 57.3389,262.237 57.3389,360.065 63.766,360.065 63.766,262.237 57.3389,262.237 57.3389,262.237
#   " fill="#009af9" fill-opacity="1"/>
# <polyline clip-path="url(#clip1002)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   57.3389,262.237 57.3389,360.065 63.766,360.065 63.766,262.237 57.3389,262.237
#   "/>
# <polygon clip-path="url(#clip1002)" points="
# 63.766,87.4945 63.766,360.065 70.1931,360.065 70.1931,87.4945 63.766,87.4945 63.766,87.4945
#   " fill="#009af9" fill-opacity="1"/>
# <polyline clip-path="url(#clip1002)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   63.766,87.4945 63.766,360.065 70.1931,360.065 70.1931,87.4945 63.766,87.4945
#   "/>
# <polygon clip-path="url(#clip1002)" points="
# 70.1931,36.3875 70.1931,360.065 76.6203,360.065 76.6203,36.3875 70.1931,36.3875 70.1931,36.3875
#   " fill="#009af9" fill-opacity="1"/>
# <polyline clip-path="url(#clip1002)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   70.1931,36.3875 70.1931,360.065 76.6203,360.065 76.6203,36.3875 70.1931,36.3875
#   "/>
# <polygon clip-path="url(#clip1002)" points="
# 76.6203,31.4961 76.6203,360.065 83.0474,360.065 83.0474,31.4961 76.6203,31.4961 76.6203,31.4961
#   " fill="#009af9" fill-opacity="1"/>
# <polyline clip-path="url(#clip1002)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   76.6203,31.4961 76.6203,360.065 83.0474,360.065 83.0474,31.4961 76.6203,31.4961
#   "/>
# <polygon clip-path="url(#clip1002)" points="
# 83.0474,41.9536 83.0474,360.065 89.4745,360.065 89.4745,41.9536 83.0474,41.9536 83.0474,41.9536
#   " fill="#009af9" fill-opacity="1"/>
# <polyline clip-path="url(#clip1002)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   83.0474,41.9536 83.0474,360.065 89.4745,360.065 89.4745,41.9536 83.0474,41.9536
#   "/>
# <polygon clip-path="url(#clip1002)" points="
# 89.4745,44.6523 89.4745,360.065 95.9017,360.065 95.9017,44.6

# %%
polAngle(v) = 180/π*acos(v[4]/v[1])
histogram(vcat(
    [polAngle(treeR2[i,:G1]) for i=1:size(treeR2,1)],
    [polAngle(treeR2[i,:G2]) for i=1:size(treeR2,1)],
    [polAngle(treeR2[i,:G3]) for i=1:size(treeR2,1)],
    [polAngle(treeR2[i,:G4]) for i=1:size(treeR2,1)]), bins=100,
    xlim = (0,180),
    lab = "", title = "Polar angles of photons", xlab = "theta (deg.)")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip1200)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip1200)" points="
# 42.1066,360.065 580.315,360.065 580.315,31.4961 42.1066,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="42" y="31" width="539" height="330"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip1202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   42.1066,355.137 42.1066,36.4246
#   "/>
# <polyline clip-path="url(#clip1202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   131.808,355.137 131.808,36.4246
#   "/>
# <polyline clip-path="url(#clip1202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   221.509,355.137 221.509,36.4246
#   "/>
# <polyline clip-path="url(#clip1202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   311.211,355.137 311.211,36.4246
#   "/>
# <polyline clip-path="url(#clip1202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   400.912,355.137 400.912,36.4246
#   "/>
# <polyline clip-path="url(#clip1202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   490.614,355.137 490.614,36.4246
#   "/>
# <polyline clip-path="url(#clip1202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   580.315,355.137 580.315,36.4246
#   "/>
# <polyline clip-path="url(#clip1202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   50.1797,360.065 572.242,360.065
#   "/>
# <polyline clip-path="url(#clip1202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   50.1797,288.854 572.242,288.854
#   "/>
# <polyline clip-path="url(#clip1202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   50.1797,217.643 572.242,217.643
#   "/>
# <polyline clip-path="url(#clip1202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   50.1797,146.431 572.242,146.431
#   "/>
# <polyline clip-path="url(#clip1202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   50.1797,75.2199 572.242,75.2199
#   "/>
# <polyline clip-path="url(#clip1200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.1066,360.065 580.315,360.065
#   "/>
# <polyline clip-path="url(#clip1200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.1066,360.065 42.1066,31.4961
#   "/>
# <polyline clip-path="url(#clip1200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.1066,360.065 42.1066,355.137
#   "/>
# <polyline clip-path="url(#clip1200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   131.808,360.065 131.808,355.137
#   "/>
# <polyline clip-path="url(#clip1200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   221.509,360.065 221.509,355.137
#   "/>
# <polyline clip-path="url(#clip1200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   311.211,360.065 311.211,355.137
#   "/>
# <polyline clip-path="url(#clip1200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   400.912,360.065 400.912,355.137
#   "/>
# <polyline clip-path="url(#clip1200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   490.614,360.065 490.614,355.137
#   "/>
# <polyline clip-path="url(#clip1200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   580.315,360.065 580.315,355.137
#   "/>
# <polyline clip-path="url(#clip1200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.1066,360.065 50.1797,360.065
#   "/>
# <polyline clip-path="url(#clip1200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.1066,288.854 50.1797,288.854
#   "/>
# <polyline clip-path="url(#clip1200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.1066,217.643 50.1797,217.643
#   "/>
# <polyline clip-path="url(#clip1200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.1066,146.431 50.1797,146.431
#   "/>
# <polyline clip-path="url(#clip1200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   42.1066,75.2199 50.1797,75.2199
#   "/>
# <g clip-path="url(#clip1200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 42.1066, 373.865)" x="42.1066" y="373.865">0</text>
# </g>
# <g clip-path="url(#clip1200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 131.808, 373.865)" x="131.808" y="373.865">30</text>
# </g>
# <g clip-path="url(#clip1200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 221.509, 373.865)" x="221.509" y="373.865">60</text>
# </g>
# <g clip-path="url(#clip1200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 311.211, 373.865)" x="311.211" y="373.865">90</text>
# </g>
# <g clip-path="url(#clip1200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 400.912, 373.865)" x="400.912" y="373.865">120</text>
# </g>
# <g clip-path="url(#clip1200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 490.614, 373.865)" x="490.614" y="373.865">150</text>
# </g>
# <g clip-path="url(#clip1200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 580.315, 373.865)" x="580.315" y="373.865">180</text>
# </g>
# <g clip-path="url(#clip1200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 36.1066, 364.565)" x="36.1066" y="364.565">0</text>
# </g>
# <g clip-path="url(#clip1200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 36.1066, 293.354)" x="36.1066" y="293.354">500</text>
# </g>
# <g clip-path="url(#clip1200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 36.1066, 222.143)" x="36.1066" y="222.143">1000</text>
# </g>
# <g clip-path="url(#clip1200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 36.1066, 150.931)" x="36.1066" y="150.931">1500</text>
# </g>
# <g clip-path="url(#clip1200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 36.1066, 79.7199)" x="36.1066" y="79.7199">2000</text>
# </g>
# <g clip-path="url(#clip1200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(0, 311.211, 18)" x="311.211" y="18">Polar angles of photons</text>
# </g>
# <g clip-path="url(#c

# %%
polAngle(v) = 180/π*acos(v[4]/v[1])
histogram2d(
    vcat([[polAngle(treeR2[i,g]) for i=1:size(treeR2,1)] for g in [:G1, :G2, :G3, :G4]]...),
    vcat([[treeR2[i,g][1] for i=1:size(treeR2,1)] for g in [:G1, :G2, :G3, :G4]]...),
    bins=50,
    lab = "", title = "Angle-Energy correlation for photons",
    xlab = "theta (deg.)", ylab = "E (GeV)")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip4000)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip4000)" points="
# 47.9701,360.065 580.315,360.065 580.315,31.4961 47.9701,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="47" y="31" width="473" height="330"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip4002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   47.9701,355.137 47.9701,36.4246
#   "/>
# <polyline clip-path="url(#clip4002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   126.694,355.137 126.694,36.4246
#   "/>
# <polyline clip-path="url(#clip4002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   205.418,355.137 205.418,36.4246
#   "/>
# <polyline clip-path="url(#clip4002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   284.143,355.137 284.143,36.4246
#   "/>
# <polyline clip-path="url(#clip4002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   362.867,355.137 362.867,36.4246
#   "/>
# <polyline clip-path="url(#clip4002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   441.591,355.137 441.591,36.4246
#   "/>
# <polyline clip-path="url(#clip4002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   520.315,355.137 520.315,36.4246
#   "/>
# <polyline clip-path="url(#clip4002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   55.0553,360.065 513.23,360.065
#   "/>
# <polyline clip-path="url(#clip4002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   55.0553,257.387 513.23,257.387
#   "/>
# <polyline clip-path="url(#clip4002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   55.0553,154.71 513.23,154.71
#   "/>
# <polyline clip-path="url(#clip4002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   55.0553,52.0316 513.23,52.0316
#   "/>
# <polyline clip-path="url(#clip4000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   47.9701,360.065 520.315,360.065
#   "/>
# <polyline clip-path="url(#clip4000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   47.9701,360.065 47.9701,31.4961
#   "/>
# <polyline clip-path="url(#clip4000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   47.9701,360.065 47.9701,355.137
#   "/>
# <polyline clip-path="url(#clip4000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   126.694,360.065 126.694,355.137
#   "/>
# <polyline clip-path="url(#clip4000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   205.418,360.065 205.418,355.137
#   "/>
# <polyline clip-path="url(#clip4000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   284.143,360.065 284.143,355.137
#   "/>
# <polyline clip-path="url(#clip4000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   362.867,360.065 362.867,355.137
#   "/>
# <polyline clip-path="url(#clip4000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   441.591,360.065 441.591,355.137
#   "/>
# <polyline clip-path="url(#clip4000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   520.315,360.065 520.315,355.137
#   "/>
# <polyline clip-path="url(#clip4000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   47.9701,360.065 55.0553,360.065
#   "/>
# <polyline clip-path="url(#clip4000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   47.9701,257.387 55.0553,257.387
#   "/>
# <polyline clip-path="url(#clip4000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   47.9701,154.71 55.0553,154.71
#   "/>
# <polyline clip-path="url(#clip4000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   47.9701,52.0316 55.0553,52.0316
#   "/>
# <g clip-path="url(#clip4000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 47.9701, 373.865)" x="47.9701" y="373.865">0</text>
# </g>
# <g clip-path="url(#clip4000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 126.694, 373.865)" x="126.694" y="373.865">30</text>
# </g>
# <g clip-path="url(#clip4000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 205.418, 373.865)" x="205.418" y="373.865">60</text>
# </g>
# <g clip-path="url(#clip4000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 284.143, 373.865)" x="284.143" y="373.865">90</text>
# </g>
# <g clip-path="url(#clip4000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 362.867, 373.865)" x="362.867" y="373.865">120</text>
# </g>
# <g clip-path="url(#clip4000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 441.591, 373.865)" x="441.591" y="373.865">150</text>
# </g>
# <g clip-path="url(#clip4000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 520.315, 373.865)" x="520.315" y="373.865">180</text>
# </g>
# <g clip-path="url(#clip4000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 41.9701, 364.565)" x="41.9701" y="364.565">0.0</text>
# </g>
# <g clip-path="url(#clip4000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 41.9701, 261.887)" x="41.9701" y="261.887">0.5</text>
# </g>
# <g clip-path="url(#clip4000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 41.9701, 159.21)" x="41.9701" y="159.21">1.0</text>
# </g>
# <g clip-path="url(#clip4000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 41.9701, 56.5316)" x="41.9701" y="56.5316">1.5</text>
# </g>
# <g clip-path="url(#clip4000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(0, 284.143, 18)" x="284.143" y="18">Angle-Energy correlation for photons</text>
# </g>
# <g clip-path="url(#clip4000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(0, 284.143, 397.6)" x="284.143" y="397.6">theta (deg.)</text>
# </g>
# <g clip-path="url(#clip4000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(-90, 14.4, 195.781)" x="14.4" y="195.781">E (GeV)</text>
# </g>
# <g clip-path="url(#clip4002)">
# <image width="472" height="329" xlink:href="data:

# %%
s1s2set = [invariants(
        treeR2[i,:C1],
        treeR2[i,:M1]+treeR2[i,:M2],
        treeR2[i,:C2]) for i=1:size(treeR2,1)]
histogram2d(
    [s1s2set[i][1] for i=1:length(s1s2set)],
    [s1s2set[i][2] for i=1:length(s1s2set)], bins=40,
    xlab="mJpsiPi", ylab="mJpsiPi", title="JpsiPiPi Dalitz plot")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip1400)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip1400)" points="
# 44.6753,360.065 580.315,360.065 580.315,31.4961 44.6753,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="44" y="31" width="477" height="330"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip1402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   137.483,355.137 137.483,36.4246
#   "/>
# <polyline clip-path="url(#clip1402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   253.493,355.137 253.493,36.4246
#   "/>
# <polyline clip-path="url(#clip1402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   369.502,355.137 369.502,36.4246
#   "/>
# <polyline clip-path="url(#clip1402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   485.512,355.137 485.512,36.4246
#   "/>
# <polyline clip-path="url(#clip1402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   51.8099,294.352 513.18,294.352
#   "/>
# <polyline clip-path="url(#clip1402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   51.8099,212.209 513.18,212.209
#   "/>
# <polyline clip-path="url(#clip1402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   51.8099,130.067 513.18,130.067
#   "/>
# <polyline clip-path="url(#clip1402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   51.8099,47.9245 513.18,47.9245
#   "/>
# <polyline clip-path="url(#clip1400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   44.6753,360.065 520.315,360.065
#   "/>
# <polyline clip-path="url(#clip1400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   44.6753,360.065 44.6753,31.4961
#   "/>
# <polyline clip-path="url(#clip1400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   137.483,360.065 137.483,355.137
#   "/>
# <polyline clip-path="url(#clip1400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   253.493,360.065 253.493,355.137
#   "/>
# <polyline clip-path="url(#clip1400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   369.502,360.065 369.502,355.137
#   "/>
# <polyline clip-path="url(#clip1400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   485.512,360.065 485.512,355.137
#   "/>
# <polyline clip-path="url(#clip1400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   44.6753,294.352 51.8099,294.352
#   "/>
# <polyline clip-path="url(#clip1400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   44.6753,212.209 51.8099,212.209
#   "/>
# <polyline clip-path="url(#clip1400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   44.6753,130.067 51.8099,130.067
#   "/>
# <polyline clip-path="url(#clip1400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   44.6753,47.9245 51.8099,47.9245
#   "/>
# <g clip-path="url(#clip1400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 137.483, 373.865)" x="137.483" y="373.865">12</text>
# </g>
# <g clip-path="url(#clip1400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 253.493, 373.865)" x="253.493" y="373.865">14</text>
# </g>
# <g clip-path="url(#clip1400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 369.502, 373.865)" x="369.502" y="373.865">16</text>
# </g>
# <g clip-path="url(#clip1400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 485.512, 373.865)" x="485.512" y="373.865">18</text>
# </g>
# <g clip-path="url(#clip1400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 38.6753, 298.852)" x="38.6753" y="298.852">12</text>
# </g>
# <g clip-path="url(#clip1400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 38.6753, 216.709)" x="38.6753" y="216.709">14</text>
# </g>
# <g clip-path="url(#clip1400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 38.6753, 134.567)" x="38.6753" y="134.567">16</text>
# </g>
# <g clip-path="url(#clip1400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 38.6753, 52.4245)" x="38.6753" y="52.4245">18</text>
# </g>
# <g clip-path="url(#clip1400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(0, 282.495, 18)" x="282.495" y="18">JpsiPiPi Dalitz plot</text>
# </g>
# <g clip-path="url(#clip1400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(0, 282.495, 397.6)" x="282.495" y="397.6">mJpsiPi</text>
# </g>
# <g clip-path="url(#clip1400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(-90, 14.4, 195.781)" x="14.4" y="195.781">mJpsiPi</text>
# </g>
# <g clip-path="url(#clip1402)">
# <image width="476" height="329" xlink:href="data:;base64,
# iVBORw0KGgoAAAANSUhEUgAAAdwAAAFJCAYAAAAxCJwFAAANoElEQVR4nO3da5DWd3XA8T+bZdns
# PtwvGyBcLAihGLkq1MiYC2GMCdFoaoNOTVutzECLY6bTTnqxY6udzujkhcngRHHaknYc4h0xWMow
# xJTEWGLCJJGEbrIBskDALLB5dgMsIX3baav+ToXDLvv5vD5z8kjI8/X/4jz/IVsWrXqzCtjwn2Mj
# 49Xm+j8Wz547Vx8SWg4AA0TDxf4AADAYCC4AJBBcAEgguACQQHABIIHgAkACwQWABIILAAmG3FRb
# E/rhi88teTH0Dzh8YnTx7O1P7wrtPnXmgB/KAGBA8IQLAAkEFwASCC4AJBBcAEgguACQQHABIIHg
# AkCCIQ0NtdAdbsftc0L/gMamvuLZ7uMjQ7tXPhybb69vdrcLwEXhCRcAEgguACQQXABIILgAkEBw
# ASCB4AJAAsEFgAThu9RFLR8L3e1++5a9xbOTN30q9FlOrvlsaH7+A9OKZw/Wt7vZBeC88YQLAAkE
# FwASCC4AJBBcAEgguACQQHABIIHgAkCCC35ruv/D7yi+2428O7eqqurI4StC8zv3v6V49stHOkO7
# vWsXgF/GEy4AJBBcAEgguACQQHABIIHgAkACwQWABIILAAkEFwASXPAfaxjTsqD4hy+evKUxtLs2
# 9kRo/uiBScWzTx2YHtq9saO1eHZrfb0fyQAYZDzhAkACwQWABIILAAkEFwASCC4AJBBcAEgguACQ
# oF/dg35i/Lrim92qqqqPz3kxtP8dn3q0eLZz04zQ7kkrni6eXbruw6HdT/Ru7Ff/ngCI84QLAAkE
# FwASCC4AJBBcAEgguACQQHABIIHgAkCCfnXf2dBQC93hbl6wMrT/vZ/eXDz75qk3Qrv7DtaKZw/t
# mRXafee2OaH5Xb1f61f/XgHwhAsAKQQXABIILgAkEFwASCC4AJBAcAEggeACQIIBfa+5ti32/tzP
# 3Ly9eLZl/InQZznT3Vo8O3zuwdDuc93DQvO3/d1Hi2e31tcP6L8DAAOFJ1wASCC4AJBAcAEggeAC
# QALBBYAEggsACQQXABIILgAkGFQ/ehD5oYzPr/peaPeenywsnl247PHQ7n273x6aj/jA42dD8wfr
# 2wfV3xmA88UTLgAkEFwASCC4AJBAcAEggeACQALBBYAEggsACQbVTWVDQ634Dvfw700N7T5VL38B
# /cmTI0K7Z694LDR/5uio4tmujsmh3Tc8NLF4tr2+eVD9/QL4ZTzhAkACwQWABIILAAkEFwASCC4A
# JBBcAEgguACQwJ3kL9DW+q7im92qqqqHlpbf1rY0vx76LNO+2BSaP3R3T/Hs5bXe0O7WcceLZxdv
# mBfa7W4XuJR5wgWABIILAAkEFwASCC4AJBBcAEgguACQQHABIIG7x/Pkn+b+QfHd7u989Fuh3ZdN
# OB2a3/uNa4pnWy6P3QQPH3OifHbK0dDud37x+tD8Mz0P+vsLDBiecAEggeACQALBBYAEggsACQQX
# ABIILgAkEFwASOCO8TxpvGxc8R1u91/Gdu/fPTc0P6btWPHsK50TQ7vnrNtbPLv/q9NDu8dN7wzN
# r9pwc/Hs1vp6f9eBi8oTLgAkEFwASCC4AJBAcAEggeACQALBBYAEggsACQQXABL4MY

# %%
s1s2set = [invariants(
        treeR2[i,:M1]+treeR2[i,:M2]+treeR2[i,:C1]+treeR2[i,:C2],
        treeR2[i,:G1]+treeR2[i,:G2],
        treeR2[i,:G3]+treeR2[i,:G4],) for i=1:size(treeR2,1)]
histogram2d(
    [s1s2set[i][1] for i=1:length(s1s2set)],
    [s1s2set[i][2] for i=1:length(s1s2set)], bins=40,
    xlab="ZcPi (GeV)", ylab="PiPi (GeV)", title="ZcPiPi Dalitz plot")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip1600)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip1600)" points="
# 61.1494,360.065 580.315,360.065 580.315,31.4961 61.1494,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="61" y="31" width="460" height="330"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip1602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   93.9469,355.137 93.9469,36.4246
#   "/>
# <polyline clip-path="url(#clip1602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   203.272,355.137 203.272,36.4246
#   "/>
# <polyline clip-path="url(#clip1602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   312.597,355.137 312.597,36.4246
#   "/>
# <polyline clip-path="url(#clip1602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   421.922,355.137 421.922,36.4246
#   "/>
# <polyline clip-path="url(#clip1602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   68.0369,313.127 513.427,313.127
#   "/>
# <polyline clip-path="url(#clip1602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   68.0369,219.25 513.427,219.25
#   "/>
# <polyline clip-path="url(#clip1602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   68.0369,125.373 513.427,125.373
#   "/>
# <polyline clip-path="url(#clip1602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   68.0369,31.4961 513.427,31.4961
#   "/>
# <polyline clip-path="url(#clip1600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   61.1494,360.065 520.315,360.065
#   "/>
# <polyline clip-path="url(#clip1600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   61.1494,360.065 61.1494,31.4961
#   "/>
# <polyline clip-path="url(#clip1600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   93.9469,360.065 93.9469,355.137
#   "/>
# <polyline clip-path="url(#clip1600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   203.272,360.065 203.272,355.137
#   "/>
# <polyline clip-path="url(#clip1600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   312.597,360.065 312.597,355.137
#   "/>
# <polyline clip-path="url(#clip1600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   421.922,360.065 421.922,355.137
#   "/>
# <polyline clip-path="url(#clip1600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   61.1494,313.127 68.0369,313.127
#   "/>
# <polyline clip-path="url(#clip1600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   61.1494,219.25 68.0369,219.25
#   "/>
# <polyline clip-path="url(#clip1600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   61.1494,125.373 68.0369,125.373
#   "/>
# <polyline clip-path="url(#clip1600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   61.1494,31.4961 68.0369,31.4961
#   "/>
# <g clip-path="url(#clip1600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 93.9469, 373.865)" x="93.9469" y="373.865">21.0</text>
# </g>
# <g clip-path="url(#clip1600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 203.272, 373.865)" x="203.272" y="373.865">21.5</text>
# </g>
# <g clip-path="url(#clip1600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 312.597, 373.865)" x="312.597" y="373.865">22.0</text>
# </g>
# <g clip-path="url(#clip1600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 421.922, 373.865)" x="421.922" y="373.865">22.5</text>
# </g>
# <g clip-path="url(#clip1600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 55.1494, 317.627)" x="55.1494" y="317.627">0.10</text>
# </g>
# <g clip-path="url(#clip1600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 55.1494, 223.75)" x="55.1494" y="223.75">0.15</text>
# </g>
# <g clip-path="url(#clip1600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 55.1494, 129.873)" x="55.1494" y="129.873">0.20</text>
# </g>
# <g clip-path="url(#clip1600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 55.1494, 35.9961)" x="55.1494" y="35.9961">0.25</text>
# </g>
# <g clip-path="url(#clip1600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(0, 290.732, 18)" x="290.732" y="18">ZcPiPi Dalitz plot</text>
# </g>
# <g clip-path="url(#clip1600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(0, 290.732, 397.6)" x="290.732" y="397.6">ZcPi (GeV)</text>
# </g>
# <g clip-path="url(#clip1600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(-90, 14.4, 195.781)" x="14.4" y="195.781">PiPi (GeV)</text>
# </g>
# <g clip-path="url(#clip1602)">
# <image width="459" height="329" xlink:href="data:;base64,
# iVBORw0KGgoAAAANSUhEUgAAAcsAAAFJCAYAAAD0egaUAAAYk0lEQVR4nO3dbbDW5WEm8D87wCGH
# lyN4zgEGEVaQFz24rUgSzGFjYd2xJlpKfctsdibxpTJW0zGNNVlWdzJdJ626Y9cmrq3G6OpM1fjC
# moxxq1jNIaEpEqcC8iJsRLTA4YAcQJYDrt0vux/2033dDs+q7e/3+ZrbPw/P81w+H+6LYQ38kzD8
# H1px6uL2q+LsslPyc7/x5k/i7NFjbw3LTwY+jH/2UT8AAHzcKUsAKFCWAFCgLAGgQFkCQIGyBIAC
# ZQkABcoSAAqUJQAUWP6g5SaOPjdez7llyrz43Kfezp/hL/71+jj7q11T4uzKNyfH2aXTd8XZ1bsn
# xtneSXvibI3vrJ8QZ/uHvRtnN7z3uO8dPnH8sgSAAmUJAAXKEgAKlCUAFChLAChQlgBQoCwBoEBZ
# AkCBy8H8P35v4tfiAYHe7sET/t+f1Z1fsD9l2ltxtr3rQJx96OmL4mxf/8g429mWf9w6R30QZ7va
# jsfZk9uOxtl9Q6Pi7KbBtjj78uHdcXbb8b+JckePveW7jJbyyxIACpQlABQoSwAoUJYAUKAsAaBA
# WQJAgbIEgAJlCQAFyhIACoZ/1A/AhzNx9Lnx0s4lY86Jz71x4Stx9rnX50W5hVN3xGeu2Tktzs4+
# PDbOrt49Mc727c0XcZadcizOXtrbF2ff3nFqnN3fotfh4pnb4mzT5H9vV/YcjLNb+38jym0+ODb+
# PPzJrmfi/75lIP4vvywBoEBZAkCBsgSAAmUJAAXKEgAKlCUAFChLAChQlgBQ4MLtx8iokafGF6t/
# 9Oufic+tuYjeO2lPnB040h5nU6v7O+Ls0um74uyWdyfE2eW3PhJn/+4Hi+Jsq9y+7vSWnDunI347
# NtcteTHOvrh2QZzdNzQqytUMX9SMONy4If+K3PDe475P/xHzyxIACpQlABQoSwAoUJYAUKAsAaBA
# WQJAgbIEgAJlCQAFLtG22MTR58Y3u88bMT8+d++xY3H2joX5he01O/N/8X7TYFuU6+0ejM+8b3t2
# Cb1pmuaaGUfj7G3/43/G2RWnfaol5666fEOcfW3jmXG2ZnBh79CIOHvxzG1x9pltM+NsjXQkoxUD
# GU3TNJ3tR+Lsyjcnx9nv7bnbd+8njF+WAFCgLAGgQFkCQIGyBIACZQkABcoSAAqUJQAUKEsAKFCW
# AFBgReJDWNx+bbzK0zVyZHzuou58leept+No0z/s3TjbipWZmoWZdBWoaZrmyp6tcXb+qhfi7KGb
# u+Pskb0nxdmaVZ6aRZqalZlWLd2s7u+Is3M7huJs+n5YOn1XfOY/n/xOnP3VrilxdvXuiXF2zrhD
# cfarW/46zh499pbv9BbxyxIACpQlABQoSwAoUJYAUKAsAaBAWQJAgbIEgAJlCQAFLrD+HxNHnxsP
# Dfzs/Pzch189O84OHM3/3+X7766Ms3dO/80429efjyhsPL4nyn1+zKT4zBsXvhJnP/d8HG1umTIv
# ztYMI9RcsJ89fn+crRlyuPedfHTirp74bV51yf4bVzwVZ+98dFmcTd383JY4e9N5c0/4f79pmqa3
# ezDOrtw5Ls52tuVf09/bc0+cbZr3ff9X8MsSAAqUJQAUKEsA

# %%
histogram((
    [treeR2[i,:C1][1] for i=1:size(treeR2,1)],
    [treeR2[i,:C2][1] for i=1:size(treeR2,1)]), bins=100,
    lab = "", title = "Energy spectrum of change pions", xlab = "E (GeV)")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip1800)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip1800)" points="
# 35.5169,360.065 580.315,360.065 580.315,31.4961 35.5169,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="35" y="31" width="546" height="330"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip1802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   41.0519,355.137 41.0519,36.4246
#   "/>
# <polyline clip-path="url(#clip1802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   139.89,355.137 139.89,36.4246
#   "/>
# <polyline clip-path="url(#clip1802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   238.729,355.137 238.729,36.4246
#   "/>
# <polyline clip-path="url(#clip1802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   337.568,355.137 337.568,36.4246
#   "/>
# <polyline clip-path="url(#clip1802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   436.406,355.137 436.406,36.4246
#   "/>
# <polyline clip-path="url(#clip1802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   535.245,355.137 535.245,36.4246
#   "/>
# <polyline clip-path="url(#clip1802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   43.6889,360.065 572.143,360.065
#   "/>
# <polyline clip-path="url(#clip1802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   43.6889,295.892 572.143,295.892
#   "/>
# <polyline clip-path="url(#clip1802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   43.6889,231.718 572.143,231.718
#   "/>
# <polyline clip-path="url(#clip1802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   43.6889,167.544 572.143,167.544
#   "/>
# <polyline clip-path="url(#clip1802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   43.6889,103.371 572.143,103.371
#   "/>
# <polyline clip-path="url(#clip1802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   43.6889,39.1969 572.143,39.1969
#   "/>
# <polyline clip-path="url(#clip1800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.5169,360.065 580.315,360.065
#   "/>
# <polyline clip-path="url(#clip1800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.5169,360.065 35.5169,31.4961
#   "/>
# <polyline clip-path="url(#clip1800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   41.0519,360.065 41.0519,355.137
#   "/>
# <polyline clip-path="url(#clip1800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   139.89,360.065 139.89,355.137
#   "/>
# <polyline clip-path="url(#clip1800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   238.729,360.065 238.729,355.137
#   "/>
# <polyline clip-path="url(#clip1800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   337.568,360.065 337.568,355.137
#   "/>
# <polyline clip-path="url(#clip1800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   436.406,360.065 436.406,355.137
#   "/>
# <polyline clip-path="url(#clip1800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   535.245,360.065 535.245,355.137
#   "/>
# <polyline clip-path="url(#clip1800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.5169,360.065 43.6889,360.065
#   "/>
# <polyline clip-path="url(#clip1800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.5169,295.892 43.6889,295.892
#   "/>
# <polyline clip-path="url(#clip1800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.5169,231.718 43.6889,231.718
#   "/>
# <polyline clip-path="url(#clip1800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.5169,167.544 43.6889,167.544
#   "/>
# <polyline clip-path="url(#clip1800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.5169,103.371 43.6889,103.371
#   "/>
# <polyline clip-path="url(#clip1800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.5169,39.1969 43.6889,39.1969
#   "/>
# <g clip-path="url(#clip1800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 41.0519, 373.865)" x="41.0519" y="373.865">0</text>
# </g>
# <g clip-path="url(#clip1800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 139.89, 373.865)" x="139.89" y="373.865">1</text>
# </g>
# <g clip-path="url(#clip1800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 238.729, 373.865)" x="238.729" y="373.865">2</text>
# </g>
# <g clip-path="url(#clip1800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 337.568, 373.865)" x="337.568" y="373.865">3</text>
# </g>
# <g clip-path="url(#clip1800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 436.406, 373.865)" x="436.406" y="373.865">4</text>
# </g>
# <g clip-path="url(#clip1800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 535.245, 373.865)" x="535.245" y="373.865">5</text>
# </g>
# <g clip-path="url(#clip1800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.5169, 364.565)" x="29.5169" y="364.565">0</text>
# </g>
# <g clip-path="url(#clip1800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.5169, 300.392)" x="29.5169" y="300.392">50</text>
# </g>
# <g clip-path="url(#clip1800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.5169, 236.218)" x="29.5169" y="236.218">100</text>
# </g>
# <g clip-path="url(#clip1800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.5169, 172.044)" x="29.5169" y="172.044">150</text>
# </g>
# <g clip-path="url(#clip1800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.5169, 107.871)" x="29.5169" y="107.871">200</text>
# </g>
# <g clip-path="url(#clip1800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.5169, 43.6969)" x="29.5169" y="43.6969">250</text>
# </g>
# <g clip-path="url(#clip1800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(0, 307.916, 18)" x="307.916" y="18">Energy spectrum of change pions</text>
# </g>
# <g clip-path="url(#clip1800)">
# <
