# %%
using QuadGK
using Plots
using GSL
using Cuba
# Out:
# INFO: Recompiling stale cache file /home/mikhasenko/.julia/lib/v0.6/GSL.ji for module GSL.
#
# WARNING: deprecated syntax "abstract Integrand{T}" at /home/mikhasenko/.julia/v0.6/Cuba/src/Cuba.jl:122.
# Use "abstract type Integrand{T} end" instead.
# INFO: Precompiling module Cuba.
#
# WARNING: deprecated syntax "abstract Integrand{T}" at /home/mikhasenko/.julia/v0.6/Cuba/src/Cuba.jl:122.
# Use "abstract type Integrand{T} end" instead.

# %% [markdown]
# ### Isobar function
# Introduce basic functions $\lambda$ and isobar shape

# %%
f1(0.7755^2)
# Out:
# 0.14902797196922707
# 0.0 + 70.28135507658997im

# %%
λ(x,y,z) = x^2+y^2+z^2-2*x*y-2*y*z-2*z*x
function f1(s)
    mρ = 0.7755;
    Γρ = 0.15;
    mπ = 0.139;
    R = 5;
    p = sqrt(λ(mπ^2,mπ^2,s)/(4*s));
    gsq = 2.85^2
    ρ = 1/(8*π)*2*p/sqrt(s)
    mΓ = gsq*ρ/2*p^2/(1./R^2+p^2)
#    print(mΓ/mρ)
    return gsq/(mρ^2-s-1im*mΓ) # *p/sqrt(1./R^2+p^2);
end
function f0(s)
    mσ = 0.8;
    mπ = 0.139;
    gsq = 5.2^2
    ρ = 1/(8*π)*sqrt(λ(mπ^2,mπ^2,s))/s
    mΓ = gsq*ρ/2
    return gsq/(mσ^2-s-1im*mΓ);
end
pl = plot(layout = 2)
plot!(pl[1], e->real(f1(e^2)),0.3,1.4)
plot!(pl[1], e->imag(f1(e^2)),0.3,1.4)
plot!(pl[2], e->real(f0(e^2)),0.3,1.4)
plot!(pl[2], e->imag(f0(e^2)),0.3,1.4)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip5100)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip5100)" points="
# 35.8488,375.813 280.315,375.813 280.315,11.811 35.8488,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="35" y="11" width="245" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip5102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   57.2559,370.353 57.2559,17.2711
#   "/>
# <polyline clip-path="url(#clip5102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   102.5,370.353 102.5,17.2711
#   "/>
# <polyline clip-path="url(#clip5102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   147.745,370.353 147.745,17.2711
#   "/>
# <polyline clip-path="url(#clip5102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   192.989,370.353 192.989,17.2711
#   "/>
# <polyline clip-path="url(#clip5102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   238.233,370.353 238.233,17.2711
#   "/>
# <polyline clip-path="url(#clip5102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   39.5158,329.37 276.648,329.37
#   "/>
# <polyline clip-path="url(#clip5102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   39.5158,259.073 276.648,259.073
#   "/>
# <polyline clip-path="url(#clip5102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   39.5158,188.775 276.648,188.775
#   "/>
# <polyline clip-path="url(#clip5102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   39.5158,118.478 276.648,118.478
#   "/>
# <polyline clip-path="url(#clip5102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   39.5158,48.1805 276.648,48.1805
#   "/>
# <polyline clip-path="url(#clip5100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8488,375.813 280.315,375.813
#   "/>
# <polyline clip-path="url(#clip5100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8488,375.813 35.8488,11.811
#   "/>
# <polyline clip-path="url(#clip5100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   57.2559,375.813 57.2559,370.353
#   "/>
# <polyline clip-path="url(#clip5100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   102.5,375.813 102.5,370.353
#   "/>
# <polyline clip-path="url(#clip5100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   147.745,375.813 147.745,370.353
#   "/>
# <polyline clip-path="url(#clip5100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   192.989,375.813 192.989,370.353
#   "/>
# <polyline clip-path="url(#clip5100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   238.233,375.813 238.233,370.353
#   "/>
# <polyline clip-path="url(#clip5100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8488,329.37 39.5158,329.37
#   "/>
# <polyline clip-path="url(#clip5100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8488,259.073 39.5158,259.073
#   "/>
# <polyline clip-path="url(#clip5100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8488,188.775 39.5158,188.775
#   "/>
# <polyline clip-path="url(#clip5100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8488,118.478 39.5158,118.478
#   "/>
# <polyline clip-path="url(#clip5100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8488,48.1805 39.5158,48.1805
#   "/>
# <g clip-path="url(#clip5100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 57.2559, 389.613)" x="57.2559" y="389.613">0.4</text>
# </g>
# <g clip-path="url(#clip5100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 102.5, 389.613)" x="102.5" y="389.613">0.6</text>
# </g>
# <g clip-path="url(#clip5100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 147.745, 389.613)" x="147.745" y="389.613">0.8</text>
# </g>
# <g clip-path="url(#clip5100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 192.989, 389.613)" x="192.989" y="389.613">1.0</text>
# </g>
# <g clip-path="url(#clip5100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 238.233, 389.613)" x="238.233" y="389.613">1.2</text>
# </g>
# <g clip-path="url(#clip5100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.8488, 333.87)" x="29.8488" y="333.87">-20</text>
# </g>
# <g clip-path="url(#clip5100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.8488, 263.573)" x="29.8488" y="263.573">0</text>
# </g>
# <g clip-path="url(#clip5100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.8488, 193.275)" x="29.8488" y="193.275">20</text>
# </g>
# <g clip-path="url(#clip5100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.8488, 122.978)" x="29.8488" y="122.978">40</text>
# </g>
# <g clip-path="url(#clip5100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.8488, 52.6805)" x="29.8488" y="52.6805">60</text>
# </g>
# <polyline clip-path="url(#clip5102)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.8488,202.897 37.0639,202.534 48.299,198.699 59.5342,193.819 66.2861,190.226 73.038,185.996 78.7466,181.811 84.4552,176.95 90.6564,170.753 96.8576,163.424
#   102.575,155.538 108.291,146.593 111.356,141.486 114.421,136.362 117.485,131.547 120.55,127.614 122.325,126.096 124.1,125.457 124.988,125.571 125.876,126.04
#   126.763,126.921 127.651,128.274 128.539,130.167 129.426,132.667 130.314,135.848 131.202,139.779 132.089,144.529 132.977,150.16 133.865,156.72 134.752,164.242
#   135.541,171.744 136.33,180.006 137.119,188.997 137.908,198.666 139.485,219.728 141.063,242.359 142.641,265.481 144.218,287.922 145.007,298.546 145.796,308.617
#   146.585,318.043 147.374,326.756 148.065,333.773 148.757,340.186 149.449,345.991 150.141,351.192 150.832,355.801 151.524,359.84 152.216,363.335 152.908,366.316
#   154.291,370.874 155.675,373.793 157.058,375.353 158.442,375.813 159.95,375.33 161.458,374.064 162.967,372.221 164.475,369.966 167.492,364.71 170.509,359.017
#   176.578,347.711 182.647,337.582 189.358,328.06 196.068,320.137 202.453,313.834 208.838,308.509 215.476,303.808 222.115,299.797 227.704,296.857 233.292,294.252
#   246.937,288.998 259.765,285.14 280.315,280.446
#   "/>
# <polyline clip-path="url(#clip5102)" style="stroke:#e26f46; stroke-width:1; stroke-opacity:1; fill:none" points="

# %% [markdown]
# ### Basic functions II:
#  * Clebsch-Gordon coefficient
#  * Wigner-D and Winber-d
#  * Function Z which will be used as basis angular further

# %%
# Clebsches and d-function
function ClebschGordon(j1,m1,j2,m2,j,m)
    factor = (j1+j2-m)%2==1 ? -1 : 1
    factor*sqrt(2*j+1)*sf_coupling_3j(2*j1,2*j2,2*j,2*m1,2*m2,-2*m)
end

function Wignerd(j,m1,m2,cosθ)
    M1=m1; M2=m2; factor=1;
    if (m1==0 && m2!=0)
        factor *= (abs(m2)%2==1 ? -1 : 1)
        M1=m2;M2=m1;
    end
    factor *= (M1 < 0) ? (abs(M1)%2==1 ? -1 : 1) : 1
    (M2 == 0) && return factor*sqrt(4*π/(2*j+1))*sf_legendre_sphPlm(j, abs(M1), cosθ)
end
function Wignerd(j,m1,m2,cosθ,ϕ)
    Wignerd(j,m1,m2,cosθ)*cis(-m1*ϕ)
end

function Z(J,M,L,l,cosθ1,ϕ1,cosθ23,ϕ23)
    rng_lm = min(l,J);
    sum([ClebschGordon(L,0,l,lm,J,lm)*sqrt((2*L+1)*(2*l+1))/(4π)*
        Wignerd(J,M,lm,cosθ1,ϕ1)*Wignerd(l,lm,0,cosθ23,ϕ23) for lm=-rng_lm:1:rng_lm])
end
# Out:
# Z (generic function with 1 method)

# %% [markdown]
# Check if integral my `Z` function are properly normalized

# %%
function integrand(x, f)
    res = (4*π)^2*Z(1,0,2,1,
        2*x[1]-1,2*π*x[2],2*x[3]-1,2*π*x[4])*
            conj(Z(1,0,2,1,
        2*x[1]-1,2*π*x[2],2*x[3]-1,2*π*x[4]))
    f[1],f[2] = reim(res)
end
result = cuhre(integrand, 4, 2)
# Out:
# Components:
#  1: 0.9999992605315885 ± 9.961372177491495e-5 (prob.: 0.0)
#  2: 0.0 ± 2.242989226691107e-17 (prob.: 0.0)
# Integrand evaluations: 29835
# Fail:                  0
# Number of subregions:  98

# %% [markdown]
# ### Change of basis
# Very important function which changes the basis from
# `(s1,cosθ1,ϕ1,cosθ23,ϕ23)` to `(s3,cosθ3,ϕ3,cosθ12,ϕ12)` by given masses and total energy
#
# I reimplement the fucntion which I previously wrote in c++ (see `wavefitter`-repository: `src/M3bodyAngularBasis.cc`)

# %%
function change_basis(s1,cosθ1,ϕ1,cosθ23,ϕ23,m1sq,m2sq,m3sq,s)
    # calculate s3 in (23) frame
    s3 = m1sq + m2sq +
    # 2*(  E2 * E1 -
        2*( (s1 + m2sq - m3sq)/(2*sqrt(s1)) * (s-m1sq-s1)/(2*sqrt(s1)) -
        # |p2|*cos(theta23) * (-|p1|)
        sqrt(λ(s1, m2sq, m3sq)/(4*s1))*cosθ23 * (-sqrt(λ(s, m1sq, s1)/(4*s1))) );
    # caluclate p3 in (23) frame
    p23bu = sqrt(λ(s1, m2sq, m3sq)/(4*s1));
    p3_in23 = [(s1 + m3sq - m2sq)/sqrt(4*s1),
               -p23bu*sqrt(1-cosθ23^2)*cos(ϕ23),
               -p23bu*sqrt(1-cosθ23^2)*sin(ϕ23),
               -p23bu*cosθ23];
    γ1 = (s + s1 - m1sq)/sqrt(4*s*s1);
    β1 = sqrt(1.-1./γ1^2);
    p3_b = [γ1*(p3_in23[1]+β1*p3_in23[4]),
            p3_in23[2],
            p3_in23[4],
            γ1*(β1*p3_in23[1]+p3_in23[4])];

    ct = cosθ1; st = sqrt(1.-cosθ1^2); cp = cos(ϕ1); sp = sin(ϕ1);
    # Rz(phi1) * Ry(theta1) * p3_boost
    p3_rot = [p3_b[1],
              cp*ct* p3_b[2] + (-sp)* p3_b[3] + cp*st* p3_b[4],
              sp*ct* p3_b[2] +   cp * p3_b[3] + sp*st* p3_b[4],
                -st* p3_b[2] +    0 * p3_b[3] +    ct* p3_b[4]];

    cosθ3 = - p3_rot[4]/sqrt(p3_rot[2]^2+p3_rot[3]^2+p3_rot[4]^2);
    ϕ3 = atan2(-p3_rot[3], -p3_rot[2]);

    cosθ12 = (s1 - m2sq - m3sq - 2* (s3+m2sq-m1sq)/(2*sqrt(s3)) * (s-m3sq-s3)/(2*sqrt(s3))) /
        (2 * sqrt(λ(s3, m1sq, m2sq)/(4*(s3))) * sqrt(λ(s, m3sq, s3)/(4*(s3))) );

    n1 = [0.,
         -sqrt(1.-cosθ1^2)*cos(ϕ1),
         -sqrt(1.-cosθ1^2)*sin(ϕ1),
         -cosθ1];
    ct = cosθ3; st = sqrt(1.-cosθ3^2); cp = cos(ϕ3); sp = sin(ϕ3);
    # Rz(phi23) * Ry(theta23) * p3_boost
    n1_rot = [n1[1],
              cp*ct* n1[2] + sp*ct* n1[3] + (-st)* n1[4],
              (-sp)* n1[2] +   cp * n1[3] +    0 * n1[4],
              cp*st* n1[2] + sp*st* n1[3] +    ct* n1[4]];
    ϕ12 = atan2(n1_rot[3], n1_rot[2]);
    return s3,cosθ3,ϕ3,cosθ12,ϕ12
end
change_basis(1.0,0.3,1.1,0.2,1.3,0.14^2,0.14^2,0.14^2,1.5)
# Out:
# (0.31687495721892145, -0.7207244428178856, 2.1547517323686503, 0.7580202408369665, 0.9877503525318634)

# %%
function integrand(x, f)
    res = (4*π)^2*Z(1,0,2,1,
        2*x[1]-1,2*π*x[2],2*x[3]-1,2*π*x[4])*
             conj(Z(1,0,2,1,
        2*x[1]-1,2*π*x[2],2*x[3]-1,2*π*x[4]))
#     mπ=0.139; s = 1.5;
#     s1=4*mπ^2+x[1]*((sqrt(s)-mπ)^2-4*mπ^2)
#     res *= sqrt(λ(s,s1,mπ^2)*λ(s1,mπ^2,mπ^2))/(s*s1)
#     res *= ((sqrt(s)-mπ)^2-4*mπ^2)
    f[1],f[2] = reim(res)
end
result = cuhre(integrand, 4, 2)
# result[1][1]
# Out:
# Components:
#  1: 0.9999992605315885 ± 9.961372177491495e-5 (prob.: 0.0)
#  2: 0.0 ± 2.242989226691107e-17 (prob.: 0.0)
# Integrand evaluations: 29835
# Fail:                  0
# Number of subregions:  98

# %%
function first_integral(s)
    function dPhiffs(x, f)
        mπ=0.139;
        s1=4*mπ^2+x[1]*((sqrt(s)-mπ)^2-4*mπ^2)
        res = sqrt(λ(s,s1,mπ^2)*λ(s1,mπ^2,mπ^2))/(s*s1)
        res *= ((sqrt(s)-mπ)^2-4*mπ^2)
        res *= abs(f1(s1))^2
        f[1] = res
    end
    result = cuhre(dPhiffs)
    result[1][1] / (4*π)^2 / (2*π) / (8*π)^2
end

function second_integral(s)
    function dPhiZ3fZ1sfs(x, f)
        mπ=0.139;
        s1=4*mπ^2+x[1]*((sqrt(s)-mπ)^2-4*mπ^2)
        # get variables for the system 3
#         y = (s1,2*x[2]-1,2*π*x[3],2*x[4]-1,2*π*x[5])
        τ1 = (s1,2*x[2]-1,2*π*x[3],2*x[4]-1,2*π*x[5])
        τ3 = change_basis(τ1[1],τ1[2],τ1[3],τ1[4],τ1[5],mπ^2,mπ^2,mπ^2,s);
        Z1v = Z(1,0,0,1,τ1[2],τ1[3],τ1[4],τ1[5]);
        Z3v = Z(1,0,0,1,τ3[2],τ3[3],τ3[4],τ3[5]);
        res = Z1v*f1(τ1[1])*conj(Z3v*f1(τ3[1]))
        #
        res *= sqrt(λ(s,s1,mπ^2)*λ(s1,mπ^2,mπ^2))/(s*s1)
        res *= ((sqrt(s)-mπ)^2-4*mπ^2)
        f[1] = real(res)
    end
    result = cuhre(dPhiZ3fZ1sfs, 5, 1)
    # as in Eq.(63)
    result[1][1] / (2*π) / (8*π)^2#abs(a1BW(s))^2*
end

function third_integral(s,σp,σ)
    mπ=0.139;
    (s < (sqrt(σ)+mπ)^2) && return 0;
    bord = 2*mπ^2+(σ+mπ^2-mπ^2)*(s-mπ^2-σ)/(2*σ)+
        sqrt(λ(σ,mπ^2,mπ^2)*λ(s,σ,mπ^2))/(2*σ)*[-1,1];
    (σp > bord[2] || σp < bord[1]) && return 0
    cosθ23 = ((2*σp)*(σ-2*mπ^2)-(σp+mπ^2-mπ^2)*(s-mπ^2-σp))/
        sqrt(λ(σp,mπ^2,mπ^2)*λ(s,σp,mπ^2));
    function integrand(x, f)
        τ1 = (σp,2*x[1]-1,2*π*x[2],cosθ23,2*π*x[3])
        τ3 = change_basis(τ1[1],τ1[2],τ1[3],τ1[4],τ1[5],mπ^2,mπ^2,mπ^2,s);
        (abs(τ3[1]-σ) > 0.001) && begin print("Error!! abs(τ3[1]-σ)",abs(τ3[1]-σ)," "); return 0 end
        Z1v = Z(1,0,0,1,τ1[2],τ1[3],τ1[4],τ1[5]);
        Z3v = Z(1,0,0,1,τ3[2],τ3[3],τ3[4],τ3[5]);
        res = Z1v*conj(Z3v)
        f[1] = real(res)
    end
    result = cuhre(integrand, 3, 1)
    result[1][1]*(4*π)*(4*π*s)/sqrt(λ(s,σ,mπ^2)*λ(s,σp,mπ^2))
end
# Out:
# third_integral (generic function with 1 method)

# %%
first_integral(1.4)*abs(a1BW(1.4))^2, 
    second_integral(1.4)*abs(a1BW(1.4))^2,
    third_integral(1.4,0.7755^2,0.7755^2)
# Out:
# (228.1655452507635, -29.002337248849276, 0.28898889738439243)

# %% [markdown]
# Very important function which changes the basis from
# `(s1,cosθ1,ϕ1,cosθ23,ϕ23)` to `(s3,cosθ3,ϕ3,cosθ12,ϕ12)` by given masses and total energy

# %%
function a1BW(s)
    ma1 = 1.26; mρ = 0.7755; mπ = 0.139;
    Γa1 = 0.4;
    # the last factor (4*π)^2/3 comes due to normalization of phase space
    gsq=2*ma1*Γa1*(8*π)*ma1^2/sqrt(λ(ma1^2,mρ^2,mπ^2))*(4*π)^2/3
    gsq/(ma1^2-s-1im*ma1*Γa1)
end
plot(e->real(a1BW(e^2)),0.75,1.7)
plot!(e->imag(a1BW(e^2)),0.75,1.7)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip9900)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip9900)" points="
# 49.028,375.813 580.315,375.813 580.315,11.811 49.028,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="49" y="11" width="532" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip9902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   74.6846,370.353 74.6846,17.2711
#   "/>
# <polyline clip-path="url(#clip9902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   187.806,370.353 187.806,17.2711
#   "/>
# <polyline clip-path="url(#clip9902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   300.927,370.353 300.927,17.2711
#   "/>
# <polyline clip-path="url(#clip9902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   414.048,370.353 414.048,17.2711
#   "/>
# <polyline clip-path="url(#clip9902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   527.169,370.353 527.169,17.2711
#   "/>
# <polyline clip-path="url(#clip9902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   56.9973,363.447 572.346,363.447
#   "/>
# <polyline clip-path="url(#clip9902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   56.9973,308.978 572.346,308.978
#   "/>
# <polyline clip-path="url(#clip9902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   56.9973,254.51 572.346,254.51
#   "/>
# <polyline clip-path="url(#clip9902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   56.9973,200.042 572.346,200.042
#   "/>
# <polyline clip-path="url(#clip9902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   56.9973,145.574 572.346,145.574
#   "/>
# <polyline clip-path="url(#clip9902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   56.9973,91.1061 572.346,91.1061
#   "/>
# <polyline clip-path="url(#clip9902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   56.9973,36.638 572.346,36.638
#   "/>
# <polyline clip-path="url(#clip9900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   49.028,375.813 580.315,375.813
#   "/>
# <polyline clip-path="url(#clip9900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   49.028,375.813 49.028,11.811
#   "/>
# <polyline clip-path="url(#clip9900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   74.6846,375.813 74.6846,370.353
#   "/>
# <polyline clip-path="url(#clip9900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   187.806,375.813 187.806,370.353
#   "/>
# <polyline clip-path="url(#clip9900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   300.927,375.813 300.927,370.353
#   "/>
# <polyline clip-path="url(#clip9900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   414.048,375.813 414.048,370.353
#   "/>
# <polyline clip-path="url(#clip9900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   527.169,375.813 527.169,370.353
#   "/>
# <polyline clip-path="url(#clip9900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   49.028,363.447 56.9973,363.447
#   "/>
# <polyline clip-path="url(#clip9900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   49.028,308.978 56.9973,308.978
#   "/>
# <polyline clip-path="url(#clip9900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   49.028,254.51 56.9973,254.51
#   "/>
# <polyline clip-path="url(#clip9900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   49.028,200.042 56.9973,200.042
#   "/>
# <polyline clip-path="url(#clip9900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   49.028,145.574 56.9973,145.574
#   "/>
# <polyline clip-path="url(#clip9900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   49.028,91.1061 56.9973,91.1061
#   "/>
# <polyline clip-path="url(#clip9900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   49.028,36.638 56.9973,36.638
#   "/>
# <g clip-path="url(#clip9900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 74.6846, 389.613)" x="74.6846" y="389.613">0.8</text>
# </g>
# <g clip-path="url(#clip9900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 187.806, 389.613)" x="187.806" y="389.613">1.0</text>
# </g>
# <g clip-path="url(#clip9900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 300.927, 389.613)" x="300.927" y="389.613">1.2</text>
# </g>
# <g clip-path="url(#clip9900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 414.048, 389.613)" x="414.048" y="389.613">1.4</text>
# </g>
# <g clip-path="url(#clip9900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 527.169, 389.613)" x="527.169" y="389.613">1.6</text>
# </g>
# <g clip-path="url(#clip9900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 43.028, 367.947)" x="43.028" y="367.947">-2000</text>
# </g>
# <g clip-path="url(#clip9900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 43.028, 313.478)" x="43.028" y="313.478">-1000</text>
# </g>
# <g clip-path="url(#clip9900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 43.028, 259.01)" x="43.028" y="259.01">0</text>
# </g>
# <g clip-path="url(#clip9900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 43.028, 204.542)" x="43.028" y="204.542">1000</text>
# </g>
# <g clip-path="url(#clip9900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 43.028, 150.074)" x="43.028" y="150.074">2000</text>
# </g>
# <g clip-path="url(#clip9900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 43.028, 95.6061)" x="43.028" y="95.6061">3000</text>
# </g>
# <g clip-path="url(#clip9900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 43.028, 41.138)" x="43.028" y="41.138">4000</text>
# </g>
# <polyline clip-path="url(#clip9902)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   51.6517,157.591 100.172,149.429 129.33,144.073 153.983,139.594 180.764,135.402 205.453,133.231 218.687,133.344 231.922,134.855 239.588,136.575 247.255,139.062
#   254.922,142.449 262.589,146.876 2

# %%
# be careful this calculation takes quite long!  
ee = collect(0.75:0.005:1.8)
fi = [first_integral(e^2) for e in ee]
si = [second_integral(e^2) for e in ee]
ti = [third_integral(e^2,0.7755^2,0.7755^2) for e in ee];

# %%
[ee, fi]

# %%
# save output to the files
writedlm("/tmp/fi.txt", fi, " ")
writedlm("/tmp/si.txt", si, " ")
writedlm("/tmp/ti.txt", ti, " ");

# %%
plot(xlabel="\$M_{3\\pi}\\: \\mathrm{(GeV)}\$",
ylabel="Contributions to r.h.s. of unitarity equation")
plot!(ee, [fi[i]*abs(a1BW(ee[i]^2))^2 for i in 1:length(ee)], lab="isobar model")
plot!(ee, [si[i]*abs(a1BW(ee[i]^2))^2 for i in 1:length(ee)], lab="recoupling")
plot!(ee, 50*ti, lab="50 x OPE")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip2300)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip2300)" points="
# 51.5968,360.065 580.315,360.065 580.315,11.811 51.5968,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="51" y="11" width="530" height="349"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip2302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   51.5968,354.842 51.5968,17.0348
#   "/>
# <polyline clip-path="url(#clip2302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   177.482,354.842 177.482,17.0348
#   "/>
# <polyline clip-path="url(#clip2302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   303.367,354.842 303.367,17.0348
#   "/>
# <polyline clip-path="url(#clip2302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   429.253,354.842 429.253,17.0348
#   "/>
# <polyline clip-path="url(#clip2302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   555.138,354.842 555.138,17.0348
#   "/>
# <polyline clip-path="url(#clip2302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   59.5276,354.295 572.384,354.295
#   "/>
# <polyline clip-path="url(#clip2302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   59.5276,305.25 572.384,305.25
#   "/>
# <polyline clip-path="url(#clip2302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   59.5276,256.206 572.384,256.206
#   "/>
# <polyline clip-path="url(#clip2302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   59.5276,207.161 572.384,207.161
#   "/>
# <polyline clip-path="url(#clip2302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   59.5276,158.117 572.384,158.117
#   "/>
# <polyline clip-path="url(#clip2302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   59.5276,109.073 572.384,109.073
#   "/>
# <polyline clip-path="url(#clip2302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   59.5276,60.0281 572.384,60.0281
#   "/>
# <polyline clip-path="url(#clip2300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   51.5968,360.065 580.315,360.065
#   "/>
# <polyline clip-path="url(#clip2300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   51.5968,360.065 51.5968,11.811
#   "/>
# <polyline clip-path="url(#clip2300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   51.5968,360.065 51.5968,354.842
#   "/>
# <polyline clip-path="url(#clip2300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   177.482,360.065 177.482,354.842
#   "/>
# <polyline clip-path="url(#clip2300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   303.367,360.065 303.367,354.842
#   "/>
# <polyline clip-path="url(#clip2300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   429.253,360.065 429.253,354.842
#   "/>
# <polyline clip-path="url(#clip2300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   555.138,360.065 555.138,354.842
#   "/>
# <polyline clip-path="url(#clip2300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   51.5968,354.295 59.5276,354.295
#   "/>
# <polyline clip-path="url(#clip2300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   51.5968,305.25 59.5276,305.25
#   "/>
# <polyline clip-path="url(#clip2300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   51.5968,256.206 59.5276,256.206
#   "/>
# <polyline clip-path="url(#clip2300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   51.5968,207.161 59.5276,207.161
#   "/>
# <polyline clip-path="url(#clip2300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   51.5968,158.117 59.5276,158.117
#   "/>
# <polyline clip-path="url(#clip2300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   51.5968,109.073 59.5276,109.073
#   "/>
# <polyline clip-path="url(#clip2300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   51.5968,60.0281 59.5276,60.0281
#   "/>
# <g clip-path="url(#clip2300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 51.5968, 373.865)" x="51.5968" y="373.865">0.75</text>
# </g>
# <g clip-path="url(#clip2300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 177.482, 373.865)" x="177.482" y="373.865">1.00</text>
# </g>
# <g clip-path="url(#clip2300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 303.367, 373.865)" x="303.367" y="373.865">1.25</text>
# </g>
# <g clip-path="url(#clip2300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 429.253, 373.865)" x="429.253" y="373.865">1.50</text>
# </g>
# <g clip-path="url(#clip2300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 555.138, 373.865)" x="555.138" y="373.865">1.75</text>
# </g>
# <g clip-path="url(#clip2300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 45.5968, 358.795)" x="45.5968" y="358.795">-50</text>
# </g>
# <g clip-path="url(#clip2300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 45.5968, 309.75)" x="45.5968" y="309.75">0</text>
# </g>
# <g clip-path="url(#clip2300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 45.5968, 260.706)" x="45.5968" y="260.706">50</text>
# </g>
# <g clip-path="url(#clip2300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 45.5968, 211.661)" x="45.5968" y="211.661">100</text>
# </g>
# <g clip-path="url(#clip2300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 45.5968, 162.617)" x="45.5968" y="162.617">150</text>
# </g>
# <g clip-path="url(#clip2300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 45.5968, 113.573)" x="45.5968" y="113.573">200</text>
# </g>
# <g clip-path="url(#clip2300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 45.5968, 64.5281)" x="45.5968" y="64.5281">250</text>
# </g>
# <g clip-path="url(#clip2300)">
# <image width="78" height="17" xlink:href="data:;base64,
# iVBORw0KGgoAAAANSUhEUgAAAE4AAAARCAYAAABzcpo/AAAB0ElEQVRYhe1X2ZHCMAyVt4LUAB1Q
# g0tIDSkhNVACNZASaCHpwFACKeHtxyY7xpFsK4lhP1YzGhjrsPx0ODYA6J/09PXpAGJkjBGz2nUd
# jDGI6RSNB8CCiQiXywWcbJb/mPLyPVjy3/c9u/eamF

# %%
savefig("/tmp/contrib.rho.pdf")

# %% [markdown]
# ## Diagonal elements for phase space

# %%
function firho(s)
    mπ=0.139;
    (s <= (3*mπ)^2+0.000001) && return 0;
    function dPhiffs(x, f)
        s1=4*mπ^2+x[1]*((sqrt(s)-mπ)^2-4*mπ^2)
        res = sqrt(λ(s,s1,mπ^2)*λ(s1,mπ^2,mπ^2))/(s*s1)
        res *= ((sqrt(s)-mπ)^2-4*mπ^2)
        res *= abs(f1(s1))^2
        f[1] = res
    end
    result = cuhre(dPhiffs)
    result[1][1] / (2*π)
end

function fisigma(s)
    mπ=0.139;
    (s <= (3*mπ)^2+0.000001) && return 0;
    function dPhiffs(x, f)
        s1=4*mπ^2+x[1]*((sqrt(s)-mπ)^2-4*mπ^2)
        res = sqrt(λ(s,s1,mπ^2)*λ(s1,mπ^2,mπ^2))/(s*s1)
        res *= ((sqrt(s)-mπ)^2-4*mπ^2)
        res *= abs(f0(s1))^2
        psq = λ(s,s1,mπ^2)/(4*s); R = 5;
        # P-wave gives extra factor
        f[1] = res*psq/(1/R^2+psq)
    end
    result = cuhre(dPhiffs)
    result[1][1] / (2*π) / (8*π)
end
# Out:
# fisigma (generic function with 1 method)

# %%
ee = begin
    mπ = 0.139
    ata = 0:0.01:π/2
    3*mπ+[tan(x) for x=0:0.02:π/2]
end
f1TT = [firho(e^2) for e in ee]
f0TT = [fisigma(e^2) for e in ee]
# export
writedlm("/tmp/f1rho.txt",hcat((ee,f1TT)...))
writedlm("/tmp/f0sigma.txt",hcat((ee,f0TT)...))
# plot
plot(ee, f1TT, xlim = (0,3.5), lab="rho pi")
plot!(ee, 10*f0TT, lab="sigma pi")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip0100)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip0100)" points="
# 35.5169,375.813 580.315,375.813 580.315,11.811 35.5169,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="35" y="11" width="546" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip0102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   35.5169,370.353 35.5169,17.2711
#   "/>
# <polyline clip-path="url(#clip0102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   113.345,370.353 113.345,17.2711
#   "/>
# <polyline clip-path="url(#clip0102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   191.174,370.353 191.174,17.2711
#   "/>
# <polyline clip-path="url(#clip0102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   269.002,370.353 269.002,17.2711
#   "/>
# <polyline clip-path="url(#clip0102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   346.83,370.353 346.83,17.2711
#   "/>
# <polyline clip-path="url(#clip0102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   424.658,370.353 424.658,17.2711
#   "/>
# <polyline clip-path="url(#clip0102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   502.487,370.353 502.487,17.2711
#   "/>
# <polyline clip-path="url(#clip0102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   580.315,370.353 580.315,17.2711
#   "/>
# <polyline clip-path="url(#clip0102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   43.6889,375.813 572.143,375.813
#   "/>
# <polyline clip-path="url(#clip0102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   43.6889,302.393 572.143,302.393
#   "/>
# <polyline clip-path="url(#clip0102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   43.6889,228.973 572.143,228.973
#   "/>
# <polyline clip-path="url(#clip0102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   43.6889,155.553 572.143,155.553
#   "/>
# <polyline clip-path="url(#clip0102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   43.6889,82.133 572.143,82.133
#   "/>
# <polyline clip-path="url(#clip0100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.5169,375.813 580.315,375.813
#   "/>
# <polyline clip-path="url(#clip0100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.5169,375.813 35.5169,11.811
#   "/>
# <polyline clip-path="url(#clip0100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.5169,375.813 35.5169,370.353
#   "/>
# <polyline clip-path="url(#clip0100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   113.345,375.813 113.345,370.353
#   "/>
# <polyline clip-path="url(#clip0100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   191.174,375.813 191.174,370.353
#   "/>
# <polyline clip-path="url(#clip0100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   269.002,375.813 269.002,370.353
#   "/>
# <polyline clip-path="url(#clip0100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   346.83,375.813 346.83,370.353
#   "/>
# <polyline clip-path="url(#clip0100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   424.658,375.813 424.658,370.353
#   "/>
# <polyline clip-path="url(#clip0100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   502.487,375.813 502.487,370.353
#   "/>
# <polyline clip-path="url(#clip0100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   580.315,375.813 580.315,370.353
#   "/>
# <polyline clip-path="url(#clip0100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.5169,375.813 43.6889,375.813
#   "/>
# <polyline clip-path="url(#clip0100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.5169,302.393 43.6889,302.393
#   "/>
# <polyline clip-path="url(#clip0100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.5169,228.973 43.6889,228.973
#   "/>
# <polyline clip-path="url(#clip0100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.5169,155.553 43.6889,155.553
#   "/>
# <polyline clip-path="url(#clip0100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   35.5169,82.133 43.6889,82.133
#   "/>
# <g clip-path="url(#clip0100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 35.5169, 389.613)" x="35.5169" y="389.613">0.0</text>
# </g>
# <g clip-path="url(#clip0100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 113.345, 389.613)" x="113.345" y="389.613">0.5</text>
# </g>
# <g clip-path="url(#clip0100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 191.174, 389.613)" x="191.174" y="389.613">1.0</text>
# </g>
# <g clip-path="url(#clip0100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 269.002, 389.613)" x="269.002" y="389.613">1.5</text>
# </g>
# <g clip-path="url(#clip0100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 346.83, 389.613)" x="346.83" y="389.613">2.0</text>
# </g>
# <g clip-path="url(#clip0100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 424.658, 389.613)" x="424.658" y="389.613">2.5</text>
# </g>
# <g clip-path="url(#clip0100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 502.487, 389.613)" x="502.487" y="389.613">3.0</text>
# </g>
# <g clip-path="url(#clip0100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 580.315, 389.613)" x="580.315" y="389.613">3.5</text>
# </g>
# <g clip-path="url(#clip0100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.5169, 380.313)" x="29.5169" y="380.313">0</text>
# </g>
# <g clip-path="url(#clip0100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.5169, 306.893)" x="29.5169" y="306.893">50</text>
# </g>
# <g clip-path="url(#clip0100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.5169, 233.473)" x="29.5169" y="233.473">100</text>
# </g>
# <g clip-path="url(#clip0100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 29.5169, 160.053)" x="29.516
