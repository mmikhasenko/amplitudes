# %% [markdown]
# # Pole positions for the COMPASS resonances
# COMPASS experiment has performed a fit of 13 major waves in the 3pi data set.
# The Breit-Wigner parameters have been extracted. Amplitude which have been used in the analysis are analytical functions of the invariant mass square $s$, therefore analytical continuation to the complex plane makes sence.
#
# In the notebook I perform the continuation for the few waves.

# %% [markdown]
# ![Resonances parameters aj measered by COMPASS](./ajs.png)
#
# ![Resonances parameters pij measered by COMPASS](./pijs.png)

# %% [markdown]
# ### Most of resonances: width does not depend on energy

# %% [markdown]
# The Breit-Wigner amplitude with the constant width reads (Eq. 21)
# $$
# BW = \frac{m_j \Gamma_j}{m_j^2-s-i m_j \Gamma_j}
# $$
# the pole position is given by $s_p = (m_j^2-im_j\Gamma_j)$
#
# The standard procedure to find the mass and width parameters of the pole is $s_p = (m_\text{p}-i\Gamma_\text{p}/2)^2$.
# Therefore, they are a little bit different to BW parameters.

# %%
function mΓpole(mBW,ΓBW)
    rep,imp = reim(sqrt(mBW^2-1im*mBW*ΓBW))
    rep, -2*imp
end
# Out:
# mΓpole (generic function with 1 method)

# %%
# results the COMPASS fit
const ma2=1.3145; const Γa2=0.1066;
const ma1=1.299; const Γa1=0.380;

# simply parameterized a1 resonances
d = Dict()
d["a1(1420)"] = (1411, 161)
d["a1(1640)"] = (1700, 510)
d["a2(1700)"] = (1681, 436)
d["a4(2040)"] = (1935, 333)
# πJ resonances
d["π(1800)"] = (1804, 220)
d["π1(1600)"] = (1600, 580)
d["π(1670)"] = (1642, 311)
d["π(1880)"] = (1847, 246)
d["π2(2005)"] = (1962, 371)
d
# Out:
# Dict{Any,Any} with 9 entries:
#   "a4(2040)" => (1935, 333)
#   "π(1880)"  => (1847, 246)
#   "π2(2005)" => (1962, 371)
#   "π(1800)"  => (1804, 220)
#   "a1(1420)" => (1411, 161)
#   "a1(1640)" => (1700, 510)
#   "π1(1600)" => (1600, 580)
#   "π(1670)"  => (1642, 311)
#   "a2(1700)" => (1681, 436)

# %%
# header
print_head() = begin
    println(rpad("resonance:",20),
            rpad("(mBW, ΓBW)",20),
            " -> ",
            lpad("(m_pole, Γ_pole)",20))
    println(rpad("",63,"-"))
end
print_head()
# parameters
for (k,v) in d
    (m,Γ) = mΓpole(v[1]/1.0e3,v[2]/1.0e3)
    println(rpad(k,20),
        rpad((v[1]/1.0e3,v[2]/1.0e3),20),
        " -> ",
        lpad((round(m,3),round(Γ,3)),20))
end
# Out:
# resonance:          (mBW, ΓBW)           ->     (m_pole, Γ_pole)
# ---------------------------------------------------------------
# a4(2040)            (1.935, 0.333)       ->       (1.942, 0.332)
# π(1880)             (1.847, 0.246)       ->       (1.851, 0.245)
# π2(2005)            (1.962, 0.371)       ->       (1.971, 0.369)
# π(1800)             (1.804, 0.22)        ->        (1.807, 0.22)
# a1(1420)            (1.411, 0.161)       ->       (1.413, 0.161)
# a1(1640)            (1.7, 0.51)          ->       (1.719, 0.504)
# π1(1600)            (1.6, 0.58)          ->       (1.625, 0.571)
# π(1670)             (1.642, 0.311)       ->        (1.649, 0.31)
# a2(1700)            (1.681, 0.436)       ->       (1.695, 0.432)

# %% [markdown]
# ### Special $a_2(1320)$
# The parameterization is given by Eq.(24).
#
# $$
# \Gamma(s) = \Gamma_0\frac{m_{a_2}}{\sqrt{s}}
# \bigg[
#     (1-x)\frac{q_{\rho\pi}(\sqrt{s})}{q_{\rho\pi}(m_{a_2})}\frac{F_2(R^2q_{\rho\pi}^2(\sqrt{s}))}{F_2(R^2q_{\rho\pi}^2(m_{a_{2}}))}
#     +x\frac{q_{\eta\pi}(\sqrt{s})}{q_{\eta\pi}(m_{a_2})}\frac{F_2(R^2q_{\eta\pi}^2(\sqrt{s}))}{F_2(R^2q_{\eta\pi}^2(m_{a_{2}}))}
# \bigg],\quad
# F_2(z) = \frac{z^2}{9+3z+z^2}
# $$
# with the parameters:
#  - $x = 0.2$
#  - $R = 5\,$GeV$^{-1}$

# %%
λ(x,y,z)=x^2+y^2+z^2-2*x*y-2*y*z-2*z*x;

function a2II(s)
    mρ=0.768; mρ2=mρ^2 # mass.indep paper
    mη=0.54786; mη2=mη^2
    mπ=0.139; mπ2=mπ^2
    # obtained parameters
    ma2sq=ma2^2
    # rho pi
    qρ=sqrt(λ(s,mρ2,mπ2)/(4s))
    qρ0=sqrt(λ(ma2sq,mρ2,mπ2)/(4ma2sq))
    Rsq = 5.0^2;
    # eta pi
    qη=sqrt(λ(s,mρ2,mπ2)/(4s))
    qη0=sqrt(λ(ma2sq,mρ2,mπ2)/(4ma2sq))
    # fraction
    xf = 0.2
    # barrier factors
    F2sq(z)=z^2/(9+3z+z^2)
    # enegry-dep. width
    Γ = Γa2*ma2/sqrt(s)*(
        (1-xf)*qρ/qρ0*F2sq(qρ^2*Rsq)/F2sq(qρ0^2*Rsq) +
           xf *qη/qη0*F2sq(qη^2*Rsq)/F2sq(qη0^2*Rsq) )
    ma2sq-s-1im*ma2*Γ
end
# Out:
# a2II (generic function with 1 method)

# %%
using Plots

# %%
sx = 0.5:0.05:3.0
sy = -0.7:0.02:0.7
fss = [a2II(sr+1im*si) for si in sy, sr in sx]
#
contour(sx, sy, [log(abs(f)) for f in fss], levels=40,
    title="Log@Abs@1/A", xlab = "Re(s), GeV^2", ylab = "Im(s), GeV^2")
annotate!(1.7 ,-0.6, "Spurious Blatt-Weisskopf pole/zeros")
annotate!(1.2 ,+0.5, "BW pole/zeros")
annotate!(1.8 ,-0.25,"a2(1320) pole")
hline!([0],lc=:black,label="",ls=:dash)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip6300">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip6300)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip6301">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip6300)" points="
# 61.4812,360.065 520.315,360.065 520.315,31.4961 61.4812,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip6302">
#     <rect x="61" y="31" width="460" height="330"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip6302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   61.4812,360.065 61.4812,31.4961
#   "/>
# <polyline clip-path="url(#clip6302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   153.248,360.065 153.248,31.4961
#   "/>
# <polyline clip-path="url(#clip6302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   245.015,360.065 245.015,31.4961
#   "/>
# <polyline clip-path="url(#clip6302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   336.781,360.065 336.781,31.4961
#   "/>
# <polyline clip-path="url(#clip6302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   428.548,360.065 428.548,31.4961
#   "/>
# <polyline clip-path="url(#clip6302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   520.315,360.065 520.315,31.4961
#   "/>
# <polyline clip-path="url(#clip6302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   61.4812,313.127 520.315,313.127
#   "/>
# <polyline clip-path="url(#clip6302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   61.4812,254.454 520.315,254.454
#   "/>
# <polyline clip-path="url(#clip6302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   61.4812,195.781 520.315,195.781
#   "/>
# <polyline clip-path="url(#clip6302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   61.4812,137.108 520.315,137.108
#   "/>
# <polyline clip-path="url(#clip6302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   61.4812,78.4345 520.315,78.4345
#   "/>
# <polyline clip-path="url(#clip6300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   61.4812,360.065 520.315,360.065
#   "/>
# <polyline clip-path="url(#clip6300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   61.4812,360.065 61.4812,31.4961
#   "/>
# <polyline clip-path="url(#clip6300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   61.4812,360.065 61.4812,355.137
#   "/>
# <polyline clip-path="url(#clip6300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   153.248,360.065 153.248,355.137
#   "/>
# <polyline clip-path="url(#clip6300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   245.015,360.065 245.015,355.137
#   "/>
# <polyline clip-path="url(#clip6300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   336.781,360.065 336.781,355.137
#   "/>
# <polyline clip-path="url(#clip6300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   428.548,360.065 428.548,355.137
#   "/>
# <polyline clip-path="url(#clip6300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   520.315,360.065 520.315,355.137
#   "/>
# <polyline clip-path="url(#clip6300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   61.4812,313.127 68.3638,313.127
#   "/>
# <polyline clip-path="url(#clip6300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   61.4812,254.454 68.3638,254.454
#   "/>
# <polyline clip-path="url(#clip6300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   61.4812,195.781 68.3638,195.781
#   "/>
# <polyline clip-path="url(#clip6300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   61.4812,137.108 68.3638,137.108
#   "/>
# <polyline clip-path="url(#clip6300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   61.4812,78.4345 68.3638,78.4345
#   "/>
# <g clip-path="url(#clip6300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 61.4812, 373.865)" x="61.4812" y="373.865">0.5</text>
# </g>
# <g clip-path="url(#clip6300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 153.248, 373.865)" x="153.248" y="373.865">1.0</text>
# </g>
# <g clip-path="url(#clip6300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 245.015, 373.865)" x="245.015" y="373.865">1.5</text>
# </g>
# <g clip-path="url(#clip6300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 336.781, 373.865)" x="336.781" y="373.865">2.0</text>
# </g>
# <g clip-path="url(#clip6300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 428.548, 373.865)" x="428.548" y="373.865">2.5</text>
# </g>
# <g clip-path="url(#clip6300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 520.315, 373.865)" x="520.315" y="373.865">3.0</text>
# </g>
# <g clip-path="url(#clip6300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 55.4812, 317.627)" x="55.4812" y="317.627">-0.50</text>
# </g>
# <g clip-path="url(#clip6300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 55.4812, 258.954)" x="55.4812" y="258.954">-0.25</text>
# </g>
# <g clip-path="url(#clip6300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 55.4812, 200.281)" x="55.4812" y="200.281">0.00</text>
# </g>
# <g clip-path="url(#clip6300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 55.4812, 141.608)" x="55.4812" y="141.608">0.25</text>
# </g>
# <g clip-path="url(#clip6300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 55.4812, 82.9345)" x="55.4812" y="82.9345">0.50</text>
# </g>
# <g clip-path="url(#clip6300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(0, 290.898, 18)" x="290.898" y="18">Log@Abs@1/A</text>
# </g>
# <g clip-path="url(#clip6300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(0, 290.898, 397.6)" x="290.898" y="397.6">Re(s), GeV^2</text>
# </g>
# <g clip-path="url(#clip6300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(-90, 14.4, 195.781)" x="14.4" y="195.781">Im(s), GeV^2</text>
# </g>
# <polyline clip-path="url(#clip6302)" style="stroke:#f8880c; stroke-width:1;

# %% [markdown]
# Zoom of the previous plot

# %%
sx = 1.68:0.5e-3:1.72
sy = -0.15:0.2e-3:-0.12
fss = [a2II(sr+1im*si) for si in sy, sr in sx]
contour(sx, sy, [log(abs(f)) for f in fss], levels=40,
    title="Log@Abs@1/A", xlab = "Re(s), GeV^2", ylab = "Im(s), GeV^2")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip6500">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip6500)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip6501">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip6500)" points="
# 61.4812,360.065 520.315,360.065 520.315,31.4961 61.4812,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip6502">
#     <rect x="61" y="31" width="460" height="330"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip6502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   61.4812,360.065 61.4812,31.4961
#   "/>
# <polyline clip-path="url(#clip6502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   176.19,360.065 176.19,31.4961
#   "/>
# <polyline clip-path="url(#clip6502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   290.898,360.065 290.898,31.4961
#   "/>
# <polyline clip-path="url(#clip6502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   405.607,360.065 405.607,31.4961
#   "/>
# <polyline clip-path="url(#clip6502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   520.315,360.065 520.315,31.4961
#   "/>
# <polyline clip-path="url(#clip6502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   61.4812,360.065 520.315,360.065
#   "/>
# <polyline clip-path="url(#clip6502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   61.4812,250.542 520.315,250.542
#   "/>
# <polyline clip-path="url(#clip6502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   61.4812,141.019 520.315,141.019
#   "/>
# <polyline clip-path="url(#clip6502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   61.4812,31.4961 520.315,31.4961
#   "/>
# <polyline clip-path="url(#clip6500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   61.4812,360.065 520.315,360.065
#   "/>
# <polyline clip-path="url(#clip6500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   61.4812,360.065 61.4812,31.4961
#   "/>
# <polyline clip-path="url(#clip6500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   61.4812,360.065 61.4812,355.137
#   "/>
# <polyline clip-path="url(#clip6500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   176.19,360.065 176.19,355.137
#   "/>
# <polyline clip-path="url(#clip6500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   290.898,360.065 290.898,355.137
#   "/>
# <polyline clip-path="url(#clip6500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   405.607,360.065 405.607,355.137
#   "/>
# <polyline clip-path="url(#clip6500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   520.315,360.065 520.315,355.137
#   "/>
# <polyline clip-path="url(#clip6500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   61.4812,360.065 68.3638,360.065
#   "/>
# <polyline clip-path="url(#clip6500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   61.4812,250.542 68.3638,250.542
#   "/>
# <polyline clip-path="url(#clip6500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   61.4812,141.019 68.3638,141.019
#   "/>
# <polyline clip-path="url(#clip6500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   61.4812,31.4961 68.3638,31.4961
#   "/>
# <g clip-path="url(#clip6500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 61.4812, 373.865)" x="61.4812" y="373.865">1.68</text>
# </g>
# <g clip-path="url(#clip6500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 176.19, 373.865)" x="176.19" y="373.865">1.69</text>
# </g>
# <g clip-path="url(#clip6500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 290.898, 373.865)" x="290.898" y="373.865">1.70</text>
# </g>
# <g clip-path="url(#clip6500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 405.607, 373.865)" x="405.607" y="373.865">1.71</text>
# </g>
# <g clip-path="url(#clip6500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 520.315, 373.865)" x="520.315" y="373.865">1.72</text>
# </g>
# <g clip-path="url(#clip6500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 55.4812, 364.565)" x="55.4812" y="364.565">-0.15</text>
# </g>
# <g clip-path="url(#clip6500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 55.4812, 255.042)" x="55.4812" y="255.042">-0.14</text>
# </g>
# <g clip-path="url(#clip6500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 55.4812, 145.519)" x="55.4812" y="145.519">-0.13</text>
# </g>
# <g clip-path="url(#clip6500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 55.4812, 35.9961)" x="55.4812" y="35.9961">-0.12</text>
# </g>
# <g clip-path="url(#clip6500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(0, 290.898, 18)" x="290.898" y="18">Log@Abs@1/A</text>
# </g>
# <g clip-path="url(#clip6500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(0, 290.898, 397.6)" x="290.898" y="397.6">Re(s), GeV^2</text>
# </g>
# <g clip-path="url(#clip6500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(-90, 14.4, 195.781)" x="14.4" y="195.781">Im(s), GeV^2</text>
# </g>
# <polyline clip-path="url(#clip6502)" style="stroke:#f4f588; stroke-width:1; stroke-opacity:1; fill:none" points="
#   79.9025,360.065 78.6875,358.249 78.4371,357.875 76.9941,355.684 75.585,353.494 74.2096,351.304 72.9521,349.253 72.8662,349.113 71.5408,346.923 70.2472,344.732
#   68.9851,342.542 67.7539,340.351 67.2167,339.375 66.5446,338.161 65.3582,335.97 64.2013,333.78 63.0735,331.589 61.9744,329.399 61.4812,328.394
#   "/>
# <polyline clip-path="url(#clip6502)" style="stroke:#f2ea6c; stroke-width:1; stroke-opacity:1; fill:none" points="
#   119.622,360.065 118.835,359.091 117.858,357.875 116.133,355.684 114.453,353.494 113.1,351.685 112.815,351.304 111.207,349.113 109.641,346.923 108.116,344.732
#   107.365,343.628 106.624,342.542 105.163,340.351 103.741,338.161 102.357,335.97 101.629,334.792 101.002,333.78 99.6752,331.589 98.384,329.399 97.1283,327.208
#   95.9074,325.018 95.8938,324.993 94.7034,322.828 93.5326,320.637 92.3949,318.447 91.2897,316.256 90.2165,314.066 90.1584,313.944 89.1584,311.875 88.1303,309.685
#   87.1326,307.494 86.1649,305.304 85.2268,303.113 84.4229,301.178 84.3159,300.923 83.4194,298.732 82.5511,296.542 81.7107,294.352 80.8979,292.161 80.1121,289.971

# %% [markdown]
# Pole position, approximately

# %%
(ma2pole,Γa2pole) = 
begin
    sp = 1.705-0.137im # just by eye
    rep,imp = reim(sqrt(sp))
    rep,-2.*imp
end
# Out:
# (1.3068081821599387, 0.10483558480140641)

# %%
print_head()
begin
        println(rpad("a2(1320)",20),
        rpad((ma2,Γa2),20),
        " -> ",
        lpad((round(ma2pole,3),round(Γa2pole,3)),20))
end
# Out:
# resonance:          (mBW, ΓBW)           ->     (m_pole, Γ_pole)
# ---------------------------------------------------------------
# a2(1320)            (1.3145, 0.1066)     ->       (1.307, 0.105)

# %% [markdown]
# ### $a_1(1260)$ the trickiest one
# energy-dependent width involves quasi-two-body parameterization
#
# To continue, I use non-symmetrized matrix element which makes it different to original COMPASS parameterization.
# In the calculation below:
# $$
# \Gamma(s) = \Gamma_0 \frac{\rho(s)}{\rho(m_{a_1}^2)}\frac{m_{a_1}}{\sqrt{s}},\quad\text{where}\quad
# \rho(s) = \int_{4m_\pi^2}^{(\sqrt{s}-m_\pi)^2} \frac{\mathrm{d}s_1}{2\pi} U_\rho(s)
# \frac{1}{8\pi} \frac{\lambda^{1/2}(s,s_1,m_\pi^2)}{s}
# $$
#
# the function $U(s_1)$ is a given of rho meson line shape $U(s_1) = \big|f_\rho(s_1)\big|^2 (1-4m_\pi^2/s_1)^{1/2}$

# %%
using QuadGK

# %%
const mπ=0.139; const mπ2=mπ^2;

# %%
ρ(s,m1sq,m2sq)=1/(8*π)*sqrt(λ(s,m1sq,m2sq))/s
# arbitrary normalization 
function Uρ(s)
    mρ=0.7685; mρ2=mρ^2 # mass.indep paper
    # Break-up momentum
    p = sqrt(λ(s,mπ2,mπ2)/(4*s))
    p0 = sqrt(λ(mρ2,mπ2,mπ2)/(4*mρ2))
    # Blatt-Weisskopf stuff
    R = 5  # GeV^-1
    F = 1./(1./R^2+p^2)
    F0 = 1./(1./R^2+p0^2)
    # FF
    BWs = p^2*F/(p0^2*F0)
    # Energy dependent width
    Γ0 = 0.1507;
    Γ = Γ0*(p/p0)*mρ/sqrt(s)*BWs
    return BWs/((mρ^2-s)^2+mρ^2*Γ^2)
end
# Out:
# Uρ (generic function with 1 method)

# %%
using QuadGK

# %%
# complex agrument
ρ(s::Complex{Float64}) = 1/(8*π*s)/(2π)*begin
    s_f = (sqrt(s)-mπ)^2 # final piont
    s_m = real(s_f)+1.0im*imag(s_f)/100; # point in the middle
    integrand = s1->begin
        sqrt(λ(s,s1,mπ^2))*Uρ(s1)*sqrt(λ(s1,mπ2,mπ2))/(8*π*s1)
    end
    int1 = quadgk(integrand, 4*mπ2, s_m)[1]
    int2 = quadgk(integrand, s_m, s_f)[1]
    int1+int2
end
# Out:
# ρ (generic function with 2 methods)

# %%
function a1II(s::Complex{Float64},m0,Γ0)
    Γ = Γ0*m0/sqrt(s)*ρ(s)/ρ(m0^2+1e-5im)
    m0^2-s-1im*m0*Γ
end
# Out:
# a1II (generic function with 1 method)

# %% [markdown]
# The first and the second sheet of the complex plane

# %%
sx = 0.5:0.05:3.0
sy = -0.8:0.02:0.8
fss = [a1II(sr+1im*si,ma1,Γa1) for si in sy, sr in sx]
#
contour(sx, sy, [log(abs(f)) for f in fss], levels=40,
    title="Log@Abs@1/A", xlab = "Re(s), GeV^2", ylab = "Im(s), GeV^2")
annotate!(1.2 ,-0.2,"Rho-Pi cut")
annotate!(1.2 , 0.2,"Rho-Pi cut")
annotate!(1.8 ,-0.65,"a1(1260) pole")
hline!([0],lc=:black,label="",ls=:dash)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip6700">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip6700)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip6701">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip6700)" points="
# 54.8916,360.065 520.315,360.065 520.315,31.4961 54.8916,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip6702">
#     <rect x="54" y="31" width="466" height="330"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip6702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   54.8916,360.065 54.8916,31.4961
#   "/>
# <polyline clip-path="url(#clip6702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   147.976,360.065 147.976,31.4961
#   "/>
# <polyline clip-path="url(#clip6702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   241.061,360.065 241.061,31.4961
#   "/>
# <polyline clip-path="url(#clip6702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   334.146,360.065 334.146,31.4961
#   "/>
# <polyline clip-path="url(#clip6702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   427.23,360.065 427.23,31.4961
#   "/>
# <polyline clip-path="url(#clip6702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   520.315,360.065 520.315,31.4961
#   "/>
# <polyline clip-path="url(#clip6702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   54.8916,318.994 520.315,318.994
#   "/>
# <polyline clip-path="url(#clip6702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   54.8916,257.387 520.315,257.387
#   "/>
# <polyline clip-path="url(#clip6702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   54.8916,195.781 520.315,195.781
#   "/>
# <polyline clip-path="url(#clip6702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   54.8916,134.174 520.315,134.174
#   "/>
# <polyline clip-path="url(#clip6702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   54.8916,72.5672 520.315,72.5672
#   "/>
# <polyline clip-path="url(#clip6700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   54.8916,360.065 520.315,360.065
#   "/>
# <polyline clip-path="url(#clip6700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   54.8916,360.065 54.8916,31.4961
#   "/>
# <polyline clip-path="url(#clip6700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   54.8916,360.065 54.8916,355.137
#   "/>
# <polyline clip-path="url(#clip6700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   147.976,360.065 147.976,355.137
#   "/>
# <polyline clip-path="url(#clip6700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   241.061,360.065 241.061,355.137
#   "/>
# <polyline clip-path="url(#clip6700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   334.146,360.065 334.146,355.137
#   "/>
# <polyline clip-path="url(#clip6700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   427.23,360.065 427.23,355.137
#   "/>
# <polyline clip-path="url(#clip6700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   520.315,360.065 520.315,355.137
#   "/>
# <polyline clip-path="url(#clip6700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   54.8916,318.994 61.873,318.994
#   "/>
# <polyline clip-path="url(#clip6700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   54.8916,257.387 61.873,257.387
#   "/>
# <polyline clip-path="url(#clip6700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   54.8916,195.781 61.873,195.781
#   "/>
# <polyline clip-path="url(#clip6700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   54.8916,134.174 61.873,134.174
#   "/>
# <polyline clip-path="url(#clip6700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   54.8916,72.5672 61.873,72.5672
#   "/>
# <g clip-path="url(#clip6700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 54.8916, 373.865)" x="54.8916" y="373.865">0.5</text>
# </g>
# <g clip-path="url(#clip6700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 147.976, 373.865)" x="147.976" y="373.865">1.0</text>
# </g>
# <g clip-path="url(#clip6700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 241.061, 373.865)" x="241.061" y="373.865">1.5</text>
# </g>
# <g clip-path="url(#clip6700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 334.146, 373.865)" x="334.146" y="373.865">2.0</text>
# </g>
# <g clip-path="url(#clip6700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 427.23, 373.865)" x="427.23" y="373.865">2.5</text>
# </g>
# <g clip-path="url(#clip6700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 520.315, 373.865)" x="520.315" y="373.865">3.0</text>
# </g>
# <g clip-path="url(#clip6700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 48.8916, 323.494)" x="48.8916" y="323.494">-0.6</text>
# </g>
# <g clip-path="url(#clip6700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 48.8916, 261.887)" x="48.8916" y="261.887">-0.3</text>
# </g>
# <g clip-path="url(#clip6700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 48.8916, 200.281)" x="48.8916" y="200.281">0.0</text>
# </g>
# <g clip-path="url(#clip6700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 48.8916, 138.674)" x="48.8916" y="138.674">0.3</text>
# </g>
# <g clip-path="url(#clip6700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 48.8916, 77.0672)" x="48.8916" y="77.0672">0.6</text>
# </g>
# <g clip-path="url(#clip6700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(0, 287.603, 18)" x="287.603" y="18">Log@Abs@1/A</text>
# </g>
# <g clip-path="url(#clip6700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(0, 287.603, 397.6)" x="287.603" y="397.6">Re(s), GeV^2</text>
# </g>
# <g clip-path="url(#clip6700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(-90, 14.4, 195.781)" x="14.4" y="195.781">Im(s), GeV^2</text>
# </g>
# <polyline clip-path="url(#clip6702)" style="stroke:#f2ea6c; stroke-width:1; stroke-opacity:

# %% [markdown]
# Zoom of the previous plot

# %%
sx = 1.655:0.2e-3:1.67
sy = -0.528:0.2e-3:-0.518
fss = [a1II(sr+1im*si,ma1,Γa1) for si in sy, sr in sx]
#
contour(sx, sy, [log(abs(f)) for f in fss], levels=40,
    title="Log@Abs@1/A", xlab = "Re(s), GeV^2", ylab = "Im(s), GeV^2")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip6900">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip6900)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip6901">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip6900)" points="
# 74.6605,360.065 520.315,360.065 520.315,31.4961 74.6605,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip6902">
#     <rect x="74" y="31" width="447" height="330"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip6902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   74.6605,360.065 74.6605,31.4961
#   "/>
# <polyline clip-path="url(#clip6902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   223.212,360.065 223.212,31.4961
#   "/>
# <polyline clip-path="url(#clip6902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   371.763,360.065 371.763,31.4961
#   "/>
# <polyline clip-path="url(#clip6902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   520.315,360.065 520.315,31.4961
#   "/>
# <polyline clip-path="url(#clip6902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   74.6605,343.637 520.315,343.637
#   "/>
# <polyline clip-path="url(#clip6902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   74.6605,261.495 520.315,261.495
#   "/>
# <polyline clip-path="url(#clip6902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   74.6605,179.352 520.315,179.352
#   "/>
# <polyline clip-path="url(#clip6902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   74.6605,97.2099 520.315,97.2099
#   "/>
# <polyline clip-path="url(#clip6900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   74.6605,360.065 520.315,360.065
#   "/>
# <polyline clip-path="url(#clip6900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   74.6605,360.065 74.6605,31.4961
#   "/>
# <polyline clip-path="url(#clip6900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   74.6605,360.065 74.6605,355.137
#   "/>
# <polyline clip-path="url(#clip6900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   223.212,360.065 223.212,355.137
#   "/>
# <polyline clip-path="url(#clip6900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   371.763,360.065 371.763,355.137
#   "/>
# <polyline clip-path="url(#clip6900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   520.315,360.065 520.315,355.137
#   "/>
# <polyline clip-path="url(#clip6900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   74.6605,343.637 81.3453,343.637
#   "/>
# <polyline clip-path="url(#clip6900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   74.6605,261.495 81.3453,261.495
#   "/>
# <polyline clip-path="url(#clip6900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   74.6605,179.352 81.3453,179.352
#   "/>
# <polyline clip-path="url(#clip6900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   74.6605,97.2099 81.3453,97.2099
#   "/>
# <g clip-path="url(#clip6900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 74.6605, 373.865)" x="74.6605" y="373.865">1.655</text>
# </g>
# <g clip-path="url(#clip6900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 223.212, 373.865)" x="223.212" y="373.865">1.660</text>
# </g>
# <g clip-path="url(#clip6900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 371.763, 373.865)" x="371.763" y="373.865">1.665</text>
# </g>
# <g clip-path="url(#clip6900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 520.315, 373.865)" x="520.315" y="373.865">1.670</text>
# </g>
# <g clip-path="url(#clip6900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 68.6605, 348.137)" x="68.6605" y="348.137">-0.5275</text>
# </g>
# <g clip-path="url(#clip6900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 68.6605, 265.995)" x="68.6605" y="265.995">-0.5250</text>
# </g>
# <g clip-path="url(#clip6900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 68.6605, 183.852)" x="68.6605" y="183.852">-0.5225</text>
# </g>
# <g clip-path="url(#clip6900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 68.6605, 101.71)" x="68.6605" y="101.71">-0.5200</text>
# </g>
# <g clip-path="url(#clip6900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(0, 297.488, 18)" x="297.488" y="18">Log@Abs@1/A</text>
# </g>
# <g clip-path="url(#clip6900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(0, 297.488, 397.6)" x="297.488" y="397.6">Re(s), GeV^2</text>
# </g>
# <g clip-path="url(#clip6900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(-90, 14.4, 195.781)" x="14.4" y="195.781">Im(s), GeV^2</text>
# </g>
# <polyline clip-path="url(#clip6902)" style="stroke:#f2ea6c; stroke-width:1; stroke-opacity:1; fill:none" points="
#   112.736,360.065 110.313,357.088 107.477,353.494 104.371,349.367 102.58,346.923 98.4287,340.955 98.0181,340.351 93.7552,333.78 92.4867,331.709 89.7774,327.208
#   86.5446,321.477 86.0775,320.637 82.6158,314.066 80.6026,309.961 79.4029,307.494 76.4119,300.923 74.6605,296.769
#   "/>
# <polyline clip-path="url(#clip6902)" style="stroke:#f3e055; stroke-width:1; stroke-opacity:1; fill:none" points="
#   150.638,360.065 145.965,355.595 143.877,353.494 140.023,349.467 137.695,346.923 134.081,342.799 132.019,340.351 128.139,335.515 126.793,333.78 122.197,327.521
#   121.974,327.208 117.514,320.637 116.255,318.661 113.391,314.066 110.313,308.763 109.589,307.494 106.068,300.923 104.371,297.5 102.825,294.352 99.8414,287.78
#   98.4287,284.396 97.103,281.209 94.5946,274.637 92.4867,268.52 92.3299,268.066 90.2518,261.495 88.4001,254.923 86.7651,248.352 86.5446,247.349 85.3036,241.78
#   84.0395,235.209 82.9723,228.638 82.0963,222.066 81.4066,215.495 80.8994,208.924 80.6026,202.974 80.5707,202.352 80.4161,195.781 80.4437,189.209 80.6026,184.235
#   80.6521,182.638 81.034,176.067 81.5962,169.495 82.3419,162.924 83.2753,156.352 84.4015,149.781 85.7265,143.21 86.5446,139.674 87.2382,136.638 88.9379,130.067
#   90.8572,123.495 92.4867,118.488 92.9934,116.924 95.328,110.353 97.9139,103.781 98.4287,102.57 100.716,97.2099 103.786,90.6385 104.371,89.4693 107.102,84.0672
#   110.313,78.2148 110.713,77.4958 114.607,70.9244 116.255,68.3217 118.825,64.353 122.197,59.4661 123.392,57.7816 128.139,51.4627 128.335,51.2102 133.691,44.6388
#   134.081,44.1814 139.512,38.0675 140.023,37.5153 145.858,31.4961
#   "/>
# <polyline clip-path

# %%
(ma1pole,Γa1pole) = 
begin
    sp = 1.662-0.522im # just by eye
    rep,imp = reim(sqrt(sp))
    rep,-2.*imp
end
# Out:
# (1.304616240833809, 0.40011766193128057)

# %%
print_head()
begin
        println(rpad("a1(1260)",20),
        rpad((ma1,Γa1),20),
        " -> ",
        lpad((round(ma1pole,3),round(Γa1pole,3)),20))
end
# Out:
# resonance:          (mBW, ΓBW)           ->     (m_pole, Γ_pole)
# ---------------------------------------------------------------
# a1(1260)            (1.299, 0.38)        ->         (1.305, 0.4)
